# %%
from alyx_connector import Connector
connector = Connector()

# %%
from alyx_connector.files import File

# %%
session = connector.search(name="wm28/20025-04-01/001")
# Out:
# Loading sessions details: 100%|██████████| 30/30 [00:03<00:00,  7.69it/s]

# %%
connector.

session
# Out:
# id                                           b7ae0fae-6831-4018-9455-2d72181bb77f
# subject                                                                      ea04
# users                                                                [wilsonmena]
# location                                                                     None
# procedures                                                                     []
# lab                                                                      HaissLab
# projects                                                                       []
# type                                                                         None
# task_protocol
# number                                                                          1
# start_time                                              2025-11-01T00:00:00+01:00
# end_time                                                                     None
# narrative
# parent_session                                                               None
# n_correct_trials                                                             None
# n_trials                                                                     None
# url                             http://127.0.0.1/sessions/b7ae0fae-6831-4018-9...
# extended_qc                                                                  None
# qc                                                                        NOT_SET
# wateradmin_session_related                                                     []
# data_dataset_session_related                                                   []
# auto_datetime                                    2025-04-28T08:36:04.693721+02:00
# alias                                                         ea04/2025-10-31/001
# u_alias                                                       ea04_2025-10-31_001
# path                            //157.99.138.167/cajal_data2/ONE/MotorSense/ea...
# json                                                                         None
# probe_insertion                                                                []
# notes                                                                          []
# default_data_repository_path          //157.99.138.167/cajal_data2/ONE/MotorSense
# default_data_repository_name                                     Cajal2MotorSense
# default_data_repository_pk                   70a43e0f-09b3-4c0f-996c-12edbdaff06d
# rel_path                                                      ea04/2025-10-31/001
# admin_url                       /admin/actions/session/b7ae0fae-6831-4018-9455...
# Name: 0, dtype: object
