# %%
from alyx_connector import Connector

# %%
connector = Connector.setup(url="http://127.0.0.1:80")
# Out:
# Please enter the username that you use to connect to http://127.0.0.1:80 (admin):

# %%
connector = Connector(url="127.0.0.1", username="admin")

# %%
connector = Connector()

# %%
connector.web_client.is_logged_in()
# Out:
# True

# %%
connector.web_client.schema.paths_dict.keys()
# Out:
# dict_keys(['/api/auth-token', '/api/brain-regions', '/api/brain-regions/{id}', '/api/cache.zip', '/api/cache/info/', '/api/channels', '/api/channels/{id}', '/api/data-formats', '/api/data-formats/{name}', '/api/data-repository', '/api/data-repository-type', '/api/data-repository-type/{name}', '/api/data-repository/{name}', '/api/dataset-types', '/api/dataset-types/{name}', '/api/datasets', '/api/datasets/{id}', '/api/downloads', '/api/downloads/{id}', '/api/files', '/api/files/{id}', '/api/insertions', '/api/insertions/{id}', '/api/labs', '/api/labs/{name}', '/api/locations', '/api/locations/{name}', '/api/media/{img_url}', '/api/new-download', '/api/notes', '/api/notes/{id}', '/api/procedures', '/api/projects', '/api/projects/{name}', '/api/register-file', '/api/revisions', '/api/revisions/{name}', '/api/server-info', '/api/sessions', '/api/sessions/{name}', '/api/sessions/{id}', '/api/subjects', '/api/subjects/{nickname}', '/api/surgeries', '/api/sync-file-status', '/api/tags', '/api/tags/{id}', '/api/tasks', '/api/tasks/{id}', '/api/trajectories', '/api/trajectories/{id}', '/api/users', '/api/users/{username}', '/api/water-administrations', '/api/water-administrations/{id}', '/api/water-requirement/{nickname}', '/api/water-restricted-subjects', '/api/water-restriction', '/api/water-type', '/api/water-type/{name}', '/api/weighings', '/api/weighings/{id}'])

# %%
connector.web_client.list_endpoints()
# Out:
# ['/api/auth-token',
#  '/api/brain-regions',
#  '/api/brain-regions/{id}',
#  '/api/cache.zip',
#  '/api/cache/info/',
#  '/api/channels',
#  '/api/channels/{id}',
#  '/api/data-formats',
#  '/api/data-formats/{name}',
#  '/api/data-repository',
#  '/api/data-repository-type',
#  '/api/data-repository-type/{name}',
#  '/api/data-repository/{name}',
#  '/api/dataset-types',
#  '/api/dataset-types/{name}',
#  '/api/datasets',
#  '/api/datasets/{id}',
#  '/api/downloads',
#  '/api/downloads/{id}',
#  '/api/files',
#  '/api/files/{id}',
#  '/api/insertions',
#  '/api/insertions/{id}',
#  '/api/labs',
#  '/api/labs/{name}',
#  '/api/locations',
#  '/api/locations/{name}',
#  '/api/media/{img_url}',
#  '/api/new-download',
#  '/api/notes',
#  '/api/notes/{id}',
#  '/api/procedures',
#  '/api/projects',
#  '/api/projects/{name}',
#  '/api/register-file',
#  '/api/revisions',
#  '/api/revisions/{name}',
#  '/api/server-info',
#  '/api/sessions',
#  '/api/sessions/{id}',
#  '/api/sessions/{name}',
#  '/api/subjects',
#  '/api/subjects/{nickname}',
#  '/api/surgeries',
#  '/api/sync-file-status',
#  '/api/tags',
#  '/api/tags/{id}',
#  '/api/tasks',
#  '/api/tasks/{id}',
#  '/api/trajectories',
#  '/api/trajectories/{id}',
#  '/api/users',
#  '/api/users/{username}',
#  '/api/water-administrations',
#  '/api/water-administrations/{id}',
#  '/api/water-requirement/{nickname}',
#  '/api/water-restricted-subjects',
#  '/api/water-restriction',
#  '/api/water-type',
#  '/api/water-type/{name}',
#  '/api/weighings',
#  '/api/weighings/{id}']

# %%
sessions = connector.search()
sessions
# Out:
#                                                        id subject    users  \
# name
# ihem/2025-12-15/002  ebecd55f-a8d7-4d93-890e-3cbc47c60f7c    ihem  [admin]
#
#                     location           procedures         lab       projects  \
# name
# ihem/2025-12-15/002     None  [Behaviour Imaging]  defaultlab  [TestProject]
#
#                      type task_protocol  number  ...              u_alias  \
# name                                             ...
# ihem/2025-12-15/002  None                     2  ...  ihem_2025-12-15_002
#
#                                                           path  json  \
# name
# ihem/2025-12-15/002  //127.0.0.1/here/test/ihem/2025-12-15/002  None
#
#                     probe_insertion notes default_data_repository_path  \
# name
# ihem/2025-12-15/002              []    []        //127.0.0.1/here/test
#
#                     default_data_repository_name  \
# name
# ihem/2025-12-15/002                         Test
#
#                                default_data_repository_pk  \
# name
# ihem/2025-12-15/002  20712cf2-24ae-4133-a316-b159e9222446
#
#                                 rel_path  \
# name
# ihem/2025-12-15/002  ihem/2025-12-15/002
#
#                                                              admin_url
# name
# ihem/2025-12-15/002  /admin/actions/session/ebecd55f-a8d7-4d93-890e...
#
# [1 rows x 33 columns]

# %%
connector.web_client.endpoint("sessions").actions["list"].request_method()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 connector.web_client.endpoint("sessions").actions["list"].request_method()
#
# TypeError: get() missing 1 required positional argument: 'url'

# %%
connector.web_client.create(endpoint="sessions")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 connector.web_client.create(endpoint="sessions")
#
# TypeError: Client.create() missing 1 required keyword-only argument: 'data'

# %%
import re
pattern = re.compile(r"^(?:/sessions|[\w/-]+/sessions)(?:(?=/{).*)?$")

# %%
for key in connector.web_client.schema.paths_dict.keys():
    if pattern.findall(key):
        print(key)
