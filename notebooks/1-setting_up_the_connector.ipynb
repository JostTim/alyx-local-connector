# %%
from alyx_connector import Connector

# %%
Connector.setup()
# Out:
# Please enter the server address that you use to connect to alyx. (http://127.0.0.1:80):
# Please enter the username that you use to connect to http://127.0.0.1:80 (myname):
# Enter Alyx password for myname at http://127.0.0.1:80:
# Connected to http://127.0.0.1:80 as myname

# %%
connector = Connector(url="127.0.0.1", username="tjostmou")

# %%
connector.url, connector.username
# Out:
# ('http://127.0.0.1:80', 'tjostmou')
