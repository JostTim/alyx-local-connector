# %%
from alyx_connector import Connector

# %%
# connector = Connector.setup(url="http://127.0.0.1:80")

# %%
# connector = Connector(url="127.0.0.1", username="tjostmou")

# %%
connector = Connector()

# %%
connector.web_client.rest("sessions","list")
# Out:
# [{'id': '1373d5f0-79b7-4161-a4e2-8643a0e08a14',
#   'name': 'ihem05/2024-11-06/003',
#   'subject': 'ihem05',
#   'start_time': '2024-11-06T20:03:24+01:00',
#   'number': 3,
#   'projects': ['Interhem'],
#   'users': ['lpanelat'],
#   'url': 'http://127.0.0.1/sessions/1373d5f0-79b7-4161-a4e2-8643a0e08a14',
#   'admin_url': '/admin/actions/session/1373d5f0-79b7-4161-a4e2-8643a0e08a14/change/',
#   'procedures': ['Z-stack with Two photon Imaging in live animals'],
#   'default_data_repository': '//157.99.138.167/cajal_data2/ONE/Interhem'},
#  {'id': 'dc5a61db-cbb6-48dc-bcb9-310211c8512c',
#   'name': 'ihem05/2024-11-06/002',
#   'subject': 'ihem05',
#   'start_time': '2024-11-06T17:24:23+01:00',
#   'number': 2,
#   'projects': ['Interhem'],
#   'users': ['lpanelat'],
#   'url': 'http://127.0.0.1/sessions/dc5a61db-cbb6-48dc-bcb9-310211c8512c',
#   'admin_url': '/admin/actions/session/dc5a61db-cbb6-48dc-bcb9-310211c8512c/change/',
#   'procedures': ['Two photon Imaging'],
# ...

# %%
connector.web_client.rest("sessions","retrieve",name="ihem05/2024-11-06/002")
# Out:
# {'id': 'dc5a61db-cbb6-48dc-bcb9-310211c8512c',
#  'subject': 'ihem05',
#  'users': ['lpanelat'],
#  'location': 'Fernbach - 2p stim setup',
#  'procedures': ['Two photon Imaging'],
#  'lab': 'HaissLab',
#  'projects': ['Interhem'],
#  'type': None,
#  'task_protocol': '',
#  'number': 2,
#  'start_time': '2024-11-06T17:24:23+01:00',
#  'end_time': None,
# ...

# %%
connector.web_client.rest("sessions","retrieve",id="dc5a61db-cbb6-48dc-bcb9-310211c8512c")
# Out:
# {'id': 'dc5a61db-cbb6-48dc-bcb9-310211c8512c',
#  'subject': 'ihem05',
#  'users': ['lpanelat'],
#  'location': 'Fernbach - 2p stim setup',
#  'procedures': ['Two photon Imaging'],
#  'lab': 'HaissLab',
#  'projects': ['Interhem'],
#  'type': None,
#  'task_protocol': '',
#  'number': 2,
#  'start_time': '2024-11-06T17:24:23+01:00',
#  'end_time': None,
# ...

# %%
connector.search(name="ihem05/2024-11-06/002", id="dc5a61db-cbb6-48dc-bcb9-310211c8512c", raises=False)
# Out:
# C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:325: UserWarning: Several required parameters needed by the operators are present, for retrieve the first matching, /sessions/{name} will be used. Found matching : /sessions/{name}, or /sessions/{id}
#   warn(
# subject                                                                    ihem05
# users                                                                  [lpanelat]
# location                                                 Fernbach - 2p stim setup
# procedures                                                   [Two photon Imaging]
# lab                                                                      HaissLab
# projects                                                               [Interhem]
# type                                                                         None
# task_protocol
# number                                                                          2
# ...
