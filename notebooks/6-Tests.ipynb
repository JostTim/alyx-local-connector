# %%
from alyx_connector import Connector

connector = Connector()
session = connector.remote.rest(
    "sessions", "retrieve", name="ihem21/2026-01-20/001"
)

# %%
date = session.start_time[:10]
subject = session.subject
number = session.number
pk = session.id
name = session.name
date, subject, number, pk, name
# Out:
# ('2026-01-20',
#  'ihem21',
#  1,
#  'adc46910-91c0-4879-898d-d20627599460',
#  'ihem21/2026-01-20/001')

# %%
connector.remote.rest(
    "datasets",
    "create",
    data={
        # "session_pk":'adc46910-91c0-4879-898d-d20627599460',
        "session": name,
        "date": date,
        "subject": session.subject,
        "number": session.number,
        "dataset_type": "trials.choice",
        "collection": "DELETE_LATER_JUST_A_TEST",
        "data_format": ".txt",
        "set_file_records": [
            {"extra": str(i).zfill(3), "exists": True} for i in range(500)]
    },
)
# Out:
# id                                 54125aff-c72e-4eb0-9131-ba6f45fbb928
# url                   http://127.0.0.1/api/datasets/54125aff-c72e-4e...
# admin_url             /admin/data/dataset/54125aff-c72e-4eb0-9131-ba...
# created_by                                                     tjostmou
# created_datetime                       2026-03-31T23:53:27.986602+02:00
# data_repository                                          Cajal2Interhem
# file_size                                                          None
# version                                                            None
# auto_datetime                          2026-03-31T23:53:27.998150+02:00
# dataset_type                                              trials.choice
# default_dataset                                                    True
# tags                                                                 []
# session                                           ihem21/2026-01-20/001
# data_format                                                        .txt
# data_repository_pk                 ea2cd868-ea54-4f59-a3b3-640130c44891
# data_format_pk                     dd3f05b1-6104-4da7-be68-ffaad1b97651
# revision_pk                                                        None
# dataset_type_pk                    378aa050-4924-4a9b-9fe7-b7cf86dff93f
# session_pk                         adc46910-91c0-4879-898d-d20627599460
# remote_root                                   /cajal_data2/ONE/Interhem
# collection                                     DELETE_LATER_JUST_A_TEST
# revision
# object                                                           trials
# attribute                                                        choice
# extension                                                          .txt
# file_records          [{'id': '8ccf1016-b228-414a-9e08-2324d140b7cc'...
# Name: trials.choice.txt, dtype: object
