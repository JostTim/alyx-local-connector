# %%
from alyx_connector import Connector

connector = Connector()

# %%
ihem17_sessions = connector.remote.rest(endpoint_name="sessions", action="list", subject="ihem17", details=True)
ihem17_sessions
# Out:
#                                                          id subject  \
# name
# ihem17/2025-12-03/001  79907d52-6fea-4aff-9ab4-8a86fde9c258  ihem17
# ihem17/2025-12-19/001  193ed528-d7a4-4d61-9543-9d939d2cfe79  ihem17
# ihem17/2025-12-02/001  92646124-5823-468f-b28e-1692326be552  ihem17
# ihem17/2026-01-16/001  e43634d7-8e49-4c9b-9d43-39071072ff7f  ihem17
#
#                                       start_time  number    projects  \
# name
# ihem17/2025-12-03/001  2025-12-03T12:30:07+01:00       1  [Interhem]
# ihem17/2025-12-19/001  2025-12-19T12:18:59+01:00       1  [Interhem]
# ihem17/2025-12-02/001  2025-12-02T14:52:04+01:00       1  [Interhem]
# ihem17/2026-01-16/001  2026-01-16T13:57:56+01:00       1  [Interhem]
#
#                                       users  \
# name
# ihem17/2025-12-03/001  [basadipo, lpanelat]
# ihem17/2025-12-19/001            [lpanelat]
# ihem17/2025-12-02/001  [basadipo, lpanelat]
# ihem17/2026-01-16/001  [basadipo, lpanelat]
#
# ...

# %%
sessions = connector.remote.search(details=False)
sessions
# Out:
#                                                          id subject  \
# name
# ihem21/2026-01-20/001  adc46910-91c0-4879-898d-d20627599460  ihem21
# ihem18/2026-01-19/001  5a42bf32-6797-4d6a-aae1-013c1da840f1  ihem18
# ihem16/2026-01-19/001  3d12affe-8951-4c7b-ac4d-3ccef2adb568  ihem16
# ihem17/2026-01-16/001  e43634d7-8e49-4c9b-9d43-39071072ff7f  ihem17
# ihem22/2026-01-15/001  3267943b-e778-4381-b3ef-7b49d2d95b06  ihem22
# ...                                                     ...     ...
# wm9/2020-09-23/001     2e8f8e54-4af0-4c6a-9da1-81f3b833ce4b     wm9
# wm9/2020-09-22/001     24cea091-1d51-43c4-8482-78297333aa38     wm9
# wm6/2020-09-22/001     31b2e3d9-c319-4c2a-875c-f31f6456c17b     wm6
# wm9/2020-09-21/001     a5d20b4c-1295-4835-b2de-717c2ca26b61     wm9
# wm6/2020-09-21/001     5c9a9206-c045-4ca9-8b37-3ddc9f3f5eaf     wm6
#
#                                       start_time  number      projects  \
# name
# ...

# %%
subjects = connector.remote.search(endpoint="subjects", subject="wm36")
subjects
# Out:
# Loading /api/subjects/{name} details: 100%|██████████| 59/59 [00:09<00:00,  6.47it/s]
#                                                         id    nickname  \
# name
# HaissLab__dummy       058e3ebf-2d54-451c-99a5-711190b1e3ac       dummy
# HaissLab__bipole3     e303df5e-649e-4bd4-a554-92628cb63d1e     bipole3
# HaissLab__bipole1     08043e27-a0dc-4c15-9462-013ab1c28b03     bipole1
# HaissLab__ea04        b0435f65-6f6d-4c70-9548-a5d7f363b3df        ea04
# HaissLab__ea02        857984bf-ace8-4199-8104-68e90473567c        ea02
# HaissLab__ea01        638e20d3-1d52-4996-a523-c87297082a16        ea01
# HaissLab__ihem03      720b1f23-8b46-4655-8e13-e865fb715396      ihem03
# HaissLab__ea03        8f42996a-a23a-4b78-9d17-81833b0f91c1        ea03
# HaissLab__ihem01      5e58e5d1-2877-4543-8a76-c35c5db51dd6      ihem01
# HaissLab__ihem02      38184d5c-d0d5-4859-9d85-4442b9c58c47      ihem02
# HaissLab__ihem04      a5d50ebe-c9dc-4a93-9a6c-cca2c6a27740      ihem04
# ...

# %%
connector.remote.authenticator.is_authenticated()
# Out:
# True

# %%
connector.remote.search(name="ea04/2024-09-30/001")
# Out:
# id                                           4ac87ea1-f8f6-4ac2-b773-fa87fba11ccc
# subject                                                                      ea04
# users                                                                  [eachirou]
# location                                                                     None
# procedures                                                   [Two photon Imaging]
# lab                                                                      HaissLab
# projects                                                             [MotorSense]
# type                                                                         None
# task_protocol
# number                                                                          1
# start_time                                              2024-09-30T17:50:00+02:00
# end_time                                                2024-09-30T18:20:00+02:00
# ...
