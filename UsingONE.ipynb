# %% [markdown]
# # Database access

# %%
from alyx_connector.client import TokenizedClient, Client, urlparse, urlunparse

# %%
client = TokenizedClient(url="127.0.0.1")
# Out:
# corrected invalid url 127.0.0.1 into http://127.0.0.1 asuming http protocol
# corrected url 127.0.0.1 missing port info into port 80 asuming http protocol is used

# %%
client.path("sessions").make_url(subject="ea04")
# Out:
# 'http://127.0.0.1:80/sessions?subject=ea04'

# %%
client.path("sessions").endpoint.actions["retrieve"].operation.operation_id.split("_")[-1]
# Out:
# 'retrieve'

# %%
client.rest("sessions","retrieve", id = "z")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 client.rest("sessions","retrieve", id = "z")
#
# File ~\Documents\Python\__packages__\ONE\src\alyx_connector\client.py:277, in Client.rest(self, endpoint_name, action, **kwargs)
#     275 def rest(self, endpoint_name: str, action: str, **kwargs):
#     276     endpoint = self.path(endpoint_name).endpoint.assert_exists()
# --> 277     return endpoint.actions[action].request(**kwargs)
#
# File ~\Documents\Python\__packages__\ONE\src\alyx_connector\client.py:353, in Operateur.request(self, data, files, **kwargs)
#     351 except ValueError as e:
#     352     raise ValueError(f"For the {self.action_name} action, " + str(e)) from e
# --> 353 return self.get_response(request_method, url, data=data, files=files)
#
# File ~\Documents\Python\__packages__\ONE\src\alyx_connector\client.py:390, in Operateur.get_response(self, request_method, url, data, files)
#     388 except json.decoder.JSONDecodeError:
#     389     message = r.text
# --> 390 raise requests.HTTPError(r.status_code, url, message, response=r)
#
# HTTPError: [Errno 404] http://127.0.0.1:80/sessions/z: '\n<!doctype html>\n<html lang="en">\n<head>\n  <title>Not Found</title>\n</head>\n<body>\n  <h1>Not Found</h1><p>The requested resource was not found on this server.</p>\n</body>\n</html>\n'

# %%
r = client.path("sessions").endpoint.actions["list"].request(subject="ea04")
r
# Out:
# {'count': 28,
#  'next': None,
#  'previous': None,
#  'results': [{'id': 'f45f19ac-8e00-4f59-8fea-22a9b700bc62',
#    'subject': 'ea04',
#    'start_time': '2024-10-04T17:12:25+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou', 'lpanelat'],
#    'url': 'http://127.0.0.1/sessions/f45f19ac-8e00-4f59-8fea-22a9b700bc62',
#    'admin_url': '/admin/actions/session/f45f19ac-8e00-4f59-8fea-22a9b700bc62/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '3795f49c-716f-4e99-b702-2f39678f0e52',
#    'subject': 'ea04',
#    'start_time': '2024-10-02T16:40:00+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/3795f49c-716f-4e99-b702-2f39678f0e52',
#    'admin_url': '/admin/actions/session/3795f49c-716f-4e99-b702-2f39678f0e52/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '4512f3c7-930a-475f-a68e-3024c3a215cc',
#    'subject': 'ea04',
#    'start_time': '2024-10-01T17:39:45+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/4512f3c7-930a-475f-a68e-3024c3a215cc',
#    'admin_url': '/admin/actions/session/4512f3c7-930a-475f-a68e-3024c3a215cc/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '4ac87ea1-f8f6-4ac2-b773-fa87fba11ccc',
#    'subject': 'ea04',
#    'start_time': '2024-09-30T17:50:00+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/4ac87ea1-f8f6-4ac2-b773-fa87fba11ccc',
#    'admin_url': '/admin/actions/session/4ac87ea1-f8f6-4ac2-b773-fa87fba11ccc/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': 'dd84d249-0f87-452b-a2f9-c558c8a0e07f',
#    'subject': 'ea04',
#    'start_time': '2024-09-27T12:29:04+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/dd84d249-0f87-452b-a2f9-c558c8a0e07f',
#    'admin_url': '/admin/actions/session/dd84d249-0f87-452b-a2f9-c558c8a0e07f/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '80d87f87-670f-4bfb-b9b0-683cd00ad759',
#    'subject': 'ea04',
#    'start_time': '2024-08-07T18:12:15+02:00',
#    'number': 3,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/80d87f87-670f-4bfb-b9b0-683cd00ad759',
#    'admin_url': '/admin/actions/session/80d87f87-670f-4bfb-b9b0-683cd00ad759/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '67727125-769e-4da5-8135-34d47058391b',
#    'subject': 'ea04',
#    'start_time': '2024-08-07T17:16:22+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/67727125-769e-4da5-8135-34d47058391b',
#    'admin_url': '/admin/actions/session/67727125-769e-4da5-8135-34d47058391b/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '6c7378f2-22b4-44ac-afa1-b0b16a4d6f03',
#    'subject': 'ea04',
#    'start_time': '2024-08-06T20:00:22+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/6c7378f2-22b4-44ac-afa1-b0b16a4d6f03',
#    'admin_url': '/admin/actions/session/6c7378f2-22b4-44ac-afa1-b0b16a4d6f03/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '535f801c-3fa9-49f2-97f3-10d181615de7',
#    'subject': 'ea04',
#    'start_time': '2024-08-05T17:30:27+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/535f801c-3fa9-49f2-97f3-10d181615de7',
#    'admin_url': '/admin/actions/session/535f801c-3fa9-49f2-97f3-10d181615de7/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': 'b74f6843-9906-444f-a9c5-172e2682e973',
#    'subject': 'ea04',
#    'start_time': '2024-08-02T20:30:05+02:00',
#    'number': 2,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/b74f6843-9906-444f-a9c5-172e2682e973',
#    'admin_url': '/admin/actions/session/b74f6843-9906-444f-a9c5-172e2682e973/change/',
#    'procedures': ['Two photon Imaging',
#     'Z-stack with Two photon Imaging in live animals'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '6dbea47f-700a-4388-a6a5-b709b4c84660',
#    'subject': 'ea04',
#    'start_time': '2024-08-02T20:00:55+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/6dbea47f-700a-4388-a6a5-b709b4c84660',
#    'admin_url': '/admin/actions/session/6dbea47f-700a-4388-a6a5-b709b4c84660/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '36a59122-9745-423f-9f73-2fe47315d4e0',
#    'subject': 'ea04',
#    'start_time': '2024-08-01T16:02:47+02:00',
#    'number': 2,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/36a59122-9745-423f-9f73-2fe47315d4e0',
#    'admin_url': '/admin/actions/session/36a59122-9745-423f-9f73-2fe47315d4e0/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': 'f8147249-eb29-44e2-98bc-3b510a379285',
#    'subject': 'ea04',
#    'start_time': '2024-08-01T15:06:00+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/f8147249-eb29-44e2-98bc-3b510a379285',
#    'admin_url': '/admin/actions/session/f8147249-eb29-44e2-98bc-3b510a379285/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '02347518-42e9-4512-8461-ec46dd2659e4',
#    'subject': 'ea04',
#    'start_time': '2024-07-30T14:55:01+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/02347518-42e9-4512-8461-ec46dd2659e4',
#    'admin_url': '/admin/actions/session/02347518-42e9-4512-8461-ec46dd2659e4/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': 'e296fc10-b86f-40a4-9f1b-6cd834b9c345',
#    'subject': 'ea04',
#    'start_time': '2024-04-10T20:26:00+02:00',
#    'number': 3,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/e296fc10-b86f-40a4-9f1b-6cd834b9c345',
#    'admin_url': '/admin/actions/session/e296fc10-b86f-40a4-9f1b-6cd834b9c345/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '4665cb9a-644b-4bb2-af79-e1a3531162d3',
#    'subject': 'ea04',
#    'start_time': '2024-04-10T19:48:00+02:00',
#    'number': 2,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/4665cb9a-644b-4bb2-af79-e1a3531162d3',
#    'admin_url': '/admin/actions/session/4665cb9a-644b-4bb2-af79-e1a3531162d3/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '82f31764-fd8a-4218-b25d-ebfa37280bdb',
#    'subject': 'ea04',
#    'start_time': '2024-04-10T18:51:00+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/82f31764-fd8a-4218-b25d-ebfa37280bdb',
#    'admin_url': '/admin/actions/session/82f31764-fd8a-4218-b25d-ebfa37280bdb/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '73bab84f-985d-42a0-9870-21ac0b31388a',
#    'subject': 'ea04',
#    'start_time': '2024-04-09T18:51:10+02:00',
#    'number': 3,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/73bab84f-985d-42a0-9870-21ac0b31388a',
#    'admin_url': '/admin/actions/session/73bab84f-985d-42a0-9870-21ac0b31388a/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '179c1ea4-14c7-4248-86de-bb039fac802f',
#    'subject': 'ea04',
#    'start_time': '2024-04-09T17:51:00+02:00',
#    'number': 2,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/179c1ea4-14c7-4248-86de-bb039fac802f',
#    'admin_url': '/admin/actions/session/179c1ea4-14c7-4248-86de-bb039fac802f/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '0e9c67c5-acb6-4539-8b78-b7139a324818',
#    'subject': 'ea04',
#    'start_time': '2024-04-09T16:40:00+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/0e9c67c5-acb6-4539-8b78-b7139a324818',
#    'admin_url': '/admin/actions/session/0e9c67c5-acb6-4539-8b78-b7139a324818/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '6495d178-69f1-41d2-bf24-a61282b6436c',
#    'subject': 'ea04',
#    'start_time': '2024-04-08T19:14:00+02:00',
#    'number': 2,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/6495d178-69f1-41d2-bf24-a61282b6436c',
#    'admin_url': '/admin/actions/session/6495d178-69f1-41d2-bf24-a61282b6436c/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '2cef269e-5429-43e9-8ae9-a133ea765302',
#    'subject': 'ea04',
#    'start_time': '2024-04-08T18:06:00+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/2cef269e-5429-43e9-8ae9-a133ea765302',
#    'admin_url': '/admin/actions/session/2cef269e-5429-43e9-8ae9-a133ea765302/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': 'bd97af5d-a738-4a61-b389-03f9a12bf0d2',
#    'subject': 'ea04',
#    'start_time': '2024-04-05T18:49:01+02:00',
#    'number': 2,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/bd97af5d-a738-4a61-b389-03f9a12bf0d2',
#    'admin_url': '/admin/actions/session/bd97af5d-a738-4a61-b389-03f9a12bf0d2/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': 'c4b111bb-1ae1-4487-a811-5f35e00b38c2',
#    'subject': 'ea04',
#    'start_time': '2024-04-05T17:47:00+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/c4b111bb-1ae1-4487-a811-5f35e00b38c2',
#    'admin_url': '/admin/actions/session/c4b111bb-1ae1-4487-a811-5f35e00b38c2/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '8cf15c1b-2db2-46a1-bb98-c58c08aee396',
#    'subject': 'ea04',
#    'start_time': '2024-04-04T18:02:00+02:00',
#    'number': 2,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/8cf15c1b-2db2-46a1-bb98-c58c08aee396',
#    'admin_url': '/admin/actions/session/8cf15c1b-2db2-46a1-bb98-c58c08aee396/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '1cae805a-5fd8-4798-ac83-64ac1850f29d',
#    'subject': 'ea04',
#    'start_time': '2024-04-04T17:08:00+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/1cae805a-5fd8-4798-ac83-64ac1850f29d',
#    'admin_url': '/admin/actions/session/1cae805a-5fd8-4798-ac83-64ac1850f29d/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '54e0aa54-3147-4edb-9e5b-6fd8d62b6094',
#    'subject': 'ea04',
#    'start_time': '2024-04-03T18:29:00+02:00',
#    'number': 2,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/54e0aa54-3147-4edb-9e5b-6fd8d62b6094',
#    'admin_url': '/admin/actions/session/54e0aa54-3147-4edb-9e5b-6fd8d62b6094/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'},
#   {'id': '95fd1f97-d636-4425-9d3a-1fb359161d96',
#    'subject': 'ea04',
#    'start_time': '2024-04-03T17:25:00+02:00',
#    'number': 1,
#    'projects': ['MotorSense'],
#    'users': ['eachirou'],
#    'url': 'http://127.0.0.1/sessions/95fd1f97-d636-4425-9d3a-1fb359161d96',
#    'admin_url': '/admin/actions/session/95fd1f97-d636-4425-9d3a-1fb359161d96/change/',
#    'procedures': ['Two photon Imaging'],
#    'default_data_repository': '//cajal/cajal_data2/ONE/MotorSense'}]}

# %%
r = client.rest("sessions","list")
r.ok
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\urllib3\connectionpool.py:495, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     494 try:
# --> 495     conn.request(
#     496         method,
#     497         url,
#     498         body=body,
#     499         headers=headers,
#     500         chunked=chunked,
#     501         preload_content=preload_content,
#     502         decode_content=decode_content,
#     503         enforce_content_length=enforce_content_length,
#     504     )
#     506 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     507 # legitimately able to close the connection after sending a valid response.
#     508 # With this behaviour, the received response is still readable.
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\urllib3\connection.py:441, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     440     self.putheader(header, value)
# --> 441 self.endheaders()
#     443 # If we're given a body we start sending that in chunks.
#
# File C:\Python312\Lib\http\client.py:1314, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1313     raise CannotSendHeader()
# -> 1314 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File C:\Python312\Lib\http\client.py:1074, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1073 del self._buffer[:]
# -> 1074 self.send(msg)
#    1076 if message_body is not None:
#    1077
#    1078     # create a consistent interface to message_body
#
# File C:\Python312\Lib\http\client.py:1018, in HTTPConnection.send(self, data)
#    1017 if self.auto_open:
# -> 1018     self.connect()
#    1019 else:
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\urllib3\connection.py:279, in HTTPConnection.connect(self)
#     278 def connect(self) -> None:
# --> 279     self.sock = self._new_conn()
#     280     if self._tunnel_host:
#     281         # If we're tunneling it means we're connected to our proxy.
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\urllib3\connection.py:214, in HTTPConnection._new_conn(self)
#     213 except OSError as e:
# --> 214     raise NewConnectionError(
#     215         self, f"Failed to establish a new connection: {e}"
#     216     ) from e
#     218 # Audit hooks are only available in Python 3.8+
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000001E1C323D0D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=80): Max retries exceeded with url: /api/schema (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001E1C323D0D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\openapi_parser\resolver.py:36, in OpenAPIResolver.resolve(self)
#      35 logger.debug(f"Resolving specification file")
# ---> 36 self._resolver.parse()
#      37 return self._resolver.specification
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\prance\__init__.py:135, in BaseParser.parse(self)
#     134     encoding = self.options.get("encoding", None)
# --> 135     self.specification = fetch_url(self.url, encoding=encoding, strict=strict)
#     137 # If we have a spec string, try to parse it.
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\prance\util\url.py:240, in fetch_url(url, cache, encoding, strict)
#     239 # Fetch URL text
# --> 240 content, content_type = fetch_url_text(url, cache, encoding=encoding)
#     242 # Parse the result
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\prance\util\url.py:205, in fetch_url_text(url, cache, encoding)
#     203 import requests
# --> 205 response = requests.get(url.geturl())
#     206 if not response.ok:  # pragma: nocover
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)
#      70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\requests\adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='127.0.0.1', port=80): Max retries exceeded with url: /api/schema (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001E1C323D0D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# File ~\Documents\Python\__packages__\ONE\src\alyx_connector\client.py:242, in Client.get_initial_schema(self)
#     241 with temporary_filter_out(logger, "Implicit type assignment: schema does not contain 'type' property"):
# --> 242     schema = parse_openapi_schema(self.url + self.schema_endpoint)
#     243 schema.paths_dict = {path.url: path for path in schema.paths}  # type: ignore
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\openapi_parser\parser.py:128, in parse(uri, spec_string, strict_enum)
#     127 resolver = OpenAPIResolver(uri, spec_string)
# --> 128 specification = resolver.resolve()
#     130 parser = _create_parser(strict_enum=strict_enum)
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\openapi_parser\resolver.py:41, in OpenAPIResolver.resolve(self)
#      40 except Exception as error:
# ---> 41     raise ParserError(f"OpenAPI file parsing error: {error}")
#
# ParserError: OpenAPI file parsing error: HTTPConnectionPool(host='127.0.0.1', port=80): Max retries exceeded with url: /api/schema (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001E1C323D0D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 r = client.rest("sessions","list")
#       2 r.ok
#
# File ~\Documents\Python\__packages__\ONE\src\alyx_connector\client.py:273, in Client.rest(self, endpoint_name, action, **kwargs)
#     272 def rest(self, endpoint_name: str, action: str, **kwargs):
# --> 273     endpoint = self.path(endpoint_name).endpoint.assert_exists()
#     274     return endpoint.actions[action].request(**kwargs)
#
# File ~\Documents\Python\__packages__\ONE\src\alyx_connector\client.py:317, in Endpoint.assert_exists(self)
#     316 def assert_exists(self):
# --> 317     if not self.exists():
#     318         self.raise_not_existing()
#     319     return self
#
# File ~\Documents\Python\__packages__\ONE\src\alyx_connector\client.py:300, in Endpoint.exists(self)
#     299 def exists(self):
# --> 300     return True if self.routes else False
#
# File ~\Documents\Python\__packages__\ONE\src\alyx_connector\client.py:306, in Endpoint.routes(self)
#     304 search_path = self.path.replace("/", r"\/")
#     305 pattern = re.compile(rf"^{search_path}(?:(?=\/{{).*)?$")
# --> 306 return [UrlPath(key, self.client) for key in self.client.schema.paths_dict.keys() if pattern.match(key)]
#
# File ~\Documents\Python\__packages__\ONE\src\alyx_connector\client.py:229, in Client.schema(self)
#     227 if self._schema:
#     228     return self._schema
# --> 229 self._schema = self.get_initial_schema()
#     230 return self._schema
#
# File ~\Documents\Python\__packages__\ONE\src\alyx_connector\client.py:246, in Client.get_initial_schema(self)
#     244     return schema  # type: ignore
#     245 except ParserError:
# --> 246     raise ConnectionError(
#     247         f"Can't connect to {self.url}.\n" + "Check your internet connections and Alyx database firewall"
#     248     )
#
# ConnectionError: Can't connect to http://127.0.0.1:80.
# Check your internet connections and Alyx database firewall

# %%
client.path("sessions").endpoint.actions["update"].describe()
# Out:
# ---------------------------------------------------------------------------
# ResolutionError                           Traceback (most recent call last)
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\openapi_parser\resolver.py:36, in OpenAPIResolver.resolve(self)
#      35 logger.debug(f"Resolving specification file")
# ---> 36 self._resolver.parse()
#      37 return self._resolver.specification
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\prance\__init__.py:135, in BaseParser.parse(self)
#     134     encoding = self.options.get("encoding", None)
# --> 135     self.specification = fetch_url(self.url, encoding=encoding, strict=strict)
#     137 # If we have a spec string, try to parse it.
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\prance\util\url.py:240, in fetch_url(url, cache, encoding, strict)
#     239 # Fetch URL text
# --> 240 content, content_type = fetch_url_text(url, cache, encoding=encoding)
#     242 # Parse the result
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\prance\util\url.py:207, in fetch_url_text(url, cache, encoding)
#     206 if not response.ok:  # pragma: nocover
# --> 207     raise ResolutionError(
#     208         'Cannot fetch URL "%s": %d %s'
#     209         % (url.geturl(), response.status_code, response.reason)
#     210     )
#     211 content_type = response.headers.get("content-type", "text/plain")
#
# ResolutionError: Cannot fetch URL "http://157.99.138.172:80/api/schema": 404 Not Found
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# File ~\Documents\Python\__packages__\ONE\src\alyx_connector\webclient.py:1718, in Client.get_schema(self)
#    1717 with temporary_filter_out(logger, "Implicit type assignment: schema does not contain 'type' property"):
# -> 1718     schema = parse_openapi_schema(self.url + self.schema_endpoint)
#    1719 schema.paths_dict = {path.url: path for path in schema.paths}  # type: ignore
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\openapi_parser\parser.py:128, in parse(uri, spec_string, strict_enum)
#     127 resolver = OpenAPIResolver(uri, spec_string)
# --> 128 specification = resolver.resolve()
#     130 parser = _create_parser(strict_enum=strict_enum)
#
# File c:\Users\tjostmou\Documents\Python\__packages__\ONE\.venv\Lib\site-packages\openapi_parser\resolver.py:41, in OpenAPIResolver.resolve(self)
#      40 except Exception as error:
# ---> 41     raise ParserError(f"OpenAPI file parsing error: {error}")
#
# ParserError: OpenAPI file parsing error: Cannot fetch URL "http://157.99.138.172:80/api/schema": 404 Not Found
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 client.path("sessions").endpoint.actions["update"].describe()
#
# File ~\Documents\Python\__packages__\ONE\src\alyx_connector\webclient.py:1780, in Endpoint.actions(self)
#    1776 @property
#    1777 def actions(self):
#    1778     return {
#    1779         operation.operation_id.split("_")[-1]: Operateur(route, self.client, operation)
# -> 1780         for route in self.routes
#    1781         for operation in self.client.schema.paths_dict[route].operations
#    1782     }
#
# File ~\Documents\Python\__packages__\ONE\src\alyx_connector\webclient.py:1774, in Endpoint.routes(self)
#    1772 search_path = self.path.replace("/", r"\/")
#    1773 pattern = re.compile(rf"^{search_path}(?:(?=\/{{).*)?$")
# -> 1774 return [UrlPath(key, self.client) for key in self.client.schema.paths_dict.keys() if pattern.match(key)]
#
# File ~\Documents\Python\__packages__\ONE\src\alyx_connector\webclient.py:1705, in Client.schema(self)
#    1703 if self._schema:
#    1704     return self._schema
# -> 1705 self._schema = self.get_schema()
#    1706 return self._schema
#
# File ~\Documents\Python\__packages__\ONE\src\alyx_connector\webclient.py:1722, in Client.get_schema(self)
#    1720     return schema  # type: ignore
#    1721 except ParserError:
# -> 1722     raise ConnectionError(
#    1723         f"Can't connect to {self.url}.\n" + "Check your internet connections and Alyx database firewall"
#    1724     )
#
# ConnectionError: Can't connect to http://157.99.138.172:80.
# Check your internet connections and Alyx database firewall

# %%
[ (param.name, param.description, param.required) for param in client.path("subjects").endpoint.actions["list"].operation.parameters ]
# Out:
# [('actual_severity',
#   '* `None` - \n* `1` - Sub-threshold\n* `2` - Mild\n* `3` - Moderate\n* `4` - Severe\n* `5` - Non-recovery',
#   False),
#  ('adverse_effects', None, False),
#  ('alive', None, False),
#  ('birth_date', None, False),
#  ('cage', None, False),
#  ('cull_method', None, False),
#  ('death_date', None, False),
#  ('description', None, False),
#  ('django', None, False),
#  ('ear_mark', None, False),
#  ('genotype', None, False),
#  ('genotype_date', None, False),
#  ('genotype_test', None, False),
#  ('id', None, False),
#  ('implant_weight', None, False),
#  ('lab', None, False),
#  ('limit', 'Number of results to return per page.', False),
#  ('line', None, False),
#  ('litter', None, False),
#  ('name', None, False),
#  ('nickname', None, False),
#  ('offset', 'The initial index from which to return the results.', False),
#  ('project', None, False),
#  ('projects', None, False),
#  ('protocol_number', '* `1` - 1\n* `2` - 2\n* `3` - 3\n* `4` - 4', False),
#  ('reduced', None, False),
#  ('reduced_date', None, False),
#  ('request', None, False),
#  ('responsible_user', None, False),
#  ('sex', '* `M` - Male\n* `F` - Female\n* `U` - Unknown', False),
#  ('source', None, False),
#  ('species', None, False),
#  ('stock', None, False),
#  ('strain', None, False),
#  ('to_be_culled', None, False),
#  ('to_be_genotyped', None, False),
#  ('water_restricted', None, False),
#  ('wean_date', None, False)]

# %%
client.list_endpoints()
# Out:
# ['/auth-token',
#  '/brain-regions',
#  '/brain-regions/{id}',
#  '/cache.zip',
#  '/cache/info/',
#  '/channels',
#  '/channels/{id}',
#  '/data-formats',
#  '/data-formats/{name}',
#  '/data-repository',
#  '/data-repository-type',
#  '/data-repository-type/{name}',
#  '/data-repository/{name}',
#  '/dataset-types',
#  '/dataset-types/{name}',
#  '/datasets',
#  '/datasets/{id}',
#  '/downloads',
#  '/downloads/{id}',
#  '/files',
#  '/files/{id}',
#  '/insertions',
#  '/insertions/{id}',
#  '/labs',
#  '/labs/{name}',
#  '/locations',
#  '/locations/{name}',
#  '/media/{img_url}',
#  '/new-download',
#  '/notes',
#  '/notes/{id}',
#  '/procedures',
#  '/projects',
#  '/projects/{name}',
#  '/register-file',
#  '/revisions',
#  '/revisions/{name}',
#  '/sessions',
#  '/sessions/{id}',
#  '/subjects',
#  '/subjects/{nickname}',
#  '/surgeries',
#  '/sync-file-status',
#  '/tags',
#  '/tags/{id}',
#  '/tasks',
#  '/tasks/{id}',
#  '/trajectories',
#  '/trajectories/{id}',
#  '/users',
#  '/users/{username}',
#  '/water-administrations',
#  '/water-administrations/{id}',
#  '/water-requirement/{nickname}',
#  '/water-restricted-subjects',
#  '/water-restriction',
#  '/water-type',
#  '/water-type/{name}',
#  '/weighings',
#  '/weighings/{id}']

# %%
client.describe("auth-token").actions
# Out:
# {'create': /auth-token - Operation(method=<OperationMethod.POST: 'post'>, responses=[Response(is_default=False, description='', code=200, content=[Content(type=<ContentType.JSON: 'application/json'>, schema=Object(type=<DataType.OBJECT: 'object'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_properties=None, min_properties=None, required=['password', 'token', 'username'], properties=[Property(name='username', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=True, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='password', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=True, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='token', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=True, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None))]), example=None, examples={})], headers=[])], summary=None, description=None, operation_id='auth_token_create', external_docs=None, request_body=RequestBody(content=[Content(type=<ContentType.FORM: 'application/x-www-form-urlencoded'>, schema=Object(type=<DataType.OBJECT: 'object'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_properties=None, min_properties=None, required=['password', 'token', 'username'], properties=[Property(name='username', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=True, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='password', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=True, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='token', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=True, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None))]), example=None, examples={}), Content(type=<ContentType.MULTIPART_FORM: 'multipart/form-data'>, schema=Object(type=<DataType.OBJECT: 'object'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_properties=None, min_properties=None, required=['password', 'token', 'username'], properties=[Property(name='username', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=True, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='password', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=True, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='token', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=True, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None))]), ex ...

# %%
r = client.rest("auth-token","create", data={"password":"lp6GF#","username":"tjostmou"})

# %%
r = client.rest("sessions","list")

# %%
client.netloc
# Out:
# '127.0.0.1:80'

# %%
r.text
# Out:
# '{"detail":"Authentication credentials were not provided.","status_code":403}'

# %%
client.url
# Out:
# '127.0.0.1'

# %%
r.text
# Out:
# '{"token":"3dd2a11095aa34723385744b3dfebe81a40f73ce"}'

# %%
client.list_endpoints()
# Out:
# ['/auth-token',
#  '/brain-regions',
#  '/brain-regions/{id}',
#  '/cache.zip',
#  '/cache/info/',
#  '/channels',
#  '/channels/{id}',
#  '/data-formats',
#  '/data-formats/{name}',
#  '/data-repository',
#  '/data-repository-type',
#  '/data-repository-type/{name}',
#  '/data-repository/{name}',
#  '/dataset-types',
#  '/dataset-types/{name}',
#  '/datasets',
#  '/datasets/{id}',
#  '/downloads',
#  '/downloads/{id}',
#  '/files',
#  '/files/{id}',
#  '/insertions',
#  '/insertions/{id}',
#  '/labs',
#  '/labs/{name}',
#  '/locations',
#  '/locations/{name}',
#  '/media/{img_url}',
#  '/new-download',
#  '/notes',
#  '/notes/{id}',
#  '/procedures',
#  '/projects',
#  '/projects/{name}',
#  '/register-file',
#  '/revisions',
#  '/revisions/{name}',
#  '/sessions',
#  '/sessions/{id}',
#  '/subjects',
#  '/subjects/{nickname}',
#  '/surgeries',
#  '/sync-file-status',
#  '/tags',
#  '/tags/{id}',
#  '/tasks',
#  '/tasks/{id}',
#  '/trajectories',
#  '/trajectories/{id}',
#  '/users',
#  '/users/{username}',
#  '/water-administrations',
#  '/water-administrations/{id}',
#  '/water-requirement/{nickname}',
#  '/water-restricted-subjects',
#  '/water-restriction',
#  '/water-type',
#  '/water-type/{name}',
#  '/weighings',
#  '/weighings/{id}']

# %% [markdown]
# ## First access

# %%
one.ONE(base_url = "http://157.99.138.172:80")
# Out:
# One (online, http://157.99.138.172:80)

# %% [markdown]
# ## In case of first setup problems :
# Can occur at setup or at first requet to the database (.rest folder was not created correctly)
# Check the file that keeps your logins :
# ### on linux :
# "/home/<user>/.one/.cache"
# and
# "/home/<user>/.one/.\<IP>_\<PORT>"
#
# ### On windows :
# "C:\Users\\<user\>\AppData\Roaming\.one\.cache"
# etc..
#
# The content should be similar to :

# %% [markdown]
# ## Accessing sessions

# %%
connector = one.ONE(mode = 'remote')
sessions = connector.search(subject = "dummy", details = True) # when setting details = True we get a dataframe with rows : sessions, columns : metadata fields
session = sessions.iloc[0] # we take the first session of the dataframe

# %% [markdown]
# ## Accessing data

# %%
files = connector.list_datasets(session.name, object = "trials", attribute = "event*" , extension = ".tdms")
files
# Out:
# ['D:\\LOCAL_DATA\\dummy\\2023-06-19\\001\\trials.eventTimeline.tdms']

# %%
file_records = connector.list_datasets(session.name, object = "trials", attribute = "event*" , extension = ".tdms" , details = True)
import pandas as pd
with pd.option_context('display.max_columns', 10000):
    display(file_records)
# Out:
#                                                                                                                                  relative_path
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  dummy/2023-06-19/001/trials.eventTimeline.tdms  \
#
#                                                                                                extra
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e        \
#
#                                                                                                 exists
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e    True  \
#
#                                                                                                                 file_name
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  trials.eventTimeline.tdms  \
#
#                                                                                                 hash
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  None  \
#
#                                                                                                                                  remote_full_path
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  \\cajal\cajal_data2\ONE\Dummy\dummy\2023-06-19...  \
#
#                                                                                                                                   local_full_path
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  D:\LOCAL_DATA\dummy\2023-06-19\001\trials.even...  \
#
#                                                                                                                                         full_path
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  D:\LOCAL_DATA\dummy\2023-06-19\001\trials.even...  \
#
#                                                                                                                      name
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  trials.eventTimeline.tdms  \
#
#                                                                                                created_by
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e       None  \
#
#                                                                                                           created_datetime
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  2023-06-19T15:47:51.830446  \
#
#                                                                                                data_repository
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e     Cajal2Dummy  \
#
#                                                                                                file_size
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e      None  \
#
#                                                                                                version
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e    None  \
#
#                                                                                                              auto_datetime
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  2023-06-19T15:51:30.386068  \
#
#                                                                                                         dataset_type
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  trials.eventTimeline  \
#
#                                                                                                 default_dataset
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e             True  \
#
#                                                                                                tags
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e   []  \
#
#                                                                                                                   data_repository_pk
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  30c973e7-bd87-444e-99c1-91ff6c58875a  \
#
#                                                                                                                       data_format_pk
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  47bcdd69-8754-4045-ba05-0b59c9dba75b  \
#
#                                                                                                revision_pk
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e        None  \
#
#                                                                                                                      dataset_type_pk
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  d130f5fe-42ae-4e4f-9664-1657e811cc89  \
#
#                                                                                                                           session_pk
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  e884d57a-611a-40c1-a46f-73586e00a26d  \
#
#                                                                                                                   remote_root
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  //cajal/cajal_data2/ONE/Dummy  \
#
#                                                                                                subject
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e   dummy  \
#
#                                                                                                       date
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  2023-06-19  \
#
#                                                                                                 number
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e       1  \
#
#                                                                                                collection
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e             \
#
#                                                                                                revision
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e           \
#
#                                                                                                 object
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  trials  \
#
#                                                                                                     attribute
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  eventTimeline  \
#
#                                                                                                extension
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e     .tdms  \
#
#                                                                                                                                       dataset_url
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  http://157.99.138.172/datasets/9dd2486e-037e-4...  \
#
#                                                                                                                                 dataset_admin_url
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  http://157.99.138.172:80/admin/data/dataset/9d...  \
#
#                                                                                                    local_root
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  D:\LOCAL_DATA

# %% [markdown]
# ## Dataset creation process
# When wanting to create new file entries, we need to suppli all the informations here :
# path :  remote_root/subject/date/number/(collection)/(revision)/object.attribute.(extra).extension
# The parts of the path in parentehesis are optionnal and can be blank. All the rest MUST be filled.
#
# The different parts of a file come from different locations of the database models : (this is named the **alf standard**)
#
#  - remote_root : Comes from a data_repository.
#      We will supply the information with the name of a data_repository (use data_repository key in data) or a primary key (use data_repository_pk key in data)
#
#  - subject : All three below come from a session. Simply supply a session primary key with session_pk key in data.
#              To obtain a session pk from a human readable session alias string, use one.to_eid(alias) (ex : alias can be 'dummy/2023-06-19/001')
#  - date :    '' Same as above
#  - number :  '' Same as above
#
#
#  - collection : Can be either "" (cannot be None anymore after changes in the model, for path construction simplicity sake) or "whateverfolder". Can chain folders like so : "whatevertoplevel/whateversub"
#  - revision : Need to supply a primary key with revision_pk. This requires you to first create a revision for the dataset.
#              For now this is not in use so we can keep wonderings about that for later.
#              (but still try as possible to not write code conflicting with this functionnality as it will probably be very usefull at some point anytime soon)
#
#  - object :    The two object and attribute parameters are set by specifying a dataset_type. This can be either a dataset_type name (using dataset_type key) or a dataset_type pk (using dataset_type_pk)
#  - attribute : Same as above. Note that if specifying a dataset_type name, it should be constructed as such : '\<object>.\<attribute>' in a string
#  - extra :     This will be supplied at the level of the file (a dataset can contain 0 to infinite files and is a "group" of files of the same content type). It will be defined later (in the firerecord creating process)
#  - extension : This is defined by the "data_format" model. It is basically a collection of file extensions and the general expectation of the content that we have with that extensions. Can be set either using the extension name (the extension string without the leading dot, using data_format) or a data_format primary key (using data_format_pk)

# %%
session.name
# Out:
# 'e884d57a-611a-40c1-a46f-73586e00a26d'

# %%
## Example :

data = {"session_pk": session.name,
        "data_format" : ".tdms",
        "dataset_type" : "trials.feedbackType",
        "data_repository_pk" : "05baa8e4-5eb5-4214-a008-c9e5331004b0",
        "collection" : "mycollection"
       }

dataset = connector.alyx.rest("datasets","create", data=data )
dataset
# Out:
# {'id': '1acc46fb-2bf5-4280-b67d-8ff7c6974f57',
#  'url': 'http://157.99.138.172/datasets/1acc46fb-2bf5-4280-b67d-8ff7c6974f57',
#  'admin_url': 'http://157.99.138.172:80/admin/data/dataset/1acc46fb-2bf5-4280-b67d-8ff7c6974f57/change',
#  'name': 'trials.feedbackType.tdms',
#  'created_by': 'tjostmou',
#  'created_datetime': '2023-06-20T22:33:41.058908',
#  'data_repository': 'Cajal2Adaptation',
#  'file_size': None,
#  'version': None,
#  'auto_datetime': '2023-06-20T22:33:41.061863',
#  'dataset_type': 'trials.feedbackType',
#  'default_dataset': True,
#  'tags': [],
#  'session': 'dummy_2023-06-19_001',
#  'data_format': '.tdms',
#  'data_repository_pk': '05baa8e4-5eb5-4214-a008-c9e5331004b0',
#  'data_format_pk': '47bcdd69-8754-4045-ba05-0b59c9dba75b',
#  'revision_pk': None,
#  'dataset_type_pk': '2a9092b0-c9fc-4740-bb43-28b254e3386e',
#  'session_pk': 'e884d57a-611a-40c1-a46f-73586e00a26d',
#  'remote_root': '//cajal/cajal_data2/ONE/Adaptation',
#  'subject': 'dummy',
#  'date': '2023-06-19',
#  'number': 1,
#  'collection': 'mycollection',
#  'revision': '',
#  'object': 'trials',
#  'attribute': 'feedbackType',
#  'extension': '.tdms',
#  'file_records': []}

# %% [markdown]
# ## Accessing an already existing dataset to add files to it :

# %%
## Example :
# Dataset already existing is :
dataset_params = {"dataset_type" : "trials.feedbackType" , "collection" : "mycollection"}

#search for infos of the session where the dataset exists :
session_dict = connector.alyx.rest("sessions","read", id = session.name , no_cache = True)

#get the matching dataset infos :
for dataset in session_dict["data_dataset_session_related"] :
    dataset_check = {key: dataset[key] for key in dataset_params.keys() if key in dataset}
    comparisons = [ dataset_check[key] == dataset_params[key] for key in dataset_check.keys() ]
    if all(comparisons):
        break
dataset
# Out:
# {'id': '1acc46fb-2bf5-4280-b67d-8ff7c6974f57',
#  'url': 'http://157.99.138.172/datasets/1acc46fb-2bf5-4280-b67d-8ff7c6974f57',
#  'admin_url': 'http://157.99.138.172:80/admin/data/dataset/1acc46fb-2bf5-4280-b67d-8ff7c6974f57/change',
#  'name': 'trials.feedbackType.tdms',
#  'created_by': 'tjostmou',
#  'created_datetime': '2023-06-20T22:33:41.058908',
#  'data_repository': 'Cajal2Adaptation',
#  'file_size': None,
#  'version': None,
#  'auto_datetime': '2023-06-20T22:33:41.061863',
#  'dataset_type': 'trials.feedbackType',
#  'default_dataset': True,
#  'tags': [],
#  'session': 'dummy_2023-06-19_001',
#  'data_format': '.tdms',
#  'data_repository_pk': '05baa8e4-5eb5-4214-a008-c9e5331004b0',
#  'data_format_pk': '47bcdd69-8754-4045-ba05-0b59c9dba75b',
#  'revision_pk': None,
#  'dataset_type_pk': '2a9092b0-c9fc-4740-bb43-28b254e3386e',
#  'session_pk': 'e884d57a-611a-40c1-a46f-73586e00a26d',
#  'remote_root': '//cajal/cajal_data2/ONE/Adaptation',
#  'subject': 'dummy',
#  'date': '2023-06-19',
#  'number': 1,
#  'collection': 'mycollection',
#  'revision': '',
#  'object': 'trials',
#  'attribute': 'feedbackType',
#  'extension': '.tdms',
#  'file_records': []}

# %% [markdown]
# # File records creation process
# We now only have the extra left to fill to have a complete file path recreateable (and easily searchable using individual components):
#
#  - extra :     This will be supplied at the level of the file (a dataset can contain 0 to infinite files and is a "group" of files of the same content type). It will be defined later (in the firerecord creating process)

# %%
data = {"dataset" : dataset["id"],
        "exist" : False, #this is a dummy file so i profit from this to set exist = False as normaly no file should be there. Set it to true if a real file is at the location there.
        "extra" : "00002"} # let's say this is file 000001 because there is one file per trial. Extra serves in that case. If you wan to have several extra parameters to differentiate : 
        # "extra" : "red.000001" also works. Simply split individual elemnts with dots. No trailing or leading dot (but the database should anyway clean those at save time if i did my job right)


file_record = connector.alyx.rest("files","create", data = data)

# %% [markdown]
# # 'Testing' file recomposition from dataset and file_record :
# The database will do it's job at patching elements together so that each file record have a calculated (and saved) field relative_path that will be the path of the file except the root.
# (all elements above up to subject)
# The root can be either the remote_root supplied by the database or a local root obtained within the one instance (that have been chosen at setup time).
#
# But if you anyway want to recompose a file with the elements themselves, you can do so with the function one.alf.spec.to_full_path  that takes as keyword arguments all parts
# described above in the **alf standard**.

# %%
import Inflow, one
# inflow is just the general purpose package i developped for the lab : install here is necessary : 
# pip install git+https://gitlab.pasteur.fr/haisslab/analysis-packages/Inflow.git@pre-releases

# %%
merge = file_record
merge.update(dataset)

Inflow.decorators.filter_kwargs( one.alf.spec.to_full_path )(**merge, root = merge["remote_root"])
# Out:
# '\\\\cajal\\cajal_data2\\ONE\\Adaptation\\dummy\\2023-06-19\\001\\mycollection\\trials.feedbackType.00002.tdms'

# %% [markdown]
# You can indeed also supply the mapping from the panda series obtained with the connector.list_datasets method (only when specifying details=True otherwise it direclty returns a list of file paths using current data_acces_mode to determine if it should use local or remote root)

# %%
file_records = connector.list_datasets(session.name, object = "trials", attribute = "event*" , extension = ".tdms" , details = True)
import pandas as pd
with pd.option_context('display.max_columns', 10000):
    display(file_records)
# Out:
#                                                                                                                                  relative_path
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  dummy/2023-06-19/001/trials.eventTimeline.tdms  \
#
#                                                                                                extra
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e        \
#
#                                                                                                 exists
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e    True  \
#
#                                                                                                                 file_name
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  trials.eventTimeline.tdms  \
#
#                                                                                                 hash
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  None  \
#
#                                                                                                                                  remote_full_path
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  \\cajal\cajal_data2\ONE\Dummy\dummy\2023-06-19...  \
#
#                                                                                                                                   local_full_path
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  D:\LOCAL_DATA\dummy\2023-06-19\001\trials.even...  \
#
#                                                                                                                                         full_path
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  D:\LOCAL_DATA\dummy\2023-06-19\001\trials.even...  \
#
#                                                                                                                      name
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  trials.eventTimeline.tdms  \
#
#                                                                                                created_by
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e       None  \
#
#                                                                                                           created_datetime
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  2023-06-19T15:47:51.830446  \
#
#                                                                                                data_repository
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e     Cajal2Dummy  \
#
#                                                                                                file_size
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e      None  \
#
#                                                                                                version
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e    None  \
#
#                                                                                                              auto_datetime
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  2023-06-19T15:51:30.386068  \
#
#                                                                                                         dataset_type
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  trials.eventTimeline  \
#
#                                                                                                 default_dataset
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e             True  \
#
#                                                                                                tags
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e   []  \
#
#                                                                                                data_format
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e       .tdms  \
#
#                                                                                                                   data_repository_pk
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  30c973e7-bd87-444e-99c1-91ff6c58875a  \
#
#                                                                                                                       data_format_pk
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  47bcdd69-8754-4045-ba05-0b59c9dba75b  \
#
#                                                                                                revision_pk
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e        None  \
#
#                                                                                                                      dataset_type_pk
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  d130f5fe-42ae-4e4f-9664-1657e811cc89  \
#
#                                                                                                                           session_pk
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  e884d57a-611a-40c1-a46f-73586e00a26d  \
#
#                                                                                                                   remote_root
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  //cajal/cajal_data2/ONE/Dummy  \
#
#                                                                                                subject
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e   dummy  \
#
#                                                                                                       date
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  2023-06-19  \
#
#                                                                                                 number
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e       1  \
#
#                                                                                                collection
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e             \
#
#                                                                                                revision
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e           \
#
#                                                                                                 object
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  trials  \
#
#                                                                                                     attribute
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  eventTimeline  \
#
#                                                                                                extension
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e     .tdms  \
#
#                                                                                                                                       dataset_url
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  http://157.99.138.172/datasets/9dd2486e-037e-4...  \
#
#                                                                                                                                 dataset_admin_url
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  http://157.99.138.172:80/admin/data/dataset/9d...  \
#
#                                                                                                    local_root
# session#             dataset#                             file#
# dummy_2023-06-19_001 9dd2486e-037e-45ba-9ffc-f1c9cef67282 48ba412e-4bd0-4721-b17d-16506389695e  D:\LOCAL_DATA

# %%
# The relative path or full_path can be reconstructed easily only by supplying a mapping of all the components of a path to the one.alf.spec.to_full_path function.
#Note that for the example here i created a data repository named Calaj2Dummy with a Dummmy folder, and the mouse is also named dummy so there is a repetition of dummies. This is expected.
Inflow.decorators.filter_kwargs( one.alf.spec.to_full_path )(**file_records.iloc[0], root = file_records.iloc[0]["remote_root"])
# Out:
# '\\\\cajal\\cajal_data2\\ONE\\Dummy\\dummy\\2023-06-19\\001\\trials.eventTimeline.tdms'

# %% [markdown]
# # Local vs Remote data access
#
# If you want to access downloaded data from the local repository you set at the begining of the One setup, just paste the files there (with folders architecture kept starting at `subject`)
# Just set the `data_access_mode` to "remote" or "local" with `.set_data_access_mode("remote")`
# At start, the mode is local by default. It can be changed by writing : `one.ONE(data_access_mode = "remote")`
#
# You can also use a specific mode momentarily with the keyword argument : `as_mode` in `list_datasets` and `search` to specify `session.path` or `filerecords.full_path` to be build from either the local or remote versions of the paths.
# Whatever the choice, you will always have `session.local_path` and `session.remote_path` fields available, and `filerecords.local_full_path` and `filerecords.remote_full_path` available.
#
# ⚠️
# The `mode` parameter of one existed before I introduced local and remote paths. It also can be either of value "local" and "remote" but this time it doesn't refer to how file paths are constructed. It refers to how the rest queries are executed. The One class is a child of a One class that is local and use cache tables to query data. Sadly, it doesn't work great, but something that works great is no_cache argument. If you want to refresh values from the "remote", simply set this no_cache argument to True.

# %%
session.local_root
# Out:
# 'D:\\LOCAL_DATA'
