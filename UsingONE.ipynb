# %% [markdown]
# # Database access

# %%
from alyx_connector import Connector
# connector = Connector(url="haiss-alyx-dev")
connector = Connector(url="127.0.0.1")

# %%
connector.web_client.endpoint("sessions").actions["list"].operation.parameters
# Out:
# [Parameter(name='atlas_acronym', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='atlas_id', location=<ParameterLocation.QUERY: 'query'>, schema=Number(type=<DataType.NUMBER: 'number'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, multiple_of=None, maximum=None, exclusive_maximum=None, minimum=None, exclusive_minimum=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='atlas_name', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='attribute', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='auto_datetime', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=<StringFormat.DATETIME: 'date-time'>), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='data_repository', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='dataset_types', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='date_range', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='default_data_repository', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='django', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='end_time', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=<StringFormat.DATETIME: 'date-time'>), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='exclude_procedures', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='extended_qc', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='histology', location=<ParameterLocation.QUERY: 'query'>, schema=Boolean(type=<DataType.BOOLEAN: 'boolean'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='id', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=<StringFormat.UUID: 'uuid'>), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='json', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='lab', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='limit', location=<ParameterLocation.QUERY: 'query'>, schema=Integer(type=<DataType.INTEGER: 'integer'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, multiple_of=None, maximum=None, exclusive_maximum=None, minimum=None, exclusive_minimum=None, format=None), content=None, required=False, description='Number of results to return per page.', deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='location', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='n_correct_trials', location=<ParameterLocation.QUERY: 'query'>, schema=Integer(type=<DataType.INTEGER: 'integer'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, multiple_of=None, maximum=None, exclusive_maximum=None, minimum=None, exclusive_minimum=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='n_trials', location=<ParameterLocation.QUERY: 'query'>, schema=Integer(type=<DataType.INTEGER: 'integer'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, multiple_of=None, maximum=None, exclusive_maximum=None, minimum=None, exclusive_minimum=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='name', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='narrative', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='number', location=<ParameterLocation.QUERY: 'query'>, schema=Integer(type=<DataType.INTEGER: 'integer'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, multiple_of=None, maximum=None, exclusive_maximum=None, minimum=None, exclusive_minimum=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='object', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='offset', location=<ParameterLocation.QUERY: 'query'>, schema=Integer(type=<DataType.INTEGER: 'integer'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, multiple_of=None, maximum=None, exclusive_maximum=None, minimum=None, exclusive_minimum=None, format=None), content=None, required=False, description='The initial index from which to return the results.', deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='parent_session', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=<StringFormat.UUID: 'uuid'>), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='performance_gte', location=<ParameterLocation.QUERY: 'query'>, schema=Number(type=<DataType.NUMBER: 'number'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, multiple_of=None, maximum=None, exclusive_maximum=None, minimum=None, exclusive_minimum=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='performance_lte', location=<ParameterLocation.QUERY: 'query'>, schema=Number(type=<DataType.NUMBER: 'number'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, multiple_of=None, maximum=None, exclusive_maximum=None, minimum=None, exclusive_minimum=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='procedures', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='project', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='projects', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='qc', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='start_time', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=<StringFormat.DATETIME: 'date-time'>), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='subject', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='tag', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='task_protocol', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='type', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={}),
#  Parameter(name='users', location=<ParameterLocation.QUERY: 'query'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=False, description=None, deprecated=False, style=<QueryParameterStyle.FORM: 'form'>, explode=True, extensions={})]

# %%
sessions = connector.search(subject = "ea04", start_time = "2025-11-01")

# %%
sessions = connector.search(subject = "ea04")
# Out:
# Loading sessions details: 100%|██████████| 30/30 [00:03<00:00,  8.11it/s]

# %%
connector.web_client.create(endpoint="sessions", data={"users":["wilsonmena"], "subject":"ea04", "start_time":"2025-11-01","number":1})
# Out:
# {'id': 'b7ae0fae-6831-4018-9455-2d72181bb77f',
#  'subject': 'ea04',
#  'users': ['wilsonmena'],
#  'location': None,
#  'procedures': [],
#  'lab': 'HaissLab',
#  'projects': [],
#  'type': None,
#  'task_protocol': '',
#  'number': 1,
#  'start_time': '2025-11-01T00:00:00+01:00',
#  'end_time': None,
#  'narrative': '',
#  'parent_session': None,
#  'n_correct_trials': None,
#  'n_trials': None,
#  'url': 'http://127.0.0.1/sessions/b7ae0fae-6831-4018-9455-2d72181bb77f',
#  'extended_qc': None,
#  'qc': 'NOT_SET',
#  'wateradmin_session_related': [],
#  'data_dataset_session_related': [],
#  'auto_datetime': '2025-04-28T08:36:04.693721+02:00',
#  'alias': 'ea04/2025-11-01/001',
#  'u_alias': 'ea04_2025-11-01_001',
#  'path': '//157.99.138.167/cajal_data2/ONE/MotorSense/ea04/2025-11-01/001',
#  'json': None,
#  'probe_insertion': [],
#  'notes': [],
#  'default_data_repository_path': '//157.99.138.167/cajal_data2/ONE/MotorSense',
#  'default_data_repository_name': 'Cajal2MotorSense',
#  'default_data_repository_pk': '70a43e0f-09b3-4c0f-996c-12edbdaff06d',
#  'rel_path': 'ea04/2025-11-01/001',
#  'admin_url': '/admin/actions/session/b7ae0fae-6831-4018-9455-2d72181bb77f/change/'}

# %%
session = connector.search(date_range = ["2025-11-01","2025-11-02"], subject = "ea04")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 session = connector.search(date_range = ["2025-11-01","2025-11-02"], subject = "ea04")
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\connector\core.py:70, in Connector.search(self, endpoint, details, raises, **kwargs)
#      69 def search(self, endpoint="sessions", details=True, raises=True, **kwargs):
# ---> 70     search_result = self.web_client.search(endpoint=endpoint, details=details, **kwargs)
#      71     if raises:
#      72         search_result = self.raise_if_search_empty(search_result)
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\clients.py:145, in Client.search(self, endpoint, details, **kwargs)
#     138 if "id" in kwargs.keys() or "name" in kwargs.keys():
#     139     # just in case, we warn the user if she/he supplied id or name, and the endpoint doesn't implement retrieve
#     140     logger.warning(
#     141         f"Endpoint {endpoint} does not implement retrieve. "
#     142         "You specified id or name but it will not work to select a specific item. Listing instead"
#     143     )
# --> 145 return self.list(endpoint=endpoint, details=details, **kwargs)
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\clients.py:176, in Client.list(self, endpoint, details, **kwargs)
#     175 def list(self, *, endpoint: str, details=True, **kwargs):
# --> 176     results = self.rest(endpoint, "list", **kwargs)
#     177     results = [] if not results else results
#     178     return self.details_aggregation(results, endpoint) if details else results
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\clients.py:99, in Client.rest(self, endpoint_name, action, timeout, **kwargs)
#      91 def rest(
#      92     self,
#      93     endpoint_name: str,
#    (...)     96     **kwargs,
#      97 ):
#      98     operateur = self.path(endpoint_name).endpoint.assert_exists().actions[action]
# ---> 99     return Request(self, operateur, timeout=timeout, **kwargs).handle()
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:322, in Request.handle(self)
#     321 def handle(self):
# --> 322     return self.handle_response(self.get_response())
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:355, in Request.handle_response(self, response)
#     353     return None
#     354 else:
# --> 355     self.raise_from_response(response)
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:366, in Request.raise_from_response(self, response)
#     364 except json.decoder.JSONDecodeError:
#     365     message = response.text
# --> 366 raise requests.HTTPError(response.status_code, self.url, message, response=response)
#
# HTTPError: [Errno 500] http://127.0.0.1:80/sessions?date_range=%5B%272025-11-01%27%2C+%272025-11-02%27%5D&subject=ea04: '["“[\'2025-11-01\'” value has an invalid date format. It must be in YYYY-MM-DD format."]'

# %%
sessions = connector.search(subject = "ea03")

# %%
from alyx_connector.files.registration.rules_config import Config
config = Config()

# %%
session = sessions.iloc[-1]
session
# Out:
# id                                           95fd1f97-d636-4425-9d3a-1fb359161d96
# subject                                                                      ea04
# users                                                                  [eachirou]
# location                                                                     None
# procedures                                                   [Two photon Imaging]
# lab                                                                      HaissLab
# projects                                                             [MotorSense]
# type                                                                         None
# task_protocol
# number                                                                          1
# start_time                                              2024-04-03T17:25:00+02:00
# end_time                                                2024-04-03T18:06:00+02:00
# narrative                       stims :\r\n- C2 : right\r\n- nothing : left\r\...
# parent_session                                                               None
# n_correct_trials                                                             None
# n_trials                                                                     None
# url                             http://127.0.0.1/sessions/95fd1f97-d636-4425-9...
# extended_qc                                                                  None
# qc                                                                        NOT_SET
# wateradmin_session_related                                                     []
# data_dataset_session_related                                                   []
# auto_datetime                                    2024-04-03T19:41:41.429420+02:00
# alias                                                         ea04/2024-04-03/001
# u_alias                                                       ea04_2024-04-03_001
# path                            //157.99.138.167/cajal_data2/ONE/MotorSense/ea...
# json                            {'whisker_stims': {'Stimulus right': {'0': 'No...
# probe_insertion                                                                []
# notes                                                                          []
# default_data_repository_path          //157.99.138.167/cajal_data2/ONE/MotorSense
# default_data_repository_name                                     Cajal2MotorSense
# default_data_repository_pk                   70a43e0f-09b3-4c0f-996c-12edbdaff06d
# rel_path                                                      ea04/2024-04-03/001
# admin_url                       /admin/actions/session/95fd1f97-d636-4425-9d3a...
# Name: 29, dtype: object

# %%
file_records = config.evaluate_session(session)

# %%
from alyx_connector.files.parsing import File
File(r"\\157.99.138.167\cajal_data2\ONE\MotorSense\ea04\2024-04-03\001\behaviour_imaging\whiskers\0.tdms")
# Out:
#         <div class="table-container">
#             <table>
#                 <thead>
#                     <th class="title" colspan="10">File :</th>
#                 </thead>
#                 <thead class="head">
#                     <tr>
#                         <th>root</th>
#                         <th>subject</th>
#                         <th>date</th>
#                         <th>number</th>
#                         <th>collection</th>
#                         <th>revision</th>
#                         <th>object</th>
#                         <th>attribute</th>
#                         <th>extra</th>
#                         <th>extension</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr>
#                         <td>\\157.99.138.167\cajal_data2\ONE\MotorSense</td>
#                         <td>ea04</td>
#                         <td>2024-04-03</td>
#                         <td>001</td>
#                         <td>behaviour_imaging\whiskers</td>
#                         <td></td>
#                         <td>0</td>
#                         <td></td>
#                         <td></td>
#                         <td>tdms</td>
#                     </tr>
#                 </tbody>
#             </table>
#         </div>
#         <style>
#             .table-container{
#                 border: 1px solid rgb(173, 173, 173);
#                 border-radius: 5px;
#                 overflow: hidden;
#                 display: inline-block;
#             }
#             .title{
#                 text-align: left;
#                 white-space: pre;
#                 font-weight: bolder;
#             }
#             table {
#                 font-family: consolas;
#                 border-collapse: collapse;
#             }
#             th, td {
#                 border: 1px solid rgb(160 160 160);
#             }
#             thead:first-of-type th {
#                 border-top: none;
#             }
#             td {
#                 border-bottom: 0px;
#             }
#             th:first-of-type, td:first-of-type {
#                 border-left: none;
#             }
#             td:last-of-type, th:last-of-type {
#                 border-right: none;
#             }
#             thead > tr > th:hover, tbody > tr > td:hover{
#                 background-color: rgba(111, 110, 160, 0.267);
#             }
#         </style>

# %%
file_records.records[0].destination_file["attribute"] = "fesse"

# %%
file_records.records[0].destination_file._attribute = "fesse"

# %%
file_records.records[0].destination_file
# Out:
#         <div class="table-container">
#             <table>
#                 <thead>
#                     <th class="title" colspan="10">File :</th>
#                 </thead>
#                 <thead class="head">
#                     <tr>
#                         <th>root</th>
#                         <th>subject</th>
#                         <th>date</th>
#                         <th>number</th>
#                         <th>collection</th>
#                         <th>revision</th>
#                         <th>object</th>
#                         <th>attribute</th>
#                         <th>extra</th>
#                         <th>extension</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr>
#                         <td>\\157.99.138.167\cajal_data2\ONE\MotorSense</td>
#                         <td>ea04</td>
#                         <td>2024-04-03</td>
#                         <td>001</td>
#                         <td>behaviour_imaging\whiskers</td>
#                         <td></td>
#                         <td>behaviour</td>
#                         <td>fesse</td>
#                         <td>whiskers.00000</td>
#                         <td>tdms</td>
#                     </tr>
#                 </tbody>
#             </table>
#         </div>
#         <style>
#             .table-container{
#                 border: 1px solid rgb(173, 173, 173);
#                 border-radius: 5px;
#                 overflow: hidden;
#                 display: inline-block;
#             }
#             .title{
#                 text-align: left;
#                 white-space: pre;
#                 font-weight: bolder;
#             }
#             table {
#                 font-family: consolas;
#                 border-collapse: collapse;
#             }
#             th, td {
#                 border: 1px solid rgb(160 160 160);
#             }
#             thead:first-of-type th {
#                 border-top: none;
#             }
#             td {
#                 border-bottom: 0px;
#             }
#             th:first-of-type, td:first-of-type {
#                 border-left: none;
#             }
#             td:last-of-type, th:last-of-type {
#                 border-right: none;
#             }
#             thead > tr > th:hover, tbody > tr > td:hover{
#                 background-color: rgba(111, 110, 160, 0.267);
#             }
#         </style>

# %%
df = file_records.to_dataframe()
# df[df["abort"]==False]
df
# Out:
#                                            source_path  match  \
# 0    \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...   True
# 1    \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...   True
# 2    \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...   True
# 3    \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...   True
# 4    \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...   True
# ..                                                 ...    ...
# 617  \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...   True
# 618  \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...  False
# 619  \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...  False
# 620  \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...  False
# 621  \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...  False
#
#                 matching_rules                 used_rule  valid_alf  \
# 0    [behavior_whiskers_rule1]  behavior_whiskers_rule1        True
# 1    [behavior_whiskers_rule1]  behavior_whiskers_rule1        True
# 2    [behavior_whiskers_rule1]  behavior_whiskers_rule1        True
# 3    [behavior_whiskers_rule1]  behavior_whiskers_rule1        True
# 4    [behavior_whiskers_rule1]  behavior_whiskers_rule1        True
# ..                         ...                       ...        ...
# 617       [imaging_data_rule1]       imaging_data_rule1        True
# 618                         []                                False
# 619                         []                                False
# 620                         []                                False
# 621                         []                                False
#
#      path_conflicts  dataset_type_exists  rename  delete  include abort  \
# 0             False                 True    True   False     True    []
# 1             False                 True    True   False     True    []
# 2             False                 True    True   False     True    []
# 3             False                 True    True   False     True    []
# 4             False                 True    True   False     True    []
# ..              ...                  ...     ...     ...      ...   ...
# 617           False                 True    True   False     True    []
# 618           False                False   False   False    False    []
# 619           False                False   False   False    False    []
# 620           False                False   False   False    False    []
# 621           False                False   False   False    False    []
#
#                                      executed_actions  \
# 0    [match -> rename, rename_successfull -> include]
# 1    [match -> rename, rename_successfull -> include]
# 2    [match -> rename, rename_successfull -> include]
# 3    [match -> rename, rename_successfull -> include]
# 4    [match -> rename, rename_successfull -> include]
# ..                                                ...
# 617  [match -> rename, rename_successfull -> include]
# 618                                                []
# 619                                                []
# 620                                                []
# 621                                                []
#
#                                           _source_file  \
# 0    <alyx_connector.files.parsing.files.File objec...
# 1    <alyx_connector.files.parsing.files.File objec...
# 2    <alyx_connector.files.parsing.files.File objec...
# 3    <alyx_connector.files.parsing.files.File objec...
# 4    <alyx_connector.files.parsing.files.File objec...
# ..                                                 ...
# 617  <alyx_connector.files.parsing.files.File objec...
# 618  <alyx_connector.files.parsing.files.File objec...
# 619  <alyx_connector.files.parsing.files.File objec...
# 620  <alyx_connector.files.parsing.files.File objec...
# 621  <alyx_connector.files.parsing.files.File objec...
#
#                                      _destination_file  \
# 0    <alyx_connector.files.parsing.files.File objec...
# 1    <alyx_connector.files.parsing.files.File objec...
# 2    <alyx_connector.files.parsing.files.File objec...
# 3    <alyx_connector.files.parsing.files.File objec...
# 4    <alyx_connector.files.parsing.files.File objec...
# ..                                                 ...
# 617  <alyx_connector.files.parsing.files.File objec...
# 618  <alyx_connector.files.parsing.files.File objec...
# 619  <alyx_connector.files.parsing.files.File objec...
# 620  <alyx_connector.files.parsing.files.File objec...
# 621  <alyx_connector.files.parsing.files.File objec...
#
#                                            _final_path  \
# 0    \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 1    \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 2    \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 3    \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 4    \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# ..                                                 ...
# 617  \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 618  \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 619  \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 620  \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 621  \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
#
#                                      _final_pathstring  \
# 0    \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 1    \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 2    \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 3    \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 4    \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# ..                                                 ...
# 617  \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 618  \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 619  \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 620  \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
# 621  \\157.99.138.167\cajal_data2\ONE\MotorSense\ea...
#
#                                                   info
# 0                        Will be  renamed and included
# 1                        Will be  renamed and included
# 2                        Will be  renamed and included
# 3                        Will be  renamed and included
# 4                        Will be  renamed and included
# ..                                                 ...
# 617                      Will be  renamed and included
# 618  Will be  excluded without change dataset_type ...
# 619  Will be  excluded without change dataset_type ...
# 620  Will be  excluded without change dataset_type ...
# 621  Will be  excluded without change dataset_type ...
#
# [622 rows x 17 columns]

# %%
f = file_records.to_dataframe()
f[f["used_rule"] == "include_test_data_rule "]
\\157.99.138.167\cajal_data2\ONE\Interhem\ihem05\2024-11-06\002\DELETE_LATER_JUST_A_TEST\trials.choice.001.txt
# Out:
#                                             source_path  match  \
# 1002  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 1003  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 1004  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
#
#                 matching_rules                used_rule  valid_alf  \
# 1002  [include_test_data_rule]  include_test_data_rule        True
# 1003  [include_test_data_rule]  include_test_data_rule        True
# 1004  [include_test_data_rule]  include_test_data_rule        True
#
#       path_conflicts  dataset_type_exists  rename  delete  include abort  \
# 1002           False                 True   False   False     True    []
# 1003           False                 True   False   False     True    []
# 1004           False                 True   False   False     True    []
#
#                                            _source_file  \
# 1002  <alyx_connector.files.parsing.File object at 0...
# 1003  <alyx_connector.files.parsing.File object at 0...
# 1004  <alyx_connector.files.parsing.File object at 0...
#
#                                       _destination_file  \
# 1002  <alyx_connector.files.parsing.File object at 0...
# 1003  <alyx_connector.files.parsing.File object at 0...
# 1004  <alyx_connector.files.parsing.File object at 0...
#
#                                             _final_path  \
# 1002  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1003  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1004  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
#
#                                       _final_pathstring  \
# 1002  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1003  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1004  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
#
#                                   info
# 1002  Will be  included without change
# 1003  Will be  included without change
# 1004  Will be  included without change

# %%
session.u_alias
# Out:
# 'ihem05_2024-11-06_002'

# %%
connector.web_client.create(endpoint="datasets", 
                            data={
                                "session_pk":"dc5a61db-cbb6-48dc-bcb9-310211c8512c",
                                  "dataset_type":"trials.choice",
                                  "collection":"DELETE_LATER_JUST_A_TEST",
                                  "data_format":".txt","set_file_records":[{"extra":"001","exists":True},
                                                                      {"extra":"002","exists":True},
                                                                      {"extra":"003","exists":True}
                                                                      ]
                                  }
                                  )
# Out:
# {'id': '0dfed412-9b32-470f-a9d0-177b4f9f207c',
#  'url': 'http://127.0.0.1/datasets/0dfed412-9b32-470f-a9d0-177b4f9f207c',
#  'admin_url': '/admin/data/dataset/0dfed412-9b32-470f-a9d0-177b4f9f207c/change/',
#  'name': 'trials.choice.txt',
#  'created_by': 'tjostmou',
#  'created_datetime': '2025-04-11T14:10:04.503148+02:00',
#  'data_repository': 'Cajal2Interhem',
#  'file_size': None,
#  'version': None,
#  'auto_datetime': '2025-04-11T14:10:04.504138+02:00',
#  'dataset_type': 'trials.choice',
#  'default_dataset': True,
#  'tags': [],
#  'session': 'ihem05_2024-11-06_002',
#  'data_format': '.txt',
#  'data_repository_pk': 'ea2cd868-ea54-4f59-a3b3-640130c44891',
#  'data_format_pk': 'dd3f05b1-6104-4da7-be68-ffaad1b97651',
#  'revision_pk': None,
#  'dataset_type_pk': '378aa050-4924-4a9b-9fe7-b7cf86dff93f',
#  'session_pk': 'dc5a61db-cbb6-48dc-bcb9-310211c8512c',
#  'remote_root': '//157.99.138.167/cajal_data2/ONE/Interhem',
#  'subject': 'ihem05',
#  'date': '2024-11-06',
#  'number': 2,
#  'collection': 'DELETE_LATER_JUST_A_TEST',
#  'revision': '',
#  'object': 'trials',
#  'attribute': 'choice',
#  'extension': '.txt',
#  'file_records': [{'id': 'cef2bd58-10bd-4098-a460-bc4e064817ad',
#    'relative_path': 'ihem05/2024-11-06/002/DELETE_LATER_JUST_A_TEST/trials.choice.001.txt',
#    'extra': '001',
#    'exists': True,
#    'file_name': 'trials.choice.001.txt',
#    'hash': None},
#   {'id': '8888aece-4580-4535-90bb-a7fb85820f92',
#    'relative_path': 'ihem05/2024-11-06/002/DELETE_LATER_JUST_A_TEST/trials.choice.002.txt',
#    'extra': '002',
#    'exists': True,
#    'file_name': 'trials.choice.002.txt',
#    'hash': None},
#   {'id': 'f4295ab5-bb26-4cec-a636-e606f62d4ecd',
#    'relative_path': 'ihem05/2024-11-06/002/DELETE_LATER_JUST_A_TEST/trials.choice.003.txt',
#    'extra': '003',
#    'exists': True,
#    'file_name': 'trials.choice.003.txt',
#    'hash': None}]}

# %%
session
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 session
#
# NameError: name 'session' is not defined

# %%
file_records.stats()
# Out:
# used_rule                            info
#                                      Will be  excluded without change                                                                                          1
#                                      Will be  excluded without change dataset_type doesn't follow alyx format dataset_type:F not existing                      1
#                                      Will be  excluded without change dataset_type doesn't follow alyx format dataset_type:F_chan2 not existing                1
#                                      Will be  excluded without change dataset_type doesn't follow alyx format dataset_type:F_corrected not existing            1
#                                      Will be  excluded without change dataset_type doesn't follow alyx format dataset_type:F_corrected_chan2 not existing      1
#                                                                                                                                                             ...
#                                      Will be  excluded without change dataset_type:treat2p.version not existing                                                1
# behavior_cam_sessings_include_rule   Will be  included without change                                                                                          1
# behavior_whiskers_rule1              Will be  included without change                                                                                        300
# imaging_data_rule2                   Will be  included without change                                                                                        300
# include_test_data_rule               Will be  included without change                                                                                          3
# Length: 315, dtype: int64

# %%
config.apply_to_alyx(file_records)
# Out:
#                                             source_path  match  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# ...                                                 ...    ...
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 1002  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 1003  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 1004  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
#
#                             matching_rules  \
# 0     [behavior_cam_sessings_include_rule]
# 1                [behavior_whiskers_rule1]
# 2                [behavior_whiskers_rule1]
# 3                [behavior_whiskers_rule1]
# 4                [behavior_whiskers_rule1]
# ...                                    ...
# 1000                                    []
# 1001                                    []
# 1002              [include_test_data_rule]
# 1003              [include_test_data_rule]
# 1004              [include_test_data_rule]
#
#                                 used_rule  valid_alf  path_conflicts  \
# 0     behavior_cam_sessings_include_rule        True           False
# 1                behavior_whiskers_rule1        True           False
# 2                behavior_whiskers_rule1        True           False
# 3                behavior_whiskers_rule1        True           False
# 4                behavior_whiskers_rule1        True           False
# ...                                   ...        ...             ...
# 1000                                            True           False
# 1001                                           False           False
# 1002              include_test_data_rule        True           False
# 1003              include_test_data_rule        True           False
# 1004              include_test_data_rule        True           False
#
#       dataset_type_exists  rename  delete  include abort  \
# 0                    True   False   False     True    []
# 1                    True   False   False     True    []
# 2                    True   False   False     True    []
# 3                    True   False   False     True    []
# 4                    True   False   False     True    []
# ...                   ...     ...     ...      ...   ...
# 1000                False   False   False    False    []
# 1001                False   False   False    False    []
# 1002                 True   False   False     True    []
# 1003                 True   False   False     True    []
# 1004                 True   False   False     True    []
#
#                                            _source_file  \
# 0     <alyx_connector.files.parsing.File object at 0...
# 1     <alyx_connector.files.parsing.File object at 0...
# 2     <alyx_connector.files.parsing.File object at 0...
# 3     <alyx_connector.files.parsing.File object at 0...
# 4     <alyx_connector.files.parsing.File object at 0...
# ...                                                 ...
# 1000  <alyx_connector.files.parsing.File object at 0...
# 1001  <alyx_connector.files.parsing.File object at 0...
# 1002  <alyx_connector.files.parsing.File object at 0...
# 1003  <alyx_connector.files.parsing.File object at 0...
# 1004  <alyx_connector.files.parsing.File object at 0...
#
#                                       _destination_file  \
# 0     <alyx_connector.files.parsing.File object at 0...
# 1     <alyx_connector.files.parsing.File object at 0...
# 2     <alyx_connector.files.parsing.File object at 0...
# 3     <alyx_connector.files.parsing.File object at 0...
# 4     <alyx_connector.files.parsing.File object at 0...
# ...                                                 ...
# 1000  <alyx_connector.files.parsing.File object at 0...
# 1001  <alyx_connector.files.parsing.File object at 0...
# 1002  <alyx_connector.files.parsing.File object at 0...
# 1003  <alyx_connector.files.parsing.File object at 0...
# 1004  <alyx_connector.files.parsing.File object at 0...
#
#                                             _final_path  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# ...                                                 ...
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1002  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1003  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1004  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
#
#                                       _final_pathstring  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# ...                                                 ...
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1002  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1003  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1004  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
#
#                                                    info
# 0                      Will be  included without change
# 1                      Will be  included without change
# 2                      Will be  included without change
# 3                      Will be  included without change
# 4                      Will be  included without change
# ...                                                 ...
# 1000  Will be  excluded without change dataset_type:...
# 1001  Will be  excluded without change dataset_type ...
# 1002                   Will be  included without change
# 1003                   Will be  included without change
# 1004                   Will be  included without change
#
# [1005 rows x 16 columns]

# %%
connector.web_client.url + session.admin_url
# Out:
# 'http://127.0.0.1:80/admin/actions/session/dc5a61db-cbb6-48dc-bcb9-310211c8512c/change/'

# %%
session.admin_url
# Out:
# '/admin/actions/session/dc5a61db-cbb6-48dc-bcb9-310211c8512c/change/'

# %%
file_records
# Out:
#                                             source_path  match  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# ...                                                 ...    ...
# 997   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 998   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 999   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
#
#                             matching_rules  \
# 0     [behavior_cam_sessings_include_rule]
# 1                [behavior_whiskers_rule1]
# 2                [behavior_whiskers_rule1]
# 3                [behavior_whiskers_rule1]
# 4                [behavior_whiskers_rule1]
# ...                                    ...
# 997                                     []
# 998                                     []
# 999                                     []
# 1000                                    []
# 1001                                    []
#
#                                 used_rule  valid_alf  path_conflicts  \
# 0     behavior_cam_sessings_include_rule        True           False
# 1                behavior_whiskers_rule1        True           False
# 2                behavior_whiskers_rule1        True           False
# 3                behavior_whiskers_rule1        True           False
# 4                behavior_whiskers_rule1        True           False
# ...                                   ...        ...             ...
# 997                                             True           False
# 998                                             True           False
# 999                                             True           False
# 1000                                            True           False
# 1001                                           False           False
#
#       dataset_type_exists  rename  delete  include abort  \
# 0                    True   False   False     True    []
# 1                    True   False   False     True    []
# 2                    True   False   False     True    []
# 3                    True   False   False     True    []
# 4                    True   False   False     True    []
# ...                   ...     ...     ...      ...   ...
# 997                 False   False   False    False    []
# 998                 False   False   False    False    []
# 999                 False   False   False    False    []
# 1000                False   False   False    False    []
# 1001                False   False   False    False    []
#
#                                            _source_file  \
# 0     <alyx_connector.files.parsing.File object at 0...
# 1     <alyx_connector.files.parsing.File object at 0...
# 2     <alyx_connector.files.parsing.File object at 0...
# 3     <alyx_connector.files.parsing.File object at 0...
# 4     <alyx_connector.files.parsing.File object at 0...
# ...                                                 ...
# 997   <alyx_connector.files.parsing.File object at 0...
# 998   <alyx_connector.files.parsing.File object at 0...
# 999   <alyx_connector.files.parsing.File object at 0...
# 1000  <alyx_connector.files.parsing.File object at 0...
# 1001  <alyx_connector.files.parsing.File object at 0...
#
#                                       _destination_file  \
# 0     <alyx_connector.files.parsing.File object at 0...
# 1     <alyx_connector.files.parsing.File object at 0...
# 2     <alyx_connector.files.parsing.File object at 0...
# 3     <alyx_connector.files.parsing.File object at 0...
# 4     <alyx_connector.files.parsing.File object at 0...
# ...                                                 ...
# 997   <alyx_connector.files.parsing.File object at 0...
# 998   <alyx_connector.files.parsing.File object at 0...
# 999   <alyx_connector.files.parsing.File object at 0...
# 1000  <alyx_connector.files.parsing.File object at 0...
# 1001  <alyx_connector.files.parsing.File object at 0...
#
#                                             _final_path  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# ...                                                 ...
# 997   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 998   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 999   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
#
#                                       _final_pathstring  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# ...                                                 ...
# 997   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 998   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 999   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
#
#                                                    info
# 0                      Will be  included without change
# 1                      Will be  included without change
# 2                      Will be  included without change
# 3                      Will be  included without change
# 4                      Will be  included without change
# ...                                                 ...
# 997   Will be  excluded without change dataset_type:...
# 998   Will be  excluded without change dataset_type:...
# 999   Will be  excluded without change dataset_type:...
# 1000  Will be  excluded without change dataset_type:...
# 1001  Will be  excluded without change dataset_type ...
#
# [1002 rows x 16 columns]

# %%
file_records.to_dataframe()
# Out:
#                                             source_path  match  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# ...                                                 ...    ...
# 997   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 998   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 999   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
#
#                             matching_rules  \
# 0     [behavior_cam_sessings_include_rule]
# 1                [behavior_whiskers_rule1]
# 2                [behavior_whiskers_rule1]
# 3                [behavior_whiskers_rule1]
# 4                [behavior_whiskers_rule1]
# ...                                    ...
# 997                                     []
# 998                                     []
# 999                                     []
# 1000                                    []
# 1001                                    []
#
#                                 used_rule  valid_alf  path_conflicts  \
# 0     behavior_cam_sessings_include_rule        True           False
# 1                behavior_whiskers_rule1        True           False
# 2                behavior_whiskers_rule1        True           False
# 3                behavior_whiskers_rule1        True           False
# 4                behavior_whiskers_rule1        True           False
# ...                                   ...        ...             ...
# 997                                             True           False
# 998                                             True           False
# 999                                             True           False
# 1000                                            True           False
# 1001                                           False           False
#
#       dataset_type_exists  rename  delete  include abort  \
# 0                    True   False   False     True    []
# 1                    True   False   False     True    []
# 2                    True   False   False     True    []
# 3                    True   False   False     True    []
# 4                    True   False   False     True    []
# ...                   ...     ...     ...      ...   ...
# 997                 False   False   False    False    []
# 998                 False   False   False    False    []
# 999                 False   False   False    False    []
# 1000                False   False   False    False    []
# 1001                False   False   False    False    []
#
#                                            _source_file  \
# 0     <alyx_connector.files.parsing.File object at 0...
# 1     <alyx_connector.files.parsing.File object at 0...
# 2     <alyx_connector.files.parsing.File object at 0...
# 3     <alyx_connector.files.parsing.File object at 0...
# 4     <alyx_connector.files.parsing.File object at 0...
# ...                                                 ...
# 997   <alyx_connector.files.parsing.File object at 0...
# 998   <alyx_connector.files.parsing.File object at 0...
# 999   <alyx_connector.files.parsing.File object at 0...
# 1000  <alyx_connector.files.parsing.File object at 0...
# 1001  <alyx_connector.files.parsing.File object at 0...
#
#                                       _destination_file  \
# 0     <alyx_connector.files.parsing.File object at 0...
# 1     <alyx_connector.files.parsing.File object at 0...
# 2     <alyx_connector.files.parsing.File object at 0...
# 3     <alyx_connector.files.parsing.File object at 0...
# 4     <alyx_connector.files.parsing.File object at 0...
# ...                                                 ...
# 997   <alyx_connector.files.parsing.File object at 0...
# 998   <alyx_connector.files.parsing.File object at 0...
# 999   <alyx_connector.files.parsing.File object at 0...
# 1000  <alyx_connector.files.parsing.File object at 0...
# 1001  <alyx_connector.files.parsing.File object at 0...
#
#                                             _final_path  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# ...                                                 ...
# 997   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 998   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 999   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
#
#                                       _final_pathstring  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# ...                                                 ...
# 997   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 998   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 999   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
#
#                                                    info
# 0                       Will be included without change
# 1                       Will be included without change
# 2                       Will be included without change
# 3                       Will be included without change
# 4                       Will be included without change
# ...                                                 ...
# 997   Will be excluded without change dataset_type n...
# 998   Will be excluded without change dataset_type n...
# 999   Will be excluded without change dataset_type n...
# 1000  Will be excluded without change dataset_type n...
# 1001  Will be excluded without change dataset_type d...
#
# [1002 rows x 16 columns]

# %%
isinstance(file_records, list)
# Out:
# False

# %%
display(file_records.to_dataframe())
# Out:
#                                             source_path  match  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# ...                                                 ...    ...
# 997   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 998   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 999   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
#
#                             matching_rules  \
# 0     [behavior_cam_sessings_include_rule]
# 1                [behavior_whiskers_rule1]
# 2                [behavior_whiskers_rule1]
# 3                [behavior_whiskers_rule1]
# 4                [behavior_whiskers_rule1]
# ...                                    ...
# 997                                     []
# 998                                     []
# 999                                     []
# 1000                                    []
# 1001                                    []
#
#                                 used_rule  valid_alf  path_conflicts  \
# 0     behavior_cam_sessings_include_rule        True           False
# 1                behavior_whiskers_rule1        True           False
# 2                behavior_whiskers_rule1        True           False
# 3                behavior_whiskers_rule1        True           False
# 4                behavior_whiskers_rule1        True           False
# ...                                   ...        ...             ...
# 997                                             True           False
# 998                                             True           False
# 999                                             True           False
# 1000                                            True           False
# 1001                                           False           False
#
#       dataset_type_exists  rename  delete  include abort  \
# 0                    True   False   False     True    []
# 1                    True   False   False     True    []
# 2                    True   False   False     True    []
# 3                    True   False   False     True    []
# 4                    True   False   False     True    []
# ...                   ...     ...     ...      ...   ...
# 997                 False   False   False    False    []
# 998                 False   False   False    False    []
# 999                 False   False   False    False    []
# 1000                False   False   False    False    []
# 1001                False   False   False    False    []
#
#                                            _source_file  \
# 0     <alyx_connector.files.parsing.File object at 0...
# 1     <alyx_connector.files.parsing.File object at 0...
# 2     <alyx_connector.files.parsing.File object at 0...
# 3     <alyx_connector.files.parsing.File object at 0...
# 4     <alyx_connector.files.parsing.File object at 0...
# ...                                                 ...
# 997   <alyx_connector.files.parsing.File object at 0...
# 998   <alyx_connector.files.parsing.File object at 0...
# 999   <alyx_connector.files.parsing.File object at 0...
# 1000  <alyx_connector.files.parsing.File object at 0...
# 1001  <alyx_connector.files.parsing.File object at 0...
#
#                                       _destination_file  \
# 0     <alyx_connector.files.parsing.File object at 0...
# 1     <alyx_connector.files.parsing.File object at 0...
# 2     <alyx_connector.files.parsing.File object at 0...
# 3     <alyx_connector.files.parsing.File object at 0...
# 4     <alyx_connector.files.parsing.File object at 0...
# ...                                                 ...
# 997   <alyx_connector.files.parsing.File object at 0...
# 998   <alyx_connector.files.parsing.File object at 0...
# 999   <alyx_connector.files.parsing.File object at 0...
# 1000  <alyx_connector.files.parsing.File object at 0...
# 1001  <alyx_connector.files.parsing.File object at 0...
#
#                                             _final_path  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# ...                                                 ...
# 997   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 998   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 999   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
#
#                                       _final_pathstring  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# ...                                                 ...
# 997   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 998   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 999   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
#
#                                                    info
# 0                       Will be included without change
# 1                       Will be included without change
# 2                       Will be included without change
# 3                       Will be included without change
# 4                       Will be included without change
# ...                                                 ...
# 997   Will be excluded without change dataset_type n...
# 998   Will be excluded without change dataset_type n...
# 999   Will be excluded without change dataset_type n...
# 1000  Will be excluded without change dataset_type n...
# 1001  Will be excluded without change dataset_type d...
#
# [1002 rows x 16 columns]

# %%
file_records_to_df(file_records, details = True)
# Out:
#                                             source_path  match  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# ...                                                 ...    ...
# 997   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 998   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 999   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
#
#                             matching_rules  \
# 0     [behavior_cam_sessings_include_rule]
# 1                [behavior_whiskers_rule1]
# 2                [behavior_whiskers_rule1]
# 3                [behavior_whiskers_rule1]
# 4                [behavior_whiskers_rule1]
# ...                                    ...
# 997                                     []
# 998                                     []
# 999                                     []
# 1000                                    []
# 1001                                    []
#
#                                 used_rule  valid_alf  path_conflicts  \
# 0     behavior_cam_sessings_include_rule        True           False
# 1                behavior_whiskers_rule1        True           False
# 2                behavior_whiskers_rule1        True           False
# 3                behavior_whiskers_rule1        True           False
# 4                behavior_whiskers_rule1        True           False
# ...                                   ...        ...             ...
# 997                                             True           False
# 998                                             True           False
# 999                                             True           False
# 1000                                            True           False
# 1001                                           False           False
#
#       dataset_type_exists  rename  delete  include abort  \
# 0                    True   False   False     True    []
# 1                    True   False   False     True    []
# 2                    True   False   False     True    []
# 3                    True   False   False     True    []
# 4                    True   False   False     True    []
# ...                   ...     ...     ...      ...   ...
# 997                 False   False   False    False    []
# 998                 False   False   False    False    []
# 999                 False   False   False    False    []
# 1000                False   False   False    False    []
# 1001                False   False   False    False    []
#
#                                            _source_file  \
# 0     <alyx_connector.files.parsing.File object at 0...
# 1     <alyx_connector.files.parsing.File object at 0...
# 2     <alyx_connector.files.parsing.File object at 0...
# 3     <alyx_connector.files.parsing.File object at 0...
# 4     <alyx_connector.files.parsing.File object at 0...
# ...                                                 ...
# 997   <alyx_connector.files.parsing.File object at 0...
# 998   <alyx_connector.files.parsing.File object at 0...
# 999   <alyx_connector.files.parsing.File object at 0...
# 1000  <alyx_connector.files.parsing.File object at 0...
# 1001  <alyx_connector.files.parsing.File object at 0...
#
#                                       _destination_file  \
# 0     <alyx_connector.files.parsing.File object at 0...
# 1     <alyx_connector.files.parsing.File object at 0...
# 2     <alyx_connector.files.parsing.File object at 0...
# 3     <alyx_connector.files.parsing.File object at 0...
# 4     <alyx_connector.files.parsing.File object at 0...
# ...                                                 ...
# 997   <alyx_connector.files.parsing.File object at 0...
# 998   <alyx_connector.files.parsing.File object at 0...
# 999   <alyx_connector.files.parsing.File object at 0...
# 1000  <alyx_connector.files.parsing.File object at 0...
# 1001  <alyx_connector.files.parsing.File object at 0...
#
#                                             _final_path  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# ...                                                 ...
# 997   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 998   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 999   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
#
#                                       _final_pathstring  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# ...                                                 ...
# 997   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 998   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 999   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...
#
#                                                    info
# 0                       Will be included without change
# 1                       Will be included without change
# 2                       Will be included without change
# 3                       Will be included without change
# 4                       Will be included without change
# ...                                                 ...
# 997   Will be excluded without change dataset_type n...
# 998   Will be excluded without change dataset_type n...
# 999   Will be excluded without change dataset_type n...
# 1000  Will be excluded without change dataset_type n...
# 1001  Will be excluded without change dataset_type d...
#
# [1002 rows x 16 columns]

# %%
sessions = connector.search(subject="wm32")

# %%
from alyx_connector.files.transfers.transfers import FileTransferManager

# %%
from alyx_connector.files.parsing import File, Matcher
from alyx_connector.files.expressions import Expressions

from alyx_registrator import Config, file_records_to_df
config = Config()

# %%
stats.print_callers('{built-in method builtins.isinstance}')
# Out:
#    Ordered by: internal time
#    List reduced from 219 to 1 due to restriction <'{built-in method builtins.isinstance}'>
#
# Function                               was called by...
#                                            ncalls  tottime  cumtime
# {built-in method builtins.isinstance}  <-       3    0.000    0.000  <frozen importlib._bootstrap>:1384(_handle_fromlist)
#                                              1013    0.000    0.000  <frozen ntpath>:107(join)
#                                             54242    0.008    0.008  <frozen ntpath>:179(splitroot)
#                                              1002    0.000    0.000  <frozen ntpath>:564(normpath)
#                                              2003    0.000    0.000  C:\Python312\Lib\copy.py:61(copy)
#                                              2003    0.000    0.000  C:\Python312\Lib\copy.py:247(_reconstruct)
#                                                16    0.000    0.000  C:\Python312\Lib\enum.py:1528(__or__)
#                                                10    0.000    0.000  C:\Python312\Lib\enum.py:1538(__and__)
#                                            194820    0.031    0.031  C:\Python312\Lib\pathlib.py:358(__init__)
#                                                 4    0.000    0.000  C:\Python312\Lib\typing.py:1439(__subclasscheck__)
#                                             11457    0.003    0.003  C:\Users\tjostmou\Documents\Python\__packages__\ONE-registrator\alyx_registrator\registration.py:381(evaluate)
#                                            128612    0.019    0.019  C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\expressions.py:228(search)
#                                             32153    0.005    0.005  C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:146(date)
#                                             32153    0.007    0.007  C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:228(extra)
#                                                 1    0.000    0.000  c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3513(run_code)
#                                                64    0.000    0.000  c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\ipykernel\ipkernel.py:775(_clean_thread_parent_frames)
#                                                 1    0.000    0.000  c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\pandas\core\dtypes\common.py:1040(needs_i8_conversion)
#                                                 1    0.000    0.000  c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\pandas\core\dtypes\common.py:1434(_is_dtype_type)
#                                                 2    0.000    0.000  c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\pandas\core\indexes\base.py:842(_engine)
#                                                 3    0.000    0.000  c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\pandas\core\indexes\base.py:5170(_get_engine_target)
#                                                 4    0.000    0.000  c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\pandas\core\indexing.py:2765(check_dict_or_set_indexers)
#                                                 1    0.000    0.000  c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\pandas\core\series.py:1095(__getitem__)
#                                                 1    0.000    0.000  c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\traitlets\traitlets.py:1527(_notify_observers)
#                                                 2    0.000    0.000  c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\traitlets\traitlets.py:2304(validate)
#                                                 2    0.000    0.000  c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\traitlets\traitlets.py:3474(validate)
#                                                 2    0.000    0.000  c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\traitlets\traitlets.py:3631(set)
#                                                 1    0.000    0.000  c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:546(_run_callback)
#                                                 7    0.000    0.000  c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\zmq\sugar\socket.py:712(send_multipart)

# %%
import cProfile
import pstats

profiler = cProfile.Profile()
profiler.enable()

file_records = config.evaluate_session(session)

profiler.disable()
stats = pstats.Stats(profiler).sort_stats('tottime')
stats.print_stats(50)  # print top 10 functions by cumulative time
# Out:
#          4955759 function calls (4925591 primitive calls) in 3.411 seconds
#
#    Ordered by: internal time
#    List reduced from 219 to 50 due to restriction <50>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1014    0.404    0.000    0.404    0.000 {built-in method nt._path_isfile}
#    352385    0.298    0.000    0.298    0.000 {method 'search' of 're.Pattern' objects}
#     32153    0.186    0.000    2.097    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:77(from_parts)
#    321530    0.176    0.000    0.279    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:60(_check_unallowed_chars)
#    321530    0.154    0.000    1.800    0.000 {built-in method builtins.setattr}
#     97410    0.154    0.000    0.223    0.000 C:\Python312\Lib\pathlib.py:358(__init__)
#     64306    0.145    0.000    0.601    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\expressions.py:228(search)
#     32153    0.111    0.000    0.953    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:108(root)
#     54242    0.103    0.000    0.161    0.000 <frozen ntpath>:179(splitroot)
#     43186    0.102    0.000    0.291    0.000 C:\Python312\Lib\pathlib.py:387(_parse_path)
#    105489    0.086    0.000    0.242    0.000 C:\Python312\Lib\pathlib.py:437(__str__)
#    351680    0.081    0.000    0.081    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:100(_raise_if_not_partname)
# 459583/459579    0.073    0.000    0.073    0.000 {built-in method builtins.isinstance}
#     32153    0.070    0.000    0.099    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:179(revision)
#     97410    0.065    0.000    0.288    0.000 C:\Python312\Lib\pathlib.py:1158(__init__)
#        12    0.062    0.005    0.062    0.005 {built-in method nt.listdir}
#     75339    0.059    0.000    0.410    0.000 C:\Python312\Lib\pathlib.py:551(drive)
#     32153    0.059    0.000    0.203    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:166(collection)
#     32153    0.057    0.000    2.507    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:87(from_path)
#    128612    0.049    0.000    0.067    0.000 C:\Python312\Lib\enum.py:197(__get__)
#     64306    0.048    0.000    0.048    0.000 {method 'groupdict' of 're.Match' objects}
#     43186    0.046    0.000    0.350    0.000 C:\Python312\Lib\pathlib.py:407(_load_parts)
#     97410    0.043    0.000    0.063    0.000 C:\Python312\Lib\pathlib.py:1165(__new__)
#     32153    0.042    0.000    2.554    0.000 C:\Users\tjostmou\Documents\Python\__packages__\ONE-registrator\alyx_registrator\registration.py:87(source_file)
#     30150    0.039    0.000    2.597    0.000 C:\Users\tjostmou\Documents\Python\__packages__\ONE-registrator\alyx_registrator\registration.py:308(evaluate)
# 164780/134629    0.036    0.000    0.046    0.000 {built-in method builtins.getattr}
#     32153    0.036    0.000    0.072    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:157(number)
#     11457    0.032    0.000    2.640    0.000 C:\Users\tjostmou\Documents\Python\__packages__\ONE-registrator\alyx_registrator\registration.py:381(evaluate)
#     32153    0.031    0.000    0.066    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:248(extension)
#    131566    0.030    0.000    0.030    0.000 {built-in method __new__ of type object at 0x00007FFDAF9F13D0}
#    106490    0.028    0.000    0.028    0.000 {method 'startswith' of 'str' objects}
#    129463    0.027    0.000    0.027    0.000 {method 'append' of 'list' objects}
#    153667    0.025    0.000    0.025    0.000 {built-in method nt.fspath}
#     32153    0.025    0.000    0.344    0.000 C:\Python312\Lib\pathlib.py:749(is_absolute)
#     42185    0.025    0.000    0.057    0.000 C:\Python312\Lib\pathlib.py:429(_format_parsed_parts)
#     68336    0.023    0.000    0.023    0.000 {method 'find' of 'str' objects}
#     97428    0.022    0.000    0.022    0.000 {method 'replace' of 'str' objects}
#     34156    0.022    0.000    0.031    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:69(__new__)
#     32153    0.021    0.000    0.057    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:228(extra)
#     87638    0.021    0.000    0.021    0.000 {built-in method sys.intern}
#     32153    0.020    0.000    0.055    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:146(date)
#     32153    0.018    0.000    0.050    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:194(object)
#     32153    0.017    0.000    0.045    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:205(attribute)
#     64306    0.016    0.000    0.016    0.000 {method 'endswith' of 'str' objects}
#     30150    0.016    0.000    0.051    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:96(__getitem__)
#     43186    0.015    0.000    0.015    0.000 {method 'split' of 'str' objects}
#     86380    0.013    0.000    0.013    0.000 {built-in method builtins.len}
#     32153    0.013    0.000    0.044    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:137(subject)
#     42185    0.011    0.000    0.011    0.000 {method 'join' of 'str' objects}
#     75339    0.011    0.000    0.011    0.000 C:\Python312\Lib\pathlib.py:560(root)

# %%
file_records_to_df(file_records, details = True)
# Out:
#                                             source_path  match  \
# 0     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 1     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 2     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 3     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# 4     \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...   True
# ...                                                 ...    ...
# 997   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 998   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 999   \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 1000  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
# 1001  \\157.99.138.167\cajal_data2\ONE\Interhem\ihem...  False
#
#                             matching_rules used_rule  valid_alf  \
# 0     [behavior_cam_sessings_include_rule]                False
# 1                [behavior_whiskers_rule1]                False
# 2                [behavior_whiskers_rule1]                False
# 3                [behavior_whiskers_rule1]                False
# 4                [behavior_whiskers_rule1]                False
# ...                                    ...       ...        ...
# 997                                     []                False
# 998                                     []                False
# 999                                     []                False
# 1000                                    []                False
# 1001                                    []                False
#
#       path_conflicts  dataset_type_exists  rename  delete  include abort  \
# 0              False                False   False   False    False    []
# 1              False                False   False   False    False    []
# 2              False                False   False   False    False    []
# 3              False                False   False   False    False    []
# 4              False                False   False   False    False    []
# ...              ...                  ...     ...     ...      ...   ...
# 997            False                False   False   False    False    []
# 998            False                False   False   False    False    []
# 999            False                False   False   False    False    []
# 1000           False                False   False   False    False    []
# 1001           False                False   False   False    False    []
#
#                                            _source_file  \
# 0     <alyx_connector.files.parsing.File object at 0...
# 1     <alyx_connector.files.parsing.File object at 0...
# 2     <alyx_connector.files.parsing.File object at 0...
# 3     <alyx_connector.files.parsing.File object at 0...
# 4     <alyx_connector.files.parsing.File object at 0...
# ...                                                 ...
# 997   <alyx_connector.files.parsing.File object at 0...
# 998   <alyx_connector.files.parsing.File object at 0...
# 999   <alyx_connector.files.parsing.File object at 0...
# 1000  <alyx_connector.files.parsing.File object at 0...
# 1001  <alyx_connector.files.parsing.File object at 0...
#
#                                       _destination_file  \
# 0     <alyx_connector.files.parsing.File object at 0...
# 1     <alyx_connector.files.parsing.File object at 0...
# 2     <alyx_connector.files.parsing.File object at 0...
# 3     <alyx_connector.files.parsing.File object at 0...
# 4     <alyx_connector.files.parsing.File object at 0...
# ...                                                 ...
# 997   <alyx_connector.files.parsing.File object at 0...
# 998   <alyx_connector.files.parsing.File object at 0...
# 999   <alyx_connector.files.parsing.File object at 0...
# 1000  <alyx_connector.files.parsing.File object at 0...
# 1001  <alyx_connector.files.parsing.File object at 0...
#
#                                                    info
# 0     Will be excluded without change dataset_type d...
# 1     Will be excluded without change dataset_type d...
# 2     Will be excluded without change dataset_type d...
# 3     Will be excluded without change dataset_type d...
# 4     Will be excluded without change dataset_type d...
# ...                                                 ...
# 997   Will be excluded without change dataset_type d...
# 998   Will be excluded without change dataset_type d...
# 999   Will be excluded without change dataset_type d...
# 1000  Will be excluded without change dataset_type d...
# 1001  Will be excluded without change dataset_type d...
#
# [1002 rows x 14 columns]

# %%
len(file_records)
# Out:
# 1002

# %%
import cProfile
import pstats

profiler = cProfile.Profile()
profiler.enable()

file_records = config.actions_cascade(file_records)

profiler.disable()
stats = pstats.Stats(profiler).sort_stats('tottime')
stats.print_stats(50)  # print top 10 functions by cumulative time
# Out:
#          939748 function calls (939733 primitive calls) in 0.571 seconds
#
#    Ordered by: internal time
#    List reduced from 332 to 50 due to restriction <50>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     53195    0.051    0.000    0.051    0.000 {method 'search' of 're.Pattern' objects}
#      4809    0.029    0.000    0.328    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:63(from_parts)
#     49290    0.027    0.000    0.043    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:46(_check_unallowed_chars)
#     49290    0.025    0.000    0.286    0.000 {built-in method builtins.setattr}
#      9618    0.023    0.000    0.095    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\expressions.py:228(search)
#     17724    0.021    0.000    0.035    0.000 C:\Python312\Lib\pathlib.py:358(__init__)
#      4809    0.018    0.000    0.153    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:94(root)
#     11419    0.016    0.000    0.023    0.000 C:\Users\tjostmou\Documents\Python\__packages__\ONE-registrator\alyx_registrator\registration.py:485(is_matching_rule)
#      8109    0.016    0.000    0.025    0.000 <frozen ntpath>:179(splitroot)
#      5409    0.014    0.000    0.042    0.000 C:\Python312\Lib\pathlib.py:387(_parse_path)
#     17724    0.013    0.000    0.048    0.000 C:\Python312\Lib\pathlib.py:1158(__init__)
# 78103/78097    0.013    0.000    0.013    0.000 {built-in method builtins.isinstance}
#     49290    0.012    0.000    0.012    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:86(_raise_if_not_partname)
#     17331    0.012    0.000    0.033    0.000 C:\Python312\Lib\pathlib.py:437(__str__)
#      3807    0.012    0.000    0.035    0.000 C:\Python312\Lib\copy.py:61(copy)
#      4809    0.011    0.000    0.016    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:165(revision)
#     19038    0.010    0.000    0.312    0.000 C:\Users\tjostmou\Documents\Python\__packages__\ONE-registrator\alyx_registrator\registration.py:465(actions_cascade)
#         1    0.010    0.010    0.503    0.503 C:\Users\tjostmou\Documents\Python\__packages__\ONE-registrator\alyx_registrator\registration.py:755(actions_cascade)
#      5109    0.010    0.000    0.034    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:152(collection)
#      4809    0.009    0.000    0.393    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:73(from_path)
#     10218    0.009    0.000    0.066    0.000 C:\Python312\Lib\pathlib.py:551(drive)
#     17724    0.008    0.000    0.012    0.000 C:\Python312\Lib\pathlib.py:1165(__new__)
#     19236    0.008    0.000    0.010    0.000 C:\Python312\Lib\enum.py:197(__get__)
#       300    0.007    0.000    0.008    0.000 {built-in method builtins.eval}
#      5409    0.007    0.000    0.057    0.000 C:\Python312\Lib\pathlib.py:407(_load_parts)
#      9618    0.007    0.000    0.007    0.000 {method 'groupdict' of 're.Match' objects}
#     19038    0.007    0.000    0.340    0.000 C:\Users\tjostmou\Documents\Python\__packages__\ONE-registrator\alyx_registrator\registration.py:665(actions_cascade)
#     40611    0.007    0.000    0.007    0.000 {built-in method builtins.getattr}
#      3807    0.006    0.000    0.359    0.000 C:\Users\tjostmou\Documents\Python\__packages__\ONE-registrator\alyx_registrator\registration.py:96(destination_file)
#     26343    0.006    0.000    0.006    0.000 {built-in method __new__ of type object at 0x00007FFDAF9F13D0}
#      4809    0.006    0.000    0.401    0.000 C:\Users\tjostmou\Documents\Python\__packages__\ONE-registrator\alyx_registrator\registration.py:87(source_file)
#      4809    0.006    0.000    0.011    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:143(number)
#      3807    0.006    0.000    0.015    0.000 C:\Python312\Lib\copy.py:247(_reconstruct)
#      8616    0.006    0.000    0.008    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:55(__new__)
# 33678/33670    0.005    0.000    0.005    0.000 {built-in method builtins.len}
#      4809    0.005    0.000    0.010    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:231(extension)
#     25233    0.004    0.000    0.004    0.000 {built-in method nt.fspath}
#     20838    0.004    0.000    0.004    0.000 {method 'get' of 'dict' objects}
#     17425    0.004    0.000    0.004    0.000 {method 'append' of 'list' objects}
#     15027    0.004    0.000    0.004    0.000 {method 'startswith' of 'str' objects}
#      4809    0.004    0.000    0.056    0.000 C:\Python312\Lib\pathlib.py:749(is_absolute)
#     10818    0.004    0.000    0.004    0.000 {method 'find' of 'str' objects}
#      3807    0.004    0.000    0.004    0.000 {method '__reduce_ex__' of 'object' objects}
#      5409    0.003    0.000    0.006    0.000 C:\Python312\Lib\pathlib.py:429(_format_parsed_parts)
#     12918    0.003    0.000    0.003    0.000 {built-in method sys.intern}
#      4809    0.003    0.000    0.009    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:132(date)
#     13518    0.003    0.000    0.003    0.000 {method 'replace' of 'str' objects}
#      5109    0.003    0.000    0.008    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:180(object)
#      5109    0.003    0.000    0.007    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:191(attribute)
#       300    0.003    0.000    0.205    0.001 C:\Users\tjostmou\Documents\Python\__packages__\ONE-registrator\alyx_registrator\registration.py:592(rename)

# %%
FileTransferManager(sessions).push_request(policies={"destination_older":"ignore"}).transfer()

# %%
import subprocess
import re

def parse_git_diff(file1, file2):
    cmd = ['git', 'diff', '--no-index', '-U0', file1, file2]
    result = subprocess.run(cmd, capture_output=True, text=True)
    if result.returncode not in (0, 1):
        raise RuntimeError(f"Git diff failed: {result.stderr}")

    diff_output = result.stdout.splitlines()
    changes = []
    src_line_num = dst_line_num = 0

    for line in diff_output:
        if line.startswith('@@'):
            hunk_header = re.match(r'@@ -(\d+)(?:,\d+)? \+(\d+)(?:,\d+)? @@', line)
            if hunk_header:
                src_line_num = int(hunk_header.group(1))
                dst_line_num = int(hunk_header.group(2))
        elif line.startswith('+') and not line.startswith('+++'):
            changes.append({
                'type': 'insertion',
                'line_number': dst_line_num,
                'content': line[1:]
            })
            dst_line_num += 1
        elif line.startswith('-') and not line.startswith('---'):
            changes.append({
                'type': 'deletion',
                'line_number': src_line_num,
                'content': line[1:]
            })
            src_line_num += 1
        elif not line.startswith('\\'):
            src_line_num += 1
            dst_line_num += 1

    return changes

file1 = r'C:\Users\tjostmou\Documents\Python\__packages__\haiss-alyx\config\django_server\Dockerfile'
file2 = r'C:\Users\tjostmou\Documents\Python\__packages__\haiss-alyx\docker\django_server\Dockerfile'

changes = parse_git_diff(file1, file2)
for change in changes:
    print(f"{change['type'].capitalize()} at line {change['line_number']}: {change['content']}")
# Out:
# Deletion at line 6: ARG APP_USER=appuser
# Deletion at line 7: ARG UID=1000
# Deletion at line 8: ARG GID=1000
# Deletion at line 9: ARG APP_GROUP=users
# Insertion at line 6: ARG APP_USER=%%PERMISIONED_USERNAME%%
# Insertion at line 7: ARG UID=%%PERMISSIONED_UID%%
# Insertion at line 8: ARG GID=%%PERMISSIONED_GID%%
# Insertion at line 9: ARG APP_GROUP=%%PERMISSIONED_GROUPNAME%%

# %%
connector.web_client.is_up()
# Out:
# False

# %%
existing_dst = connector.search("dataset-types", details = False)

# %%
sessions = connector.search(subject="wm32",number="1",start_time="2025-05-05")
sessions
# Out:
#                                      id subject       users location  \
# 0  2da81fda-279a-4ee8-b6e7-49a05a683d15    wm32  [tjostmou]     None
#
#   procedures       lab projects  type task_protocol  number  ...  \
# 0         []  HaissLab       []  None                     1  ...
#
#                u_alias                                               path  \
# 0  wm32_2025-05-04_001  //157.99.138.167/cajal_data2/ONE/Adaptation/wm...
#
#    json probe_insertion notes                 default_data_repository_path  \
# 0  None              []    []  //157.99.138.167/cajal_data2/ONE/Adaptation
#
#   default_data_repository_name            default_data_repository_pk  \
# 0             Cajal2Adaptation  05baa8e4-5eb5-4214-a008-c9e5331004b0
#
#               rel_path                                          admin_url
# 0  wm32/2025-05-04/001  /admin/actions/session/2da81fda-279a-4ee8-b6e7...
#
# [1 rows x 33 columns]

# %%
connector.web_client.create(endpoint="sessions", data={"subject":"wm32","start_time":"2025-05-05","number":"001"})
# Out:
# {'id': '2da81fda-279a-4ee8-b6e7-49a05a683d15',
#  'subject': 'wm32',
#  'users': ['tjostmou'],
#  'location': None,
#  'procedures': [],
#  'lab': 'HaissLab',
#  'projects': [],
#  'type': None,
#  'task_protocol': '',
#  'number': 1,
#  'start_time': '2025-05-05T00:00:00+02:00',
#  'end_time': None,
#  'narrative': '',
#  'parent_session': None,
#  'n_correct_trials': None,
#  'n_trials': None,
#  'url': 'http://127.0.0.1/sessions/2da81fda-279a-4ee8-b6e7-49a05a683d15',
#  'extended_qc': None,
#  'qc': 'NOT_SET',
#  'wateradmin_session_related': [],
#  'data_dataset_session_related': [],
#  'auto_datetime': '2025-04-09T21:03:37.320283+02:00',
#  'alias': 'wm32/2025-05-05/001',
#  'u_alias': 'wm32_2025-05-05_001',
#  'path': '//157.99.138.167/cajal_data2/ONE/Adaptation/wm32/2025-05-05/001',
#  'json': None,
#  'probe_insertion': [],
#  'notes': [],
#  'default_data_repository_path': '//157.99.138.167/cajal_data2/ONE/Adaptation',
#  'default_data_repository_name': 'Cajal2Adaptation',
#  'default_data_repository_pk': '05baa8e4-5eb5-4214-a008-c9e5331004b0',
#  'rel_path': 'wm32/2025-05-05/001',
#  'admin_url': '/admin/actions/session/2da81fda-279a-4ee8-b6e7-49a05a683d15/change/'}

# %%
session.path
# Out:
# '//157.99.138.167/cajal_data2/ONE/Interhem/ihem05/2024-11-06/002'

# %%
sum([v[2] for k,v in stats.stats.items()])
# Out:
# 79.7198255

# %%
import re
import timeit

_unallowed_chars_set = {"?", "*", ":", '"', "<", ">"}
_unallowed_chars_re = re.compile(r'[?*:"><]')

def check_set(variable):
    return any(char in _unallowed_chars_set for char in variable)

def check_re(variable):
    return bool(_unallowed_chars_re.search(variable))

test_str = "this_is_a_test_string_with_no_unallowed_chars"

print("Set:", timeit.timeit(lambda: check_set(test_str), number=1000000))
print("Regexp:", timeit.timeit(lambda: check_re(test_str), number=1000000))
# Out:
# Set: 2.646561099914834
# Regexp: 0.3690903000533581

# %%
profiler.dump_stats("profile_results.prof")

# %%
stats = pstats.Stats(profiler).sort_stats('tottime')
stats.print_stats(50)  # print top 10 functions by cumulative time
# Out:
#          145726694 function calls (144967324 primitive calls) in 79.720 seconds
#
#    Ordered by: internal time
#    List reduced from 228 to 50 due to restriction <50>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#   4744322    5.847    0.000    9.579    0.000 C:\Python312\Lib\pathlib.py:358(__init__)
#   4373811    5.533    0.000    8.682    0.000 <frozen ntpath>:179(splitroot)
#   1095930    3.514    0.000    8.529    0.000 C:\Python312\Lib\pathlib.py:387(_parse_path)
#   4744322    3.376    0.000   12.955    0.000 C:\Python312\Lib\pathlib.py:1158(__init__)
#   3676320    2.972    0.000    3.680    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:45(_check_unallowed_chars)
# 17528008/17528004    2.672    0.000    2.672    0.000 {built-in method builtins.isinstance}
#    735324    2.518    0.000    2.518    0.000 {method 'search' of 're.Pattern' objects}
#    728418    2.467    0.000    7.767    0.000 <frozen ntpath>:107(join)
#    367512    2.310    0.000   25.677    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:63(from_parts)
#   1463442    2.199    0.000   20.365    0.000 C:\Python312\Lib\pathlib.py:437(__str__)
#   2185254    1.973    0.000    9.861    0.000 C:\Python312\Lib\pathlib.py:380(with_segments)
#   3676320    1.883    0.000   21.958    0.000 {built-in method builtins.setattr}
#   4744322    1.878    0.000    2.874    0.000 C:\Python312\Lib\pathlib.py:1165(__new__)
#    735024    1.691    0.000    7.130    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\expressions.py:228(search)
#   1095930    1.557    0.000   18.186    0.000 C:\Python312\Lib\pathlib.py:407(_load_parts)
#  10218550    1.472    0.000    1.472    0.000 {built-in method builtins.getattr}
#   1463442    1.409    0.000   19.595    0.000 C:\Python312\Lib\pathlib.py:551(drive)
#    367512    1.379    0.000   11.507    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:94(root)
#   2185254    1.342    0.000   11.202    0.000 C:\Python312\Lib\pathlib.py:712(joinpath)
#   8390318    1.305    0.000    1.305    0.000 {built-in method nt.fspath}
#    364209    1.300    0.000   15.796    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:244(session_name)
#    364209    1.259    0.000    4.625    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:274(filename)
#   5469741    1.221    0.000    1.221    0.000 {method 'replace' of 'str' objects}
#   4559217    1.146    0.000    1.146    0.000 {built-in method sys.intern}
#   5114834    1.099    0.000    1.099    0.000 {built-in method __new__ of type object at 0x00007FFDAF9F13D0}
#   3676320    0.951    0.000    0.951    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:86(_raise_if_not_partname)
#   1092627    0.932    0.000    2.061    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:219(extras)
#    367512    0.866    0.000    1.203    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:165(revision)
# 367511/70    0.865    0.000    0.011    0.000 C:\Users\tjostmou\Documents\Python\__packages__\ONE-registrator\alyx_registrator\registration.py:85(source_file)
#   2185254    0.829    0.000   12.031    0.000 C:\Python312\Lib\pathlib.py:720(__truediv__)
#    726612    0.821    0.000   11.932    0.000 C:\Python312\Lib\pathlib.py:484(_str_normcase)
#   3675112    0.802    0.000    0.802    0.000 {built-in method builtins.any}
#   3641489    0.787    0.000    0.787    0.000 {method 'extend' of 'list' objects}
#   3289592    0.786    0.000    0.786    0.000 {method 'append' of 'list' objects}
#   2186748    0.758    0.000    0.758    0.000 {method 'split' of 'str' objects}
# 367511/70    0.734    0.000    0.011    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:73(from_path)
#   1095930    0.728    0.000    1.898    0.000 C:\Python312\Lib\pathlib.py:429(_format_parsed_parts)
#    364209    0.724    0.000   21.270    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:315(session_path)
#    367812    0.722    0.000    2.583    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:152(collection)
#   2191860    0.713    0.000    0.713    0.000 {method 'find' of 'str' objects}
#    364209    0.708    0.000    4.167    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:297(collection_subpath)
#    735024    0.610    0.000    0.610    0.000 {method 'groupdict' of 're.Match' objects}
#   1470048    0.600    0.000    0.823    0.000 C:\Python312\Lib\enum.py:197(__get__)
#   2183445    0.570    0.000    0.856    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:210(extra)
#       603    0.549    0.001   79.129    0.131 C:\Users\tjostmou\Documents\Python\__packages__\ONE-registrator\alyx_registrator\registration.py:134(check_path_conflicts)
#   1460139    0.513    0.000    0.513    0.000 {method 'join' of 'str' objects}
#    367512    0.465    0.000    0.948    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:143(number)
#   1467045    0.409    0.000    0.409    0.000 {method 'startswith' of 'str' objects}
#    364209    0.406    0.000   17.381    0.000 C:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\src\alyx_connector\files\parsing.py:240(session_name_as_path)
#    363609    0.405    0.000    0.405    0.000 <string>:2(__eq__)

# %%
[name for name in config.dataset_types if "behaviour" in name]
# Out:
# ['behaviour.camera_settings',
#  'behaviour.video',
#  'behaviour.video_compressed',
#  'behaviour.video_compressed_meta']

# %%
file_records[0].destination_file.dataset_type in config.dataset_types
# Out:
# True

# %%
file_records[0].destination_file.is_dataset_type_valid
# Out:
# True

# %%
file_records_to_df(file_records, details = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 file_records_to_df(file_records, details = True)
#
# NameError: name 'file_records' is not defined

# %%
sessions = connector.web_client.search(endpoint="sessions", subject = "wm32")
# Out:
# Loading sessions details: 100%|██████████| 18/18 [00:02<00:00,  8.43it/s]

# %%
sessions = connector.web_client.update(endpoint="sessions", data = {"subject" : "wm32", "date":"2025-05-15","number":"1"})
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sessions = connector.web_client.update(endpoint="sessions", data = {"subject" : "wm32", "date":"2025-05-15","number":"1"})
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\clients.py:168, in Client.update(self, endpoint, **kwargs)
#     167 def update(self, *, endpoint: str, **kwargs):
# --> 168     raise NotImplementedError("Update is not yet implemented")
#
# NotImplementedError: Update is not yet implemented

# %%
connector.web_client.endpoint("sessions").actions
# Out:
# {'list': /sessions - Operation(method=<OperationMethod.GET: 'get'>, responses=[Response(is_default=False, description='', code=200, content=[Content(type=<ContentType.JSON: 'application/json'>, schema=Object(type=<DataType.OBJECT: 'object'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_properties=None, min_properties=None, required=['count', 'results'], properties=[Property(name='count', schema=Integer(type=<DataType.INTEGER: 'integer'>, title=None, enum=[], example=123, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, multiple_of=None, maximum=None, exclusive_maximum=None, minimum=None, exclusive_minimum=None, format=None)), Property(name='next', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example='http://api.example.org/accounts/?offset=400&limit=100', description=None, default=None, nullable=True, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=<StringFormat.URI: 'uri'>)), Property(name='previous', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example='http://api.example.org/accounts/?offset=200&limit=100', description=None, default=None, nullable=True, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=<StringFormat.URI: 'uri'>)), Property(name='results', schema=Array(type=<DataType.ARRAY: 'array'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_items=None, min_items=None, unique_items=None, items=Object(type=<DataType.OBJECT: 'object'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_properties=None, min_properties=None, required=['id', 'lab', 'subject'], properties=[Property(name='subject', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description='Please follow the standard format :\nTwo or three initials of the person in charge + number of the animal for that person, in chronological order.\ne.g. wm25 => Wilson Mena mouse n°25.\nFor following the identity of the mouses in term of genotype/injected viruses and the correspunding number in mayakind,\nplease use the Zygosities fields below, and the description field to put more details that you want to remember.', default=None, nullable=False, read_only=True, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='start_time', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=True, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=<StringFormat.DATETIME: 'date-time'>)), Property(name='number', schema=Integer(type=<DataType.INTEGER: 'integer'>, title=None, enum=[], example=None, description='Necessary session number for this subject, this day. Must be unique', default=None, nullable=True, read_only=False, write_only=False, deprecated=False, extensions={}, multiple_of=None, maximum=2147483647, exclusive_maximum=None, minimum=-2147483648, exclusive_minimum=None, format=None)), Property(name='lab', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=True, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='id', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=True, write_only=False, deprecated=Fa ...
#  'create': /sessions - Operation(method=<OperationMethod.POST: 'post'>, responses=[Response(is_default=False, description='', code=201, content=[Content(type=<ContentType.JSON: 'application/json'>, schema=Object(type=<DataType.OBJECT: 'object'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_properties=None, min_properties=None, required=['admin_url', 'alias', 'auto_datetime', 'data_dataset_session_related', 'default_data_repository_path', 'id', 'notes', 'path', 'probe_insertion', 'rel_path', 'subject', 'u_alias', 'url', 'wateradmin_session_related'], properties=[Property(name='id', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=True, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=<StringFormat.UUID: 'uuid'>)), Property(name='subject', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description='Please follow the standard format :\nTwo or three initials of the person in charge + number of the animal for that person, in chronological order.\ne.g. wm25 => Wilson Mena mouse n°25.\nFor following the identity of the mouses in term of genotype/injected viruses and the correspunding number in mayakind,\nplease use the Zygosities fields below, and the description field to put more details that you want to remember.', default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='users', schema=Array(type=<DataType.ARRAY: 'array'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_items=None, min_items=None, unique_items=None, items=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description='Required. 150 characters or fewer. Letters, digits and @/./+/-/_ only.', default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None))), Property(name='location', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description='Long name', default=None, nullable=True, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='procedures', schema=Array(type=<DataType.ARRAY: 'array'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_items=None, min_items=None, unique_items=None, items=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description='Long name', default=None, nullable=True, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None))), Property(name='lab', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='projects', schema=Array(type=<DataType.ARRAY: 'array'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_items=None, min_items=None, unique_items=None, items=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None))), Property(name='type', schema=String(type=<DataType.STRING:  ...
#  'retrieve': /sessions/{id} - Operation(method=<OperationMethod.GET: 'get'>, responses=[Response(is_default=False, description='', code=200, content=[Content(type=<ContentType.JSON: 'application/json'>, schema=Object(type=<DataType.OBJECT: 'object'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_properties=None, min_properties=None, required=['admin_url', 'alias', 'auto_datetime', 'data_dataset_session_related', 'default_data_repository_path', 'id', 'notes', 'path', 'probe_insertion', 'rel_path', 'subject', 'u_alias', 'url', 'wateradmin_session_related'], properties=[Property(name='id', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=True, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=<StringFormat.UUID: 'uuid'>)), Property(name='subject', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description='Please follow the standard format :\nTwo or three initials of the person in charge + number of the animal for that person, in chronological order.\ne.g. wm25 => Wilson Mena mouse n°25.\nFor following the identity of the mouses in term of genotype/injected viruses and the correspunding number in mayakind,\nplease use the Zygosities fields below, and the description field to put more details that you want to remember.', default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='users', schema=Array(type=<DataType.ARRAY: 'array'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_items=None, min_items=None, unique_items=None, items=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description='Required. 150 characters or fewer. Letters, digits and @/./+/-/_ only.', default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None))), Property(name='location', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description='Long name', default=None, nullable=True, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='procedures', schema=Array(type=<DataType.ARRAY: 'array'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_items=None, min_items=None, unique_items=None, items=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description='Long name', default=None, nullable=True, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None))), Property(name='lab', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='projects', schema=Array(type=<DataType.ARRAY: 'array'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_items=None, min_items=None, unique_items=None, items=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None))), Property(name='type', schema=String(type=<DataType.STR ...
#  'update': /sessions/{id} - Operation(method=<OperationMethod.PATCH: 'patch'>, responses=[Response(is_default=False, description='', code=200, content=[Content(type=<ContentType.JSON: 'application/json'>, schema=Object(type=<DataType.OBJECT: 'object'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_properties=None, min_properties=None, required=['admin_url', 'alias', 'auto_datetime', 'data_dataset_session_related', 'default_data_repository_path', 'id', 'notes', 'path', 'probe_insertion', 'rel_path', 'subject', 'u_alias', 'url', 'wateradmin_session_related'], properties=[Property(name='id', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=True, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=<StringFormat.UUID: 'uuid'>)), Property(name='subject', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description='Please follow the standard format :\nTwo or three initials of the person in charge + number of the animal for that person, in chronological order.\ne.g. wm25 => Wilson Mena mouse n°25.\nFor following the identity of the mouses in term of genotype/injected viruses and the correspunding number in mayakind,\nplease use the Zygosities fields below, and the description field to put more details that you want to remember.', default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='users', schema=Array(type=<DataType.ARRAY: 'array'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_items=None, min_items=None, unique_items=None, items=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description='Required. 150 characters or fewer. Letters, digits and @/./+/-/_ only.', default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None))), Property(name='location', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description='Long name', default=None, nullable=True, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='procedures', schema=Array(type=<DataType.ARRAY: 'array'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_items=None, min_items=None, unique_items=None, items=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description='Long name', default=None, nullable=True, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None))), Property(name='lab', schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None)), Property(name='projects', schema=Array(type=<DataType.ARRAY: 'array'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_items=None, min_items=None, unique_items=None, items=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None))), Property(name='type', schema=String(type=<DataType.S ...
#  'destroy': /sessions/{id} - Operation(method=<OperationMethod.DELETE: 'delete'>, responses=[Response(is_default=False, description='No response body', code=204, content=None, headers=[])], summary=None, description='Detail of one session', operation_id='sessions_destroy', external_docs=None, request_body=None, deprecated=False, parameters=[Parameter(name='id', location=<ParameterLocation.PATH: 'path'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=<StringFormat.UUID: 'uuid'>), content=None, required=True, description=None, deprecated=False, style=<PathParameterStyle.SIMPLE: 'simple'>, explode=False, extensions={})], tags=['sessions'], security=[{'cookieAuth': []}, {'tokenAuth': []}], extensions={})}

# %%
sessions = connector.web_client.create(endpoint="sessions", data = {"subject" : "wm32", "date":"2025-05-15","number":"1"})
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sessions = connector.web_client.create(endpoint="sessions", data = {"subject" : "wm32", "date":"2025-05-15","number":"1"})
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\clients.py:171, in Client.create(self, endpoint, **kwargs)
#     170 def create(self, *, endpoint: str, **kwargs):
# --> 171     result = self.rest(endpoint, "create", **kwargs)
#     172     return result
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\clients.py:99, in Client.rest(self, endpoint_name, action, timeout, **kwargs)
#      91 def rest(
#      92     self,
#      93     endpoint_name: str,
#    (...)     96     **kwargs,
#      97 ):
#      98     operateur = self.path(endpoint_name).endpoint.assert_exists().actions[action]
# ---> 99     return Request(self, operateur, timeout=timeout, **kwargs).handle()
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:325, in Request.handle(self)
#     324 def handle(self):
# --> 325     return self.handle_response(self.get_response())
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:358, in Request.handle_response(self, response)
#     356     return None
#     357 else:
# --> 358     self.raise_from_response(response)
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:369, in Request.raise_from_response(self, response)
#     367 except json.decoder.JSONDecodeError:
#     368     message = response.text
# --> 369 raise requests.HTTPError(response.status_code, self.url, message, response=response)
#
# HTTPError: [Errno 500] http://127.0.0.1:80/sessions: "['Two session with same subject, date and number cannot exist']"

# %%
import requests

response = requests.post(url="http://127.0.0.1:80/sessions", data= {"subject":"wm32","date":"2025-05-05","number":"1"},
                        headers= {'Authorization': 'Token 3dd2a11095aa34723385744b3dfebe81a40f73ce',
 'Accept': 'application/json'})
print(response.status_code, response.text)
response.raise_for_status()
# Out:
# 500 {"status_code":500,"detail":"['Two session with same subject, date and number cannot exist']"}
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[26], line 7
#       3 response = requests.post(url="http://127.0.0.1:80/sessions", data= {"subject":"wm32","date":"2025-05-05","number":"1"},
#       4                         headers= {'Authorization': 'Token 3dd2a11095aa34723385744b3dfebe81a40f73ce',
#       5  'Accept': 'application/json'})
#       6 print(response.status_code, response.text)
# ----> 7 response.raise_for_status()
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 500 Server Error: Internal Server Error for url: http://127.0.0.1:80/sessions

# %%
response.status_code, response.text
# Out:
# (500,
#  '{"status_code":500,"detail":"[\'Two session with same subject, date and number cannot exist\']"}')

# %%
connector.web_client.endpoint("session").actions
# Out:
# {}

# %%
connector.web_client.create(endpoint="sessions", subject="wm32", date="2025-05-15",number=1)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 connector.web_client.create(endpoint="sessions", subject="wm32", date="2025-05-15",number=1)
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\clients.py:171, in Client.create(self, endpoint, **kwargs)
#     170 def create(self, *, endpoint: str, **kwargs):
# --> 171     result = self.rest(endpoint, "create", **kwargs)
#     172     return result
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\clients.py:99, in Client.rest(self, endpoint_name, action, timeout, **kwargs)
#      91 def rest(
#      92     self,
#      93     endpoint_name: str,
#    (...)     96     **kwargs,
#      97 ):
#      98     operateur = self.path(endpoint_name).endpoint.assert_exists().actions[action]
# ---> 99     return Request(self, operateur, timeout=timeout, **kwargs).handle()
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:316, in Request.handle(self)
#     315 def handle(self):
# --> 316     return self.handle_response(self.get_response())
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:349, in Request.handle_response(self, response)
#     347     return None
#     348 else:
# --> 349     self.raise_from_response(response)
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:360, in Request.raise_from_response(self, response)
#     358 except json.decoder.JSONDecodeError:
#     359     message = response.text
# --> 360 raise requests.HTTPError(response.status_code, self.url, message, response=response)
#
# HTTPError: [Errno 400] http://127.0.0.1:80/sessions?subject=wm32&date=2025-05-15&number=1: {'subject': ['This field is required.']}

# %%
sessions
# Out:
# [{'id': 'c51bcb25-67f9-4417-9e38-5668b8b32754',
#   'subject': 'wm32',
#   'users': ['eachirou', 'tjostmou', 'wilsonmena'],
#   'location': 'Fernbach - 2p stim setup',
#   'procedures': ['Calibration'],
#   'lab': 'HaissLab',
#   'projects': ['Calibrations'],
#   'type': None,
#   'task_protocol': '',
#   'number': 3,
#   'start_time': '2024-02-08T17:02:44+01:00',
#   'end_time': '2024-02-08T17:02:49+01:00',
#   'narrative': "Session where we recorded the whisker camera in sync with 20 trials. \r\nThe whiskers should be visible with the incident light, and the mouse's neck, nose and mouse shall be visible too",
#   'parent_session': None,
#   'n_correct_trials': None,
#   'n_trials': None,
#   'url': 'http://127.0.0.1/sessions/c51bcb25-67f9-4417-9e38-5668b8b32754',
#   'extended_qc': None,
#   'qc': 'NOT_SET',
#   'wateradmin_session_related': [],
#   'data_dataset_session_related': [],
#   'auto_datetime': '2024-02-09T18:07:44.004048+01:00',
#   'alias': 'wm32/2024-02-08/003',
#   'u_alias': 'wm32_2024-02-08_003',
#   'path': '//157.99.138.167/cajal_data2/ONE/Calibrations/wm32/2024-02-08/003',
#   'json': None,
#   'probe_insertion': [],
#   'notes': [],
#   'default_data_repository_path': '//157.99.138.167/cajal_data2/ONE/Calibrations',
#   'default_data_repository_name': 'CajalCalibrations',
#   'default_data_repository_pk': '6d92db03-665c-4684-bb09-249b9816e684',
#   'rel_path': 'wm32/2024-02-08/003',
#   'admin_url': '/admin/actions/session/c51bcb25-67f9-4417-9e38-5668b8b32754/change/'},
#  {'id': '6400e9ec-be90-46c5-aa6e-691912df106d',
#   'subject': 'wm32',
#   'users': ['eachirou', 'tjostmou', 'wilsonmena'],
#   'location': 'Fernbach - 2p stim setup',
#   'procedures': ['Calibration'],
#   'lab': 'HaissLab',
#   'projects': ['Calibrations'],
#   'type': None,
#   'task_protocol': '',
#   'number': 2,
#   'start_time': '2024-02-08T16:59:51+01:00',
#   'end_time': '2024-02-08T17:00:04+01:00',
#   'narrative': '# Measures\r\nMeasuring the pixel movement in 2photon at several zoom levels, in relation with physical displacement.\r\n\r\n# Results\r\n-  Zoom 1 : `250µm` (horizontal move) = `69 pixels` (measured with 2D correlation) -> `0.276 pixels` per µm\r\n-  Zoom 2 : `100 µm` (horizontal move) = `55 pixels` (measured with 2D correlation) -> `0.55 pixels` per µm\r\n-  Zoom 4 : `50µm` (horizontal move) = `55 pixels` (measured with 2D correlation) -> `1.1 pixels` per µm\r\n\r\n# Conclusion : \r\nLinear relationship of slope `0.275` between zoom and pixels per µm.\r\n\r\n> Ex : if zoom 2, you know that  pixels per µm = 2 * 0.275 = 0.55',
#   'parent_session': None,
#   'n_correct_trials': None,
#   'n_trials': None,
#   'url': 'http://127.0.0.1/sessions/6400e9ec-be90-46c5-aa6e-691912df106d',
#   'extended_qc': None,
#   'qc': 'NOT_SET',
#   'wateradmin_session_related': [],
#   'data_dataset_session_related': [],
#   'auto_datetime': '2024-08-30T16:21:03.288880+02:00',
#   'alias': 'wm32/2024-02-08/002',
#   'u_alias': 'wm32_2024-02-08_002',
#   'path': '//157.99.138.167/cajal_data2/ONE/Calibrations/wm32/2024-02-08/002',
#   'json': None,
#   'probe_insertion': [],
#   'notes': [],
#   'default_data_repository_path': '//157.99.138.167/cajal_data2/ONE/Calibrations',
#   'default_data_repository_name': 'CajalCalibrations',
#   'default_data_repository_pk': '6d92db03-665c-4684-bb09-249b9816e684',
#   'rel_path': 'wm32/2024-02-08/002',
#   'admin_url': '/admin/actions/session/6400e9ec-be90-46c5-aa6e-691912df106d/change/'},
#  {'id': 'a0786f19-1506-4211-afe9-50600f2cc71d',
#   'subject': 'wm32',
#   'users': ['eachirou', 'tjostmou', 'wilsonmena'],
#   'location': 'Fernbach - 2p stim setup',
#   'procedures': ['Calibration'],
#   'lab': 'HaissLab',
#   'projects': ['Calibrations'],
#   'type': None,
#   'task_protocol': '',
#   'number': 1,
#   'start_time': '2024-02-08T16:36:49+01:00',
#   'end_time': '2024-02-08T16:37:00+01:00',
#   'narrative': 'Measurement of pixels displacement relative to physical displacement on the 1 photon camera\r\nMovement between reference and moved files :\r\n- 1 : 250 µm (motor control) (horizonta move) = 281 pixels (measured via 2D correlation) -> 1.124 pixels / µm\r\n- 2 : 150 µm (motor control) (vertical move) = 184 pixels (measured via 2D correlation= -> 1.226 pixels / µm',
#   'parent_session': None,
#   'n_correct_trials': None,
#   'n_trials': None,
#   'url': 'http://127.0.0.1/sessions/a0786f19-1506-4211-afe9-50600f2cc71d',
#   'extended_qc': None,
#   'qc': 'NOT_SET',
#   'wateradmin_session_related': [],
#   'data_dataset_session_related': [],
#   'auto_datetime': '2024-08-30T15:32:33.548221+02:00',
#   'alias': 'wm32/2024-02-08/001',
#   'u_alias': 'wm32_2024-02-08_001',
#   'path': '//157.99.138.167/cajal_data2/ONE/Calibrations/wm32/2024-02-08/001',
#   'json': None,
#   'probe_insertion': [],
#   'notes': [],
#   'default_data_repository_path': '//157.99.138.167/cajal_data2/ONE/Calibrations',
#   'default_data_repository_name': 'CajalCalibrations',
#   'default_data_repository_pk': '6d92db03-665c-4684-bb09-249b9816e684',
#   'rel_path': 'wm32/2024-02-08/001',
#   'admin_url': '/admin/actions/session/a0786f19-1506-4211-afe9-50600f2cc71d/change/'},
#  {'id': 'ac2aa8f4-17fc-49ee-8055-9b35351964b8',
#   'subject': 'wm32',
#   'users': ['wilsonmena'],
#   'location': 'Fernbach - 2p stim setup',
#   'procedures': ['Imaging neuropil functionnal mapping', 'Two photon Imaging'],
#   'lab': 'HaissLab',
#   'projects': ['Adaptation'],
#   'type': None,
#   'task_protocol': '',
#   'number': 2,
#   'start_time': '2023-08-29T16:15:09+02:00',
#   'end_time': None,
#   'narrative': '- Vgat#29 / wm#32_20230829\r\nFolder 002:\r\n- C1 (left)\r\n- Gamma (right)\r\n- PW: 10 to 90 Hz and AW: 0 Hz or 10 Hz\r\n- PW: 10 to 20 Hz and AW: 0 Hz or 10 Hz\r\n- PW: 10           Hz and AW: 0 Hz or 10 Hz\r\n- Rotation: 16\r\n- zoom: 2\r\n- awake mice\r\n- FOV2 (different focal plane)\r\n- Z: -0.370 (surface)\r\n- pupil recorded\r\n- whisker recorded',
#   'parent_session': None,
#   'n_correct_trials': None,
#   'n_trials': None,
#   'url': 'http://127.0.0.1/sessions/ac2aa8f4-17fc-49ee-8055-9b35351964b8',
#   'extended_qc': {'neuropil_mapping': {'signal': 'good',
#     'positions': 'overlapping',
#     'cropped_barrels': 2,
#     'mappable_whiskers': 2,
#     'multi_spot_whisker': 0}},
#   'qc': 'WARNING',
#   'wateradmin_session_related': [],
#   'data_dataset_session_related': [{'id': '4f38fd0f-8c7e-4c2e-b313-3bb004bf3417',
#     'url': 'http://127.0.0.1/datasets/4f38fd0f-8c7e-4c2e-b313-3bb004bf3417',
#     'admin_url': '/admin/data/dataset/4f38fd0f-8c7e-4c2e-b313-3bb004bf3417/change/',
#     'name': 'behaviour.video.tdms',
#     'created_by': 'tjostmou',
#     'created_datetime': '2023-08-31T07:30:55.197100+02:00',
#     'data_repository': 'Cajal2Adaptation',
#     'file_size': None,
#     'version': None,
#     'auto_datetime': '2023-08-31T07:30:55.200223+02:00',
#     'dataset_type': 'behaviour.video',
#     'default_dataset': True,
#     'tags': [],
#     'session': 'wm32_2023-08-29_002',
#     'data_format': '.tdms',
#     'data_repository_pk': '05baa8e4-5eb5-4214-a008-c9e5331004b0',
#     'data_format_pk': '47bcdd69-8754-4045-ba05-0b59c9dba75b',
#     'revision_pk': None,
#     'dataset_type_pk': 'e37eec5d-60be-4bdb-9c57-07fe17546459',
#     'session_pk': 'ac2aa8f4-17fc-49ee-8055-9b35351964b8',
#     'remote_root': '//157.99.138.167/cajal_data2/ONE/Adaptation',
#     'subject': 'wm32',
#     'date': '2023-08-29',
#     'number': 2,
#     'collection': 'behaviour_imaging/whiskers',
#     'revision': '',
#     'object': 'behaviour',
#     'attribute': 'video',
#     'extension': '.tdms',
#     'file_records': [{'id': 'bad7c292-ad26-4110-8d58-5fc0167ac120',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00000.tdms',
#       'extra': 'whiskers.00000',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00000.tdms',
#       'hash': None},
#      {'id': '8112937f-a116-4ccc-a5cb-19556771e4e5',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00001.tdms',
#       'extra': 'whiskers.00001',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00001.tdms',
#       'hash': None},
#      {'id': 'f2140310-7e16-4da0-a9b3-4f0507662366',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00010.tdms',
#       'extra': 'whiskers.00010',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00010.tdms',
#       'hash': None},
#      {'id': '9bc1e954-3459-4d82-b636-4a4a1458befc',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00100.tdms',
#       'extra': 'whiskers.00100',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00100.tdms',
#       'hash': None},
#      {'id': '33866525-ec23-486f-9b20-1c90486e93a1',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00101.tdms',
#       'extra': 'whiskers.00101',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00101.tdms',
#       'hash': None},
#      {'id': '6e36cba1-1b9b-4ae6-94d9-4fd9813ef819',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00102.tdms',
#       'extra': 'whiskers.00102',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00102.tdms',
#       'hash': None},
#      {'id': '07f4e0b2-d3ef-4d71-885a-11fd60963600',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00103.tdms',
#       'extra': 'whiskers.00103',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00103.tdms',
#       'hash': None},
#      {'id': '48a9388b-d450-4431-86ee-d5ea3d1fa4ac',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00104.tdms',
#       'extra': 'whiskers.00104',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00104.tdms',
#       'hash': None},
#      {'id': '9ef0f0a7-73d9-4591-acb6-1ce8468e47a2',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00105.tdms',
#       'extra': 'whiskers.00105',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00105.tdms',
#       'hash': None},
#      {'id': '33353754-1419-4c2c-8dbe-06c7ea42434a',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00106.tdms',
#       'extra': 'whiskers.00106',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00106.tdms',
#       'hash': None},
#      {'id': '06a159c6-d2a0-4cd1-87a1-8e171bc22d9d',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00107.tdms',
#       'extra': 'whiskers.00107',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00107.tdms',
#       'hash': None},
#      {'id': '8123cae3-60d4-45e8-99e9-b610a7cf9e46',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00108.tdms',
#       'extra': 'whiskers.00108',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00108.tdms',
#       'hash': None},
#      {'id': '975a8afa-e87e-4776-beff-6f6e4aba6b35',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00109.tdms',
#       'extra': 'whiskers.00109',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00109.tdms',
#       'hash': None},
#      {'id': 'e2faf3a4-8fa8-4f19-91b8-cf5cab0a58ec',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00011.tdms',
#       'extra': 'whiskers.00011',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00011.tdms',
#       'hash': None},
#      {'id': 'a503112a-c833-4cac-9742-d474db9290fb',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00110.tdms',
#       'extra': 'whiskers.00110',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00110.tdms',
#       'hash': None},
#      {'id': '05ca4bed-fca8-48a7-8c4a-e83b305f0207',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00111.tdms',
#       'extra': 'whiskers.00111',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00111.tdms',
#       'hash': None},
#      {'id': 'da5881f8-ef9c-47c8-a2d9-27473f30ba25',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00112.tdms',
#       'extra': 'whiskers.00112',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00112.tdms',
#       'hash': None},
#      {'id': 'f6d4fe4b-2662-484b-aff4-2e280b420bc0',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00113.tdms',
#       'extra': 'whiskers.00113',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00113.tdms',
#       'hash': None},
#      {'id': '9eba88bd-43f9-4661-a7cc-0b25995c593f',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00114.tdms',
#       'extra': 'whiskers.00114',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00114.tdms',
#       'hash': None},
#      {'id': '2e8f723e-e7f0-476d-be33-ce7a55da817d',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00115.tdms',
#       'extra': 'whiskers.00115',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00115.tdms',
#       'hash': None},
#      {'id': '3b8271db-9e1b-46c3-9b92-40ab8be71477',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00116.tdms',
#       'extra': 'whiskers.00116',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00116.tdms',
#       'hash': None},
#      {'id': 'ddbd7bbe-2b78-4f52-bc51-b39deb4dcb11',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00117.tdms',
#       'extra': 'whiskers.00117',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00117.tdms',
#       'hash': None},
#      {'id': 'b696d96d-951c-4a93-aff0-a144b6de12f8',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00118.tdms',
#       'extra': 'whiskers.00118',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00118.tdms',
#       'hash': None},
#      {'id': 'f3fa7a74-2448-44e0-9b6c-040dc63b982a',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00119.tdms',
#       'extra': 'whiskers.00119',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00119.tdms',
#       'hash': None},
#      {'id': 'e60a4344-e5a1-403e-992b-5dce58b12deb',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00012.tdms',
#       'extra': 'whiskers.00012',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00012.tdms',
#       'hash': None},
#      {'id': '5175163b-e352-42bb-9b66-e4b938ee140e',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00120.tdms',
#       'extra': 'whiskers.00120',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00120.tdms',
#       'hash': None},
#      {'id': 'e23b4df2-e73d-4101-aab0-0082faa3e9dc',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00121.tdms',
#       'extra': 'whiskers.00121',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00121.tdms',
#       'hash': None},
#      {'id': 'c220f78e-c0d3-42a2-9510-95916f6aaf5d',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00122.tdms',
#       'extra': 'whiskers.00122',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00122.tdms',
#       'hash': None},
#      {'id': '0fe089fd-fb11-4d17-9943-25d8d8c36000',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00123.tdms',
#       'extra': 'whiskers.00123',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00123.tdms',
#       'hash': None},
#      {'id': 'c91cb588-8c97-43d2-8a5b-88b35ff18882',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00124.tdms',
#       'extra': 'whiskers.00124',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00124.tdms',
#       'hash': None},
#      {'id': '9fc9480e-ce20-41da-a23d-68499eafa9de',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00125.tdms',
#       'extra': 'whiskers.00125',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00125.tdms',
#       'hash': None},
#      {'id': 'f5706da7-ccbe-4831-80af-0548db0b3247',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00126.tdms',
#       'extra': 'whiskers.00126',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00126.tdms',
#       'hash': None},
#      {'id': 'a6237db2-e25b-4d42-beb1-82d65c2f3b2c',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00127.tdms',
#       'extra': 'whiskers.00127',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00127.tdms',
#       'hash': None},
#      {'id': '92ee7479-0b29-4511-8274-e0fe6019a117',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00128.tdms',
#       'extra': 'whiskers.00128',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00128.tdms',
#       'hash': None},
#      {'id': 'e343dc39-c590-42fd-935e-ec825a494aed',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00129.tdms',
#       'extra': 'whiskers.00129',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00129.tdms',
#       'hash': None},
#      {'id': 'a7b6e1ed-87f9-4311-9071-0514487d4eef',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00013.tdms',
#       'extra': 'whiskers.00013',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00013.tdms',
#       'hash': None},
#      {'id': '12d1fb43-845e-4c44-a68d-ce2110f9957b',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00130.tdms',
#       'extra': 'whiskers.00130',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00130.tdms',
#       'hash': None},
#      {'id': '6cf96db7-f5ef-4652-a75a-9ad44e5c2386',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00131.tdms',
#       'extra': 'whiskers.00131',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00131.tdms',
#       'hash': None},
#      {'id': '2faba187-040b-4c20-ad9a-de2e74559668',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00132.tdms',
#       'extra': 'whiskers.00132',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00132.tdms',
#       'hash': None},
#      {'id': '8477273a-5885-485d-b81f-b3a390504190',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00133.tdms',
#       'extra': 'whiskers.00133',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00133.tdms',
#       'hash': None},
#      {'id': '89c12a62-c3d0-470e-9ff8-d971ddd160c9',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00134.tdms',
#       'extra': 'whiskers.00134',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00134.tdms',
#       'hash': None},
#      {'id': '919c91fc-56f6-4fa9-94fd-c1b33c579c1f',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00135.tdms',
#       'extra': 'whiskers.00135',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00135.tdms',
#       'hash': None},
#      {'id': 'df54b57a-a997-4c71-b153-2e2857d6fb68',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00136.tdms',
#       'extra': 'whiskers.00136',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00136.tdms',
#       'hash': None},
#      {'id': '2a0609b0-edaf-4a5a-8414-5b6cdb3ed159',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00137.tdms',
#       'extra': 'whiskers.00137',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00137.tdms',
#       'hash': None},
#      {'id': '4b9a05a6-b67f-4c91-ac0c-52bfa0a881c6',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00138.tdms',
#       'extra': 'whiskers.00138',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00138.tdms',
#       'hash': None},
#      {'id': 'd8d2a1fe-2158-41ab-b95e-e5016b4c0e34',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00139.tdms',
#       'extra': 'whiskers.00139',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00139.tdms',
#       'hash': None},
#      {'id': '5bd9a2fb-c362-4dc5-afc2-b642023fb0b6',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00014.tdms',
#       'extra': 'whiskers.00014',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00014.tdms',
#       'hash': None},
#      {'id': 'a973fa01-f55a-4929-9de8-6e304982c9e6',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00140.tdms',
#       'extra': 'whiskers.00140',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00140.tdms',
#       'hash': None},
#      {'id': '3674d5db-c52e-479a-be89-5dd57529ab9d',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00141.tdms',
#       'extra': 'whiskers.00141',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00141.tdms',
#       'hash': None},
#      {'id': '03fe90ff-b09a-49da-8933-8e6e962bd2de',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00142.tdms',
#       'extra': 'whiskers.00142',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00142.tdms',
#       'hash': None},
#      {'id': 'c4c4ea65-5346-44ca-bfc7-2ce0f2a95316',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00143.tdms',
#       'extra': 'whiskers.00143',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00143.tdms',
#       'hash': None},
#      {'id': '7c8e872d-fa7b-4d3c-9f67-8739490e5fe3',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00144.tdms',
#       'extra': 'whiskers.00144',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00144.tdms',
#       'hash': None},
#      {'id': '64d5403e-eec4-477a-97e3-f66c63fe79c9',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00145.tdms',
#       'extra': 'whiskers.00145',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00145.tdms',
#       'hash': None},
#      {'id': '38404feb-b61a-4dff-bc01-3925c44db3bb',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00146.tdms',
#       'extra': 'whiskers.00146',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00146.tdms',
#       'hash': None},
#      {'id': '95b64bbd-2ffc-460e-8dc9-112182a4e8d7',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00147.tdms',
#       'extra': 'whiskers.00147',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00147.tdms',
#       'hash': None},
#      {'id': '34c1e0a8-c4f5-459d-b01e-67c733131d19',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00148.tdms',
#       'extra': 'whiskers.00148',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00148.tdms',
#       'hash': None},
#      {'id': 'dc265a7e-7a9a-4ebe-b45d-3499e1d06b4b',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00149.tdms',
#       'extra': 'whiskers.00149',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00149.tdms',
#       'hash': None},
#      {'id': '0435ec7a-33c3-4494-808f-a18dfb81e89b',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00015.tdms',
#       'extra': 'whiskers.00015',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00015.tdms',
#       'hash': None},
#      {'id': '04da6763-4091-4c97-bb36-c631d659843c',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00150.tdms',
#       'extra': 'whiskers.00150',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00150.tdms',
#       'hash': None},
#      {'id': '67f0f9ca-ca4a-4beb-a294-f7665c1b3c39',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00151.tdms',
#       'extra': 'whiskers.00151',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00151.tdms',
#       'hash': None},
#      {'id': '196def60-a0ad-481d-bfd2-006609200a8c',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00152.tdms',
#       'extra': 'whiskers.00152',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00152.tdms',
#       'hash': None},
#      {'id': '09d9118b-4342-41da-a1ce-98235567bf63',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00153.tdms',
#       'extra': 'whiskers.00153',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00153.tdms',
#       'hash': None},
#      {'id': '5812a9c7-ca2b-4681-a61d-5d89c1d0a6be',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00154.tdms',
#       'extra': 'whiskers.00154',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00154.tdms',
#       'hash': None},
#      {'id': 'caee9d2f-15c0-49c4-8e9e-ed924fef02a1',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00155.tdms',
#       'extra': 'whiskers.00155',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00155.tdms',
#       'hash': None},
#      {'id': 'e9625f9d-e45c-49fd-92d9-865965ccc5e2',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00156.tdms',
#       'extra': 'whiskers.00156',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00156.tdms',
#       'hash': None},
#      {'id': 'ab47dd58-ec4e-4e90-a671-c0e74653694e',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00157.tdms',
#       'extra': 'whiskers.00157',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00157.tdms',
#       'hash': None},
#      {'id': 'de51d271-0fed-4c75-ac18-79963110d00b',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00158.tdms',
#       'extra': 'whiskers.00158',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00158.tdms',
#       'hash': None},
#      {'id': 'd19faf88-d59d-4284-9e5b-fd4feb1e0e42',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00159.tdms',
#       'extra': 'whiskers.00159',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00159.tdms',
#       'hash': None},
#      {'id': '650bcc89-5515-45f0-b423-86fe49ee5cc1',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00016.tdms',
#       'extra': 'whiskers.00016',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00016.tdms',
#       'hash': None},
#      {'id': '5f3dfc46-52e2-47bc-8efd-aef43ec72b1f',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00160.tdms',
#       'extra': 'whiskers.00160',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00160.tdms',
#       'hash': None},
#      {'id': '26e3ca0a-19a9-462d-a619-489a3982d120',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00161.tdms',
#       'extra': 'whiskers.00161',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00161.tdms',
#       'hash': None},
#      {'id': 'b7e70e14-833e-4e14-8f87-cc7845000a98',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00162.tdms',
#       'extra': 'whiskers.00162',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00162.tdms',
#       'hash': None},
#      {'id': '77f6400b-1afc-499d-a913-87987d1fce46',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00163.tdms',
#       'extra': 'whiskers.00163',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00163.tdms',
#       'hash': None},
#      {'id': 'c044038d-5c99-4b49-8715-f2120fa01d86',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00164.tdms',
#       'extra': 'whiskers.00164',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00164.tdms',
#       'hash': None},
#      {'id': 'dafe9df0-aec9-41d6-bcf2-70e0f002cda0',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00165.tdms',
#       'extra': 'whiskers.00165',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00165.tdms',
#       'hash': None},
#      {'id': '04ceeacf-ce87-4fff-9bd2-62f8ec2fbe6c',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00166.tdms',
#       'extra': 'whiskers.00166',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00166.tdms',
#       'hash': None},
#      {'id': 'e115034d-970d-4e8e-a043-66d7c97d1f23',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00167.tdms',
#       'extra': 'whiskers.00167',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00167.tdms',
#       'hash': None},
#      {'id': 'b2f6361c-83b5-4539-9add-d0aa589c7942',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00168.tdms',
#       'extra': 'whiskers.00168',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00168.tdms',
#       'hash': None},
#      {'id': 'b9beee7c-7de0-4011-bf48-0663eda7e0dd',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00169.tdms',
#       'extra': 'whiskers.00169',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00169.tdms',
#       'hash': None},
#      {'id': '1d9660da-59ba-49b2-b087-3d74ca117e2b',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00017.tdms',
#       'extra': 'whiskers.00017',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00017.tdms',
#       'hash': None},
#      {'id': '252b5cb9-3671-44f5-ba19-104492b43083',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00170.tdms',
#       'extra': 'whiskers.00170',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00170.tdms',
#       'hash': None},
#      {'id': '022fc157-effb-4579-aa94-a808c3315b37',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00171.tdms',
#       'extra': 'whiskers.00171',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00171.tdms',
#       'hash': None},
#      {'id': '13867330-3451-47bb-8243-9919c5076533',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00172.tdms',
#       'extra': 'whiskers.00172',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00172.tdms',
#       'hash': None},
#      {'id': 'fe148ce3-22b1-4ab4-b8a0-4c0729958e38',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00173.tdms',
#       'extra': 'whiskers.00173',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00173.tdms',
#       'hash': None},
#      {'id': 'ae8d970e-3586-4960-b3b8-5a54805d197e',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00174.tdms',
#       'extra': 'whiskers.00174',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00174.tdms',
#       'hash': None},
#      {'id': 'c75715a5-1c41-4066-969e-50ed40d90947',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00175.tdms',
#       'extra': 'whiskers.00175',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00175.tdms',
#       'hash': None},
#      {'id': '8b8e0d1b-a1f0-4b0b-8717-53bb2ea3506c',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00176.tdms',
#       'extra': 'whiskers.00176',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00176.tdms',
#       'hash': None},
#      {'id': '8378dbc6-0855-48de-9709-4f1a456c4b31',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00177.tdms',
#       'extra': 'whiskers.00177',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00177.tdms',
#       'hash': None},
#      {'id': '0f6d0619-8a05-4913-9efa-cd38228258e8',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00178.tdms',
#       'extra': 'whiskers.00178',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00178.tdms',
#       'hash': None},
#      {'id': '65a1273c-1c44-4533-b8b8-499b27f66311',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00179.tdms',
#       'extra': 'whiskers.00179',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00179.tdms',
#       'hash': None},
#      {'id': '11989d40-9c37-43db-9f5a-3d27f17a33e6',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00018.tdms',
#       'extra': 'whiskers.00018',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00018.tdms',
#       'hash': None},
#      {'id': 'c787f983-5635-41f7-b218-82a6f10a4a8f',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00180.tdms',
#       'extra': 'whiskers.00180',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00180.tdms',
#       'hash': None},
#      {'id': '043e57ff-723d-4768-af4d-3cf30933edbb',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00181.tdms',
#       'extra': 'whiskers.00181',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00181.tdms',
#       'hash': None},
#      {'id': '60c4ab64-fb07-49df-bf12-68a4bffa6d83',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00182.tdms',
#       'extra': 'whiskers.00182',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00182.tdms',
#       'hash': None},
#      {'id': 'a9b2474e-7d22-4107-bada-40b489a14b72',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00183.tdms',
#       'extra': 'whiskers.00183',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00183.tdms',
#       'hash': None},
#      {'id': 'baefb184-5b51-40ec-9b21-5b8cfa63a864',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00184.tdms',
#       'extra': 'whiskers.00184',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00184.tdms',
#       'hash': None},
#      {'id': '038d9b00-cc6c-4a96-95cb-ebbe63dba4d2',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00185.tdms',
#       'extra': 'whiskers.00185',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00185.tdms',
#       'hash': None},
#      {'id': 'c701966d-0d6e-45d5-a573-347008fb239f',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00186.tdms',
#       'extra': 'whiskers.00186',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00186.tdms',
#       'hash': None},
#      {'id': '9b0c1f92-10c7-4dc8-8b49-66c52fc2a0d7',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00187.tdms',
#       'extra': 'whiskers.00187',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00187.tdms',
#       'hash': None},
#      {'id': '2842852c-58e0-40ab-87b3-988ee915f9f0',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00188.tdms',
#       'extra': 'whiskers.00188',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00188.tdms',
#       'hash': None},
#      {'id': '4228a93e-30ed-4b56-8a55-a0ad9b4e0138',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00189.tdms',
#       'extra': 'whiskers.00189',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00189.tdms',
#       'hash': None},
#      {'id': '427a2264-cd31-4ce0-97d2-99c3e49c738d',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00019.tdms',
#       'extra': 'whiskers.00019',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00019.tdms',
#       'hash': None},
#      {'id': '65bc096a-aa40-4eb0-bf36-5decb4a12a33',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00190.tdms',
#       'extra': 'whiskers.00190',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00190.tdms',
#       'hash': None},
#      {'id': 'c728b59f-9ca5-4422-8b81-f7e44a5828b4',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00191.tdms',
#       'extra': 'whiskers.00191',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00191.tdms',
#       'hash': None},
#      {'id': '310c774d-95dd-44e8-8b1c-f98c2aae1104',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00192.tdms',
#       'extra': 'whiskers.00192',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00192.tdms',
#       'hash': None},
#      {'id': '6b48799b-7b0e-45b1-a5e6-28bfda132da9',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00193.tdms',
#       'extra': 'whiskers.00193',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00193.tdms',
#       'hash': None},
#      {'id': 'ee6e4941-6ef2-4e02-8923-ddcff73e4a44',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00194.tdms',
#       'extra': 'whiskers.00194',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00194.tdms',
#       'hash': None},
#      {'id': '7919d30c-42f5-419e-9665-b43d3c00a1ea',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00195.tdms',
#       'extra': 'whiskers.00195',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00195.tdms',
#       'hash': None},
#      {'id': '9530a15b-873e-4a93-9435-8f31380d4cf0',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00196.tdms',
#       'extra': 'whiskers.00196',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00196.tdms',
#       'hash': None},
#      {'id': 'de21e4ec-4a7d-43fd-a5d8-d4fd07a680f1',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00197.tdms',
#       'extra': 'whiskers.00197',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00197.tdms',
#       'hash': None},
#      {'id': '94ae9491-264e-40b6-8e42-1eaccbda8b6b',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00198.tdms',
#       'extra': 'whiskers.00198',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00198.tdms',
#       'hash': None},
#      {'id': '04efc109-1ed0-4264-9454-4cc4bc1d260b',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00199.tdms',
#       'extra': 'whiskers.00199',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00199.tdms',
#       'hash': None},
#      {'id': 'd392fbff-8a3c-4f1e-a1d6-b1f79f3733ea',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00002.tdms',
#       'extra': 'whiskers.00002',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00002.tdms',
#       'hash': None},
#      {'id': '04d0b66b-177c-4bfb-9de3-af85c2192164',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00020.tdms',
#       'extra': 'whiskers.00020',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00020.tdms',
#       'hash': None},
#      {'id': 'ce47f796-62e9-4991-aa30-69638a27d53a',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00200.tdms',
#       'extra': 'whiskers.00200',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00200.tdms',
#       'hash': None},
#      {'id': '2fe5a29b-8134-4100-96b0-abcdb52e4c19',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00201.tdms',
#       'extra': 'whiskers.00201',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00201.tdms',
#       'hash': None},
#      {'id': 'f29a8fb5-82a2-45bf-b72a-1d0e660057e2',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00202.tdms',
#       'extra': 'whiskers.00202',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00202.tdms',
#       'hash': None},
#      {'id': 'adf06c5b-823a-4e7a-9662-e928ac4c2051',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00203.tdms',
#       'extra': 'whiskers.00203',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00203.tdms',
#       'hash': None},
#      {'id': '1b3e7498-deb3-4b61-9b11-f99555d5c573',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00204.tdms',
#       'extra': 'whiskers.00204',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00204.tdms',
#       'hash': None},
#      {'id': 'b526aa13-4255-4413-a467-10db84d2d50d',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00205.tdms',
#       'extra': 'whiskers.00205',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00205.tdms',
#       'hash': None},
#      {'id': '98d7e03f-decb-4ef0-9b3d-5273729a2d8a',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00206.tdms',
#       'extra': 'whiskers.00206',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00206.tdms',
#       'hash': None},
#      {'id': '237ec399-2c6f-4194-8296-ccb8994db9ec',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00207.tdms',
#       'extra': 'whiskers.00207',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00207.tdms',
#       'hash': None},
#      {'id': '13cae07c-49b5-4f4a-8009-3f053ef303a6',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00208.tdms',
#       'extra': 'whiskers.00208',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00208.tdms',
#       'hash': None},
#      {'id': '354b374b-031c-4fff-beed-e2aebdd00e05',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00209.tdms',
#       'extra': 'whiskers.00209',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00209.tdms',
#       'hash': None},
#      {'id': 'e428511b-c256-4ae9-916d-58a9cf9cd62b',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00021.tdms',
#       'extra': 'whiskers.00021',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00021.tdms',
#       'hash': None},
#      {'id': 'c2e2f6c3-fda1-4554-9fa6-1e58220efef3',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00210.tdms',
#       'extra': 'whiskers.00210',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00210.tdms',
#       'hash': None},
#      {'id': '1c539cbc-c6f8-4815-970f-f8462c91bbbe',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00211.tdms',
#       'extra': 'whiskers.00211',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00211.tdms',
#       'hash': None},
#      {'id': '87ea1ed8-8dfa-4c31-8985-afa4cfaeef63',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00212.tdms',
#       'extra': 'whiskers.00212',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00212.tdms',
#       'hash': None},
#      {'id': 'a35a9c0d-c317-4c0f-8b72-c1eef978c997',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00213.tdms',
#       'extra': 'whiskers.00213',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00213.tdms',
#       'hash': None},
#      {'id': '114e5850-fa54-4446-9d16-e04870c4ef0c',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00214.tdms',
#       'extra': 'whiskers.00214',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00214.tdms',
#       'hash': None},
#      {'id': 'a0361224-eafd-47f1-bb4e-8353e40667f8',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00215.tdms',
#       'extra': 'whiskers.00215',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00215.tdms',
#       'hash': None},
#      {'id': '04b43392-5215-49ee-8d0b-1fc0510bdb88',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00216.tdms',
#       'extra': 'whiskers.00216',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00216.tdms',
#       'hash': None},
#      {'id': '2ff0cae1-466c-4715-a1ad-84d11e3af655',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00217.tdms',
#       'extra': 'whiskers.00217',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00217.tdms',
#       'hash': None},
#      {'id': '9f06de69-c75a-4022-aa6e-ce9f0aa74c12',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00218.tdms',
#       'extra': 'whiskers.00218',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00218.tdms',
#       'hash': None},
#      {'id': '1d27b938-2b55-4f6c-9685-245dab6ec2b1',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00219.tdms',
#       'extra': 'whiskers.00219',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00219.tdms',
#       'hash': None},
#      {'id': 'd18c216b-7e04-4454-871d-eacb4f5da821',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00022.tdms',
#       'extra': 'whiskers.00022',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00022.tdms',
#       'hash': None},
#      {'id': 'a21e4ec8-dc4d-4fd6-8fe4-ffba239025ca',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00220.tdms',
#       'extra': 'whiskers.00220',
#       'exists': True,
#       'file_name': 'behaviour.video.whiskers.00220.tdms',
#       'hash': None},
#      {'id': 'a054c73c-6961-4a5c-a51a-fa02ea90b75c',
#       'relative_path': 'wm32/2023-08-29/002/behaviour_imaging/whiskers/behaviour.video.whiskers.00221.tdms',
#       'extra': 'whiskers.00221',
#       'exists': True,
# ...
#       'hash': None},
#      {'id': 'cbb941fd-068e-4971-b50d-c80e2497798d',
#       'relative_path': 'wm32/2023-06-28/002/intrinsic_optical_imaging/imaging_intrinsic.bin_delta_stim_images.B1.binlv',
#       'extra': 'B1',
#       'exists': True,
#       'file_name': 'imaging_intrinsic.bin_delta_stim_images.B1.binlv',
#       'hash': None},
#      {'id': 'b75e03f2-5923-476e-b46c-565e4fb0454e',
#       'relative_path': 'wm32/2023-06-28/002/intrinsic_optical_imaging/imaging_intrinsic.bin_delta_stim_images.C1.binlv',
#       'extra': 'C1',
#       'exists': True,
#       'file_name': 'imaging_intrinsic.bin_delta_stim_images.C1.binlv',
#       'hash': None},
#      {'id': 'e72ca3fc-14b5-43f1-a4fa-edbaf79af95f',
#       'relative_path': 'wm32/2023-06-28/002/intrinsic_optical_imaging/imaging_intrinsic.bin_delta_stim_images.D1.binlv',
#       'extra': 'D1',
#       'exists': True,
#       'file_name': 'imaging_intrinsic.bin_delta_stim_images.D1.binlv',
#       'hash': None}]}],
#   'auto_datetime': '2023-07-04T12:49:42.959692+02:00',
#   'alias': 'wm32/2023-06-28/002',
#   'u_alias': 'wm32_2023-06-28_002',
#   'path': '//157.99.138.167/cajal_data2/ONE/Adaptation/wm32/2023-06-28/002',
#   'json': None,
#   'probe_insertion': [],
#   'notes': [],
#   'default_data_repository_path': '//157.99.138.167/cajal_data2/ONE/Adaptation',
#   'default_data_repository_name': 'Cajal2Adaptation',
#   'default_data_repository_pk': '05baa8e4-5eb5-4214-a008-c9e5331004b0',
#   'rel_path': 'wm32/2023-06-28/002',
#   'admin_url': '/admin/actions/session/aba3b9a0-a69b-4d90-8d97-704260bf0ea5/change/'},
#  {'id': '5d505101-451d-4be8-a64e-5f1a4ec7f508',
#   'subject': 'wm32',
#   'users': ['wilsonmena'],
#   'location': 'Fernbach - 2p stim setup',
#   'procedures': ['Anesthesia isoflurane recovery',
#    'Intrinsic optical imaging'],
#   'lab': 'HaissLab',
#   'projects': ['Adaptation'],
#   'type': None,
#   'task_protocol': '',
#   'number': 1,
#   'start_time': '2023-06-28T16:11:31+02:00',
#   'end_time': None,
#   'narrative': '',
#   'parent_session': None,
#   'n_correct_trials': None,
#   'n_trials': None,
#   'url': 'http://127.0.0.1/sessions/5d505101-451d-4be8-a64e-5f1a4ec7f508',
#   'extended_qc': None,
#   'qc': 'NOT_SET',
#   'wateradmin_session_related': [],
#   'data_dataset_session_related': [{'id': 'e201cddc-3625-4c45-9237-af929cb4f6e8',
#     'url': 'http://127.0.0.1/datasets/e201cddc-3625-4c45-9237-af929cb4f6e8',
#     'admin_url': '/admin/data/dataset/e201cddc-3625-4c45-9237-af929cb4f6e8/change/',
#     'name': 'imaging_intrinsic.vessels_reference.tiff',
#     'created_by': 'tjostmou',
#     'created_datetime': '2023-07-07T15:28:12.423198+02:00',
#     'data_repository': 'Cajal2Adaptation',
#     'file_size': None,
#     'version': None,
#     'auto_datetime': '2023-07-07T15:28:12.425387+02:00',
#     'dataset_type': 'imaging_intrinsic.vessels_reference',
#     'default_dataset': True,
#     'tags': [],
#     'session': 'wm32_2023-06-28_001',
#     'data_format': '.tiff',
#     'data_repository_pk': '05baa8e4-5eb5-4214-a008-c9e5331004b0',
#     'data_format_pk': '4ae7cb18-2390-4a1c-aedf-c76caace043a',
#     'revision_pk': None,
#     'dataset_type_pk': '99204399-63c9-4f02-b0ef-9577a0e29c29',
#     'session_pk': '5d505101-451d-4be8-a64e-5f1a4ec7f508',
#     'remote_root': '//157.99.138.167/cajal_data2/ONE/Adaptation',
#     'subject': 'wm32',
#     'date': '2023-06-28',
#     'number': 1,
#     'collection': 'intrinsic_optical_imaging',
#     'revision': '',
#     'object': 'imaging_intrinsic',
#     'attribute': 'vessels_reference',
#     'extension': '.tiff',
#     'file_records': [{'id': '812b41d3-422c-422e-90b8-31feaf43603a',
#       'relative_path': 'wm32/2023-06-28/001/intrinsic_optical_imaging/imaging_intrinsic.vessels_reference.tiff',
#       'extra': '',
#       'exists': True,
#       'file_name': 'imaging_intrinsic.vessels_reference.tiff',
#       'hash': None}]},
#    {'id': '684ed3c1-da46-4b25-aa0d-b83a38a1fa15',
#     'url': 'http://127.0.0.1/datasets/684ed3c1-da46-4b25-aa0d-b83a38a1fa15',
#     'admin_url': '/admin/data/dataset/684ed3c1-da46-4b25-aa0d-b83a38a1fa15/change/',
#     'name': 'imaging_intrinsic.delta_stim_images.tdms',
#     'created_by': 'tjostmou',
#     'created_datetime': '2023-07-07T15:28:12.109943+02:00',
#     'data_repository': 'Cajal2Adaptation',
#     'file_size': None,
#     'version': None,
#     'auto_datetime': '2023-07-07T15:28:12.112059+02:00',
#     'dataset_type': 'imaging_intrinsic.delta_stim_images',
#     'default_dataset': True,
#     'tags': [],
#     'session': 'wm32_2023-06-28_001',
#     'data_format': '.tdms',
#     'data_repository_pk': '05baa8e4-5eb5-4214-a008-c9e5331004b0',
#     'data_format_pk': '47bcdd69-8754-4045-ba05-0b59c9dba75b',
#     'revision_pk': None,
#     'dataset_type_pk': '6a98bba7-da9e-41d0-a5d7-44cb2715ae8d',
#     'session_pk': '5d505101-451d-4be8-a64e-5f1a4ec7f508',
#     'remote_root': '//157.99.138.167/cajal_data2/ONE/Adaptation',
#     'subject': 'wm32',
#     'date': '2023-06-28',
#     'number': 1,
#     'collection': 'intrinsic_optical_imaging',
#     'revision': '',
#     'object': 'imaging_intrinsic',
#     'attribute': 'delta_stim_images',
#     'extension': '.tdms',
#     'file_records': [{'id': '3420cf34-348e-45c4-a098-5690dd16738a',
#       'relative_path': 'wm32/2023-06-28/001/intrinsic_optical_imaging/imaging_intrinsic.delta_stim_images.A1.tdms',
#       'extra': 'A1',
#       'exists': True,
#       'file_name': 'imaging_intrinsic.delta_stim_images.A1.tdms',
#       'hash': None}]},
#    {'id': '9e951cb2-fde1-4363-9dfe-963063c00850',
#     'url': 'http://127.0.0.1/datasets/9e951cb2-fde1-4363-9dfe-963063c00850',
#     'admin_url': '/admin/data/dataset/9e951cb2-fde1-4363-9dfe-963063c00850/change/',
#     'name': 'imaging_intrinsic.bin_delta_stim_images.binlv',
#     'created_by': 'tjostmou',
#     'created_datetime': '2023-07-07T15:28:11.801418+02:00',
#     'data_repository': 'Cajal2Adaptation',
#     'file_size': None,
#     'version': None,
#     'auto_datetime': '2023-07-07T15:28:11.803592+02:00',
#     'dataset_type': 'imaging_intrinsic.bin_delta_stim_images',
#     'default_dataset': True,
#     'tags': [],
#     'session': 'wm32_2023-06-28_001',
#     'data_format': '.binlv',
#     'data_repository_pk': '05baa8e4-5eb5-4214-a008-c9e5331004b0',
#     'data_format_pk': '0bd3fd51-5190-4102-a0cb-cd0e2898b3bc',
#     'revision_pk': None,
#     'dataset_type_pk': 'd7b6832a-a9b3-41b1-8296-6c5af9769af9',
#     'session_pk': '5d505101-451d-4be8-a64e-5f1a4ec7f508',
#     'remote_root': '//157.99.138.167/cajal_data2/ONE/Adaptation',
#     'subject': 'wm32',
#     'date': '2023-06-28',
#     'number': 1,
#     'collection': 'intrinsic_optical_imaging',
#     'revision': '',
#     'object': 'imaging_intrinsic',
#     'attribute': 'bin_delta_stim_images',
#     'extension': '.binlv',
#     'file_records': [{'id': '68cd9bce-7e2e-4fa7-a91a-17e90198d489',
#       'relative_path': 'wm32/2023-06-28/001/intrinsic_optical_imaging/imaging_intrinsic.bin_delta_stim_images.A1.binlv',
#       'extra': 'A1',
#       'exists': True,
#       'file_name': 'imaging_intrinsic.bin_delta_stim_images.A1.binlv',
#       'hash': None}]}],
#   'auto_datetime': '2023-06-29T12:12:07.605371+02:00',
#   'alias': 'wm32/2023-06-28/001',
#   'u_alias': 'wm32_2023-06-28_001',
#   'path': '//157.99.138.167/cajal_data2/ONE/Adaptation/wm32/2023-06-28/001',
#   'json': None,
#   'probe_insertion': [],
#   'notes': [],
#   'default_data_repository_path': '//157.99.138.167/cajal_data2/ONE/Adaptation',
#   'default_data_repository_name': 'Cajal2Adaptation',
#   'default_data_repository_pk': '05baa8e4-5eb5-4214-a008-c9e5331004b0',
#   'rel_path': 'wm32/2023-06-28/001',
#   'admin_url': '/admin/actions/session/5d505101-451d-4be8-a64e-5f1a4ec7f508/change/'},
#  {'id': '08557158-4c86-4760-a5d3-30b2d0d9fc94',
#   'subject': 'wm32',
#   'users': ['wilsonmena'],
#   'location': 'Fernbach - 2p stim setup',
#   'procedures': ['Anesthesia Isoflurane', 'Intrinsic optical imaging'],
#   'lab': 'HaissLab',
#   'projects': ['Adaptation'],
#   'type': None,
#   'task_protocol': '',
#   'number': 2,
#   'start_time': '2023-06-15T17:13:50+02:00',
#   'end_time': None,
#   'narrative': '',
#   'parent_session': None,
#   'n_correct_trials': None,
#   'n_trials': None,
#   'url': 'http://127.0.0.1/sessions/08557158-4c86-4760-a5d3-30b2d0d9fc94',
#   'extended_qc': None,
#   'qc': 'NOT_SET',
#   'wateradmin_session_related': [],
#   'data_dataset_session_related': [{'id': '6d6d3b5b-994f-4b47-869c-c93a5854d50a',
#     'url': 'http://127.0.0.1/datasets/6d6d3b5b-994f-4b47-869c-c93a5854d50a',
#     'admin_url': '/admin/data/dataset/6d6d3b5b-994f-4b47-869c-c93a5854d50a/change/',
#     'name': 'imaging_intrinsic.vessels_reference.tiff',
#     'created_by': 'tjostmou',
#     'created_datetime': '2023-07-07T15:37:24.542668+02:00',
#     'data_repository': 'Cajal2Adaptation',
#     'file_size': None,
#     'version': None,
#     'auto_datetime': '2023-07-07T15:37:24.544780+02:00',
#     'dataset_type': 'imaging_intrinsic.vessels_reference',
#     'default_dataset': True,
#     'tags': [],
#     'session': 'wm32_2023-06-15_002',
#     'data_format': '.tiff',
#     'data_repository_pk': '05baa8e4-5eb5-4214-a008-c9e5331004b0',
#     'data_format_pk': '4ae7cb18-2390-4a1c-aedf-c76caace043a',
#     'revision_pk': None,
#     'dataset_type_pk': '99204399-63c9-4f02-b0ef-9577a0e29c29',
#     'session_pk': '08557158-4c86-4760-a5d3-30b2d0d9fc94',
#     'remote_root': '//157.99.138.167/cajal_data2/ONE/Adaptation',
#     'subject': 'wm32',
#     'date': '2023-06-15',
#     'number': 2,
#     'collection': 'intrinsic_optical_imaging',
#     'revision': '',
#     'object': 'imaging_intrinsic',
#     'attribute': 'vessels_reference',
#     'extension': '.tiff',
#     'file_records': [{'id': 'c4b3d802-9b31-4fb5-9fae-e3c7c4c2ba6c',
#       'relative_path': 'wm32/2023-06-15/002/intrinsic_optical_imaging/imaging_intrinsic.vessels_reference.tiff',
#       'extra': '',
#       'exists': True,
#       'file_name': 'imaging_intrinsic.vessels_reference.tiff',
#       'hash': None}]},
#    {'id': '7a9cda29-284f-4e26-a7a1-750ac50208e0',
#     'url': 'http://127.0.0.1/datasets/7a9cda29-284f-4e26-a7a1-750ac50208e0',
#     'admin_url': '/admin/data/dataset/7a9cda29-284f-4e26-a7a1-750ac50208e0/change/',
#     'name': 'imaging_intrinsic.delta_stim_images.tdms',
#     'created_by': 'tjostmou',
#     'created_datetime': '2023-07-07T15:37:24.042352+02:00',
#     'data_repository': 'Cajal2Adaptation',
#     'file_size': None,
#     'version': None,
#     'auto_datetime': '2023-07-07T15:37:24.044537+02:00',
#     'dataset_type': 'imaging_intrinsic.delta_stim_images',
#     'default_dataset': True,
#     'tags': [],
#     'session': 'wm32_2023-06-15_002',
#     'data_format': '.tdms',
#     'data_repository_pk': '05baa8e4-5eb5-4214-a008-c9e5331004b0',
#     'data_format_pk': '47bcdd69-8754-4045-ba05-0b59c9dba75b',
#     'revision_pk': None,
#     'dataset_type_pk': '6a98bba7-da9e-41d0-a5d7-44cb2715ae8d',
#     'session_pk': '08557158-4c86-4760-a5d3-30b2d0d9fc94',
#     'remote_root': '//157.99.138.167/cajal_data2/ONE/Adaptation',
#     'subject': 'wm32',
#     'date': '2023-06-15',
#     'number': 2,
#     'collection': 'intrinsic_optical_imaging',
#     'revision': '',
#     'object': 'imaging_intrinsic',
#     'attribute': 'delta_stim_images',
#     'extension': '.tdms',
#     'file_records': [{'id': '756a1c5a-a612-4b0d-9064-9621d078cbd7',
#       'relative_path': 'wm32/2023-06-15/002/intrinsic_optical_imaging/imaging_intrinsic.delta_stim_images.B1.tdms',
#       'extra': 'B1',
#       'exists': True,
#       'file_name': 'imaging_intrinsic.delta_stim_images.B1.tdms',
#       'hash': None},
#      {'id': '04a1bc8c-4430-4607-abe2-43dd19216a23',
#       'relative_path': 'wm32/2023-06-15/002/intrinsic_optical_imaging/imaging_intrinsic.delta_stim_images.C1.tdms',
#       'extra': 'C1',
#       'exists': True,
#       'file_name': 'imaging_intrinsic.delta_stim_images.C1.tdms',
#       'hash': None},
#      {'id': 'ae51993f-93a5-4fff-8631-7704f0d66d02',
#       'relative_path': 'wm32/2023-06-15/002/intrinsic_optical_imaging/imaging_intrinsic.delta_stim_images.D1.tdms',
#       'extra': 'D1',
#       'exists': True,
#       'file_name': 'imaging_intrinsic.delta_stim_images.D1.tdms',
#       'hash': None}]},
#    {'id': '0ac6c172-b253-4538-b970-1444d9cf9aac',
#     'url': 'http://127.0.0.1/datasets/0ac6c172-b253-4538-b970-1444d9cf9aac',
#     'admin_url': '/admin/data/dataset/0ac6c172-b253-4538-b970-1444d9cf9aac/change/',
#     'name': 'imaging_intrinsic.bin_delta_stim_images.binlv',
#     'created_by': 'tjostmou',
#     'created_datetime': '2023-07-07T15:37:23.537496+02:00',
#     'data_repository': 'Cajal2Adaptation',
#     'file_size': None,
#     'version': None,
#     'auto_datetime': '2023-07-07T15:37:23.539664+02:00',
#     'dataset_type': 'imaging_intrinsic.bin_delta_stim_images',
#     'default_dataset': True,
#     'tags': [],
#     'session': 'wm32_2023-06-15_002',
#     'data_format': '.binlv',
#     'data_repository_pk': '05baa8e4-5eb5-4214-a008-c9e5331004b0',
#     'data_format_pk': '0bd3fd51-5190-4102-a0cb-cd0e2898b3bc',
#     'revision_pk': None,
#     'dataset_type_pk': 'd7b6832a-a9b3-41b1-8296-6c5af9769af9',
#     'session_pk': '08557158-4c86-4760-a5d3-30b2d0d9fc94',
#     'remote_root': '//157.99.138.167/cajal_data2/ONE/Adaptation',
#     'subject': 'wm32',
#     'date': '2023-06-15',
#     'number': 2,
#     'collection': 'intrinsic_optical_imaging',
#     'revision': '',
#     'object': 'imaging_intrinsic',
#     'attribute': 'bin_delta_stim_images',
#     'extension': '.binlv',
#     'file_records': [{'id': '7c84bb24-110a-4632-901b-f3fe2678873c',
#       'relative_path': 'wm32/2023-06-15/002/intrinsic_optical_imaging/imaging_intrinsic.bin_delta_stim_images.B1.binlv',
#       'extra': 'B1',
#       'exists': True,
#       'file_name': 'imaging_intrinsic.bin_delta_stim_images.B1.binlv',
#       'hash': None},
#      {'id': 'c121e9e3-a43f-44ec-a9b3-b6494801a363',
#       'relative_path': 'wm32/2023-06-15/002/intrinsic_optical_imaging/imaging_intrinsic.bin_delta_stim_images.C1.binlv',
#       'extra': 'C1',
#       'exists': True,
#       'file_name': 'imaging_intrinsic.bin_delta_stim_images.C1.binlv',
#       'hash': None},
#      {'id': '8d296098-60e1-4c3a-9988-bbb0f0b3a60b',
#       'relative_path': 'wm32/2023-06-15/002/intrinsic_optical_imaging/imaging_intrinsic.bin_delta_stim_images.D1.binlv',
#       'extra': 'D1',
#       'exists': True,
#       'file_name': 'imaging_intrinsic.bin_delta_stim_images.D1.binlv',
#       'hash': None}]}],
#   'auto_datetime': '2023-06-27T17:15:41.535144+02:00',
#   'alias': 'wm32/2023-06-15/002',
#   'u_alias': 'wm32_2023-06-15_002',
#   'path': '//157.99.138.167/cajal_data2/ONE/Adaptation/wm32/2023-06-15/002',
#   'json': None,
#   'probe_insertion': [],
#   'notes': [],
#   'default_data_repository_path': '//157.99.138.167/cajal_data2/ONE/Adaptation',
#   'default_data_repository_name': 'Cajal2Adaptation',
#   'default_data_repository_pk': '05baa8e4-5eb5-4214-a008-c9e5331004b0',
#   'rel_path': 'wm32/2023-06-15/002',
#   'admin_url': '/admin/actions/session/08557158-4c86-4760-a5d3-30b2d0d9fc94/change/'},
#  {'id': '9e81e13f-bba4-4f0e-9a31-04d648228e2a',
#   'subject': 'wm32',
#   'users': ['wilsonmena'],
#   'location': 'Fernbach - 2p stim setup',
#   'procedures': ['Imaging simple signal check'],
#   'lab': 'HaissLab',
#   'projects': ['Adaptation'],
#   'type': None,
#   'task_protocol': '',
#   'number': 1,
#   'start_time': '2023-06-15T15:28:11+02:00',
#   'end_time': None,
#   'narrative': 'Vgat#29 / wm32\r\nchecking signal and blinking cells\r\nspontaneous activity',
#   'parent_session': None,
#   'n_correct_trials': None,
#   'n_trials': None,
#   'url': 'http://127.0.0.1/sessions/9e81e13f-bba4-4f0e-9a31-04d648228e2a',
#   'extended_qc': None,
#   'qc': 'NOT_SET',
#   'wateradmin_session_related': [],
#   'data_dataset_session_related': [],
#   'auto_datetime': '2023-10-12T17:31:30.826588+02:00',
#   'alias': 'wm32/2023-06-15/001',
#   'u_alias': 'wm32_2023-06-15_001',
#   'path': '//157.99.138.167/cajal_data2/ONE/Adaptation/wm32/2023-06-15/001',
#   'json': None,
#   'probe_insertion': [],
#   'notes': [],
#   'default_data_repository_path': '//157.99.138.167/cajal_data2/ONE/Adaptation',
#   'default_data_repository_name': 'Cajal2Adaptation',
#   'default_data_repository_pk': '05baa8e4-5eb5-4214-a008-c9e5331004b0',
#   'rel_path': 'wm32/2023-06-15/001',
#   'admin_url': '/admin/actions/session/9e81e13f-bba4-4f0e-9a31-04d648228e2a/change/'}]

# %%
class FileRecordSerializer(serializers.HyperlinkedModelSerializer):
    dataset = serializers.PrimaryKeyRelatedField(read_only=False, queryset=Dataset.objects.all())

    admin_url = serializers.SerializerMethodField()

    extra = serializers.CharField(required=False, allow_blank=True, max_length=255)

    exists = serializers.BooleanField(required=False, allow_null=True)

    hash = serializers.CharField(required=False, allow_null=True)

    @staticmethod
    def setup_eager_loading(queryset):
        """Perform necessary eager loading of data to avoid horrible performance."""
        queryset = queryset.select_related("dataset")
        return queryset

    def get_admin_url(self, obj):
        return get_admin_url(obj)

    class Meta:
        model = FileRecord
        fields = [
            "id",
            "url",
            "admin_url",
            "dataset",
            "json",
            "file_name",
            "full_path",
            "relative_path",
            "exists",
            "hash",
            # ALF parts :
            "remote_root",
            "attribute",
            "object",
            "extension",
            "revision",
            "collection",
            "subject",
            "date",
            "number",
            "extra",
        ]


class DataRepositorySerializer(serializers.HyperlinkedModelSerializer):
    repository_type = serializers.SlugRelatedField(
        read_only=False, slug_field="name", queryset=DataRepositoryType.objects.all(), allow_null=True, required=False
    )

    class Meta:
        model = DataRepository
        fields = ("id", "name", "timezone", "globus_path", "hostname", "data_path", "repository_type", "json")
        extra_kwargs = {"url": {"view_name": "datarepository-detail", "lookup_field": "name"}}

class DatasetFileRecordsSerializer(serializers.ModelSerializer):
    class Meta:
        model = FileRecord
        fields = ("id", "relative_path", "extra", "exists", "file_name", "hash")


class DatasetTypeSerializer(serializers.HyperlinkedModelSerializer):
    created_by = serializers.SlugRelatedField(
        read_only=False,
        slug_field="username",
        queryset=get_user_model().objects.all(),
        allow_null=True,
        required=False,
        default=serializers.CurrentUserDefault(),
    )

    admin_url = serializers.SerializerMethodField()

    def get_admin_url(self, obj):
        return get_admin_url(obj)

    class Meta:
        model = DatasetType
        fields = ("id", "name", "created_by", "description", "filename_pattern", "object", "attribute", "admin_url")
        extra_kwargs = {"url": {"view_name": "datasettype-detail", "lookup_field": "name"}}

    def create(self, validated_data):
        file_records_data = validated_data.pop("file_records", [])
        collection = validated_data.get("collection", None)
        dataset_type = validated_data.get("dataset_type", None)
        default = validated_data.get("default_dataset", None)
        session = validated_data.get("session", None)

        if session:
            if default:
                _change_default_dataset(session, collection, dataset_type)
                validated_data["default_dataset"] = True
            dataset = super().create(validated_data)
        else:
            subject = validated_data.pop("subject", None)
            date = validated_data.pop("date", None)
            number = validated_data.pop("number", None)
            if not subject or not date or not number:
                dataset = super().create(validated_data)
            else:
                user = validated_data.pop("created_by", None)
                session = _get_session(subject=subject, date=date, number=number, user=user)
                validated_data["session"] = session
                if default:
                    _change_default_dataset(session, collection, dataset_type)
                    validated_data["default_dataset"] = True
                dataset = super().create(validated_data)

        # Bulk create FileRecords
        file_records_instances = [
            FileRecord(dataset=dataset, **file_record_data) for file_record_data in file_records_data
        ]
        FileRecord.objects.bulk_create(file_records_instances, batch_size=500)

        return dataset



class FileRecordList(generics.ListCreateAPIView):
    """
    get: **FILTERS**

    -   **dataset**: dataset UUID: `/files?dataset=aad23144-0e52-4eac-80c5-c4ee2decb198`
    -   **exists**: Bool `/files?exists=False`
    -   **lab**: lab name `/files?lab=wittenlab`
    -   **globus_is_personal**: bool type of Globus endpoint `/files?globus_is_personal=True`

    [===> file record model reference](/admin/doc/models/data.filerecord)
    """

    queryset = FileRecord.objects.all()
    queryset = FileRecordSerializer.setup_eager_loading(queryset)
    serializer_class = FileRecordSerializer
    permission_classes = rest_permission_classes()
    filterset_class = FileRecordFilter


class FileRecordDetail(generics.RetrieveUpdateDestroyAPIView):
    queryset = FileRecord.objects.all()
    serializer_class = FileRecordSerializer
    permission_classes = rest_permission_classes()



class DatasetList(generics.ListCreateAPIView):
    """
    get: **FILTERS**
    -   **subject**: subject nickname: `/datasets?subject=Algernon`
    -   **lab**: lab name `/datsets?lab=wittenlab`
    -   **created_date**: dataset registration date `/datasets?created_date=2020-02-16`
    -   **date**: session start time date `/datasets?date=2020-02-16`
    -   **created_by**: lab member creation `/datasets?created_by=root`
    -   **experiment_number**: session number  `/datasets?experiment_number=1`
    -   **created_date_gte**: greater/equal creation date  `/datasets?created_date_gte=2020-02-16`
    -   **created_date_lte**: lower/equal creation date  `/datasets?created_date_lte=2020-02-16`
    -   **exists**: only returns datasets for which a file record exists or doesn't exit on a
    server repo (boolean)  `/datasets?exists=True`
    -   **probe_insertions**: probe insertion id '/datasets?probe_insertion=uuid
    -   **tag**: tag name '/datasets?tag=repeated_site
    -   **public**: only returns datasets that are public or not public
    -   **protected**: only returns datasets that are protected or not protected

    [===> dataset model reference](/admin/doc/models/data.dataset)
    """

    queryset = Dataset.objects.all()
    queryset = DatasetSerializer.setup_eager_loading(queryset)
    serializer_class = DatasetSerializer
    permission_classes = rest_permission_classes()
    filterset_class = DatasetFilter


class DatasetDetail(generics.RetrieveUpdateDestroyAPIView):
    queryset = Dataset.objects.all()
    serializer_class = DatasetSerializer
    permission_classes = rest_permission_classes()
class Dataset(BaseExperimentalData):
    """
    A chunk of data that is stored outside the database, most often a rectangular binary array.
    There can be multiple FileRecords for one Dataset, which will be different physical files,
    all having the same dataset-type.
    """

    objects = DatasetManager()

    file_size = models.BigIntegerField(blank=True, null=True, help_text="Size in bytes")
    # this shall be removed and moved to filerecord

    md5 = models.UUIDField(blank=True, null=True, help_text="MD5 hash of the data buffer")
    # this shall be removed and moved to filerecord

    hash = models.CharField(
        blank=True,
        null=True,
        max_length=64,
        help_text="Hash of the data buffer, SHA-1 is 40 hex chars, while md5is 32 hex chars",
    )
    # this shall be removed and moved to filerecord

    # here we usually refer to version as an algorithm version such as ibllib-1.4.2, scanimage X.watever...
    # This fild should not be too important, as the dataset-type content description should not be not too wide
    # (if new version => new content in the file, just create a new dataset type instead of packing tons of
    # possibilities inside one dataset-type)
    # and if changes in storage manner depending on version is made in a way that the most recent readers are
    # retrocompatible.
    version = models.CharField(
        blank=True,
        null=True,
        max_length=64,
        help_text="version of the algorithm generating the file",
    )

    # the collection is the subfolder(s) inside the session folder, where files will be located
    collection = models.CharField(
        blank=True,
        default="",
        max_length=255,
        help_text="file subcollection or subfolder",
    )

    data_repository = models.ForeignKey(
        "DataRepository",
        blank=True,
        null=True,
        on_delete=models.SET_NULL,
        help_text=(
            "The data repository of all the files of this dataset. If left blank, it will use the default data"
            " repository of the session"
        ),
    )

    dataset_type = models.ForeignKey(
        DatasetType,
        blank=False,
        null=False,
        on_delete=models.PROTECT,
        default=default_dataset_type,
    )

    data_format = models.ForeignKey(
        DataFormat,
        blank=False,
        null=False,
        on_delete=models.PROTECT,
        default=default_data_format,
    )

    revision = models.ForeignKey(Revision, blank=True, null=True, on_delete=models.SET_NULL)

    tags = models.ManyToManyField("data.Tag", blank=True, related_name="datasets")

    auto_datetime = models.DateTimeField(auto_now=True, blank=True, null=True, verbose_name="last updated")

    default_dataset = models.BooleanField(
        default=True, help_text="Whether this dataset is the default latest revision"
    )  # THIS SHOULD BE NAMED DEFAULT REVISIONS, NOT DEFAULT DATASET

    extras_description = models.CharField(
        blank=True,
        null=True,
        max_length=512,
        help_text=(
            "Description of what the extra refer to for all the files in this dataset. Should be null or one"
            " description "
        ),
    )

    @property
    def is_online(self):
        fr = self.file_records
        if fr:
            return all(
                fr.values_list("exists", flat=True)
            )  # If we want this to be somewhat usefull, it should be a field that is checked regularly
            # (each week let's say. If the amount of file is not crazy, maybe each day during night ?)
            # by a worker and files "existance" should be updated at that time.
            # This may be usefull to probe for user error (like a massive deletion) and be able to react fast before
            # the NAS backups are trashed.
        else:
            return False

    @property
    def is_protected(self):
        tags = self.tags.filter(protected=True)
        if tags.count() > 0:
            return True
        else:
            return False

    @property
    def is_public(self):
        tags = self.tags.filter(public=True)
        if tags.count() > 0:
            return True
        else:
            return False

    @property
    def object(self):
        return self.dataset_type.object

    @property
    def attribute(self):
        return self.dataset_type.attribute

    @property
    def extension(self):
        return self.data_format.file_extension

    @property
    def subject(self):
        return self.get_session_path(as_dict=True)["subject"]

    @property
    def date(self):
        return self.get_session_path(as_dict=True)["date"]

    @property
    def number(self):
        return self.get_session_path(as_dict=True)["number"]

    @property
    def remote_root(self):
        return self.data_repository.data_path

    def get_session_path(self, as_dict=False) -> str | dict:
        # returns wm29/2023-05-25/002
        session_path = self.session.alias
        if not as_dict:
            return session_path

        patt = r"(?P<subject>[\w-]+)(?:\/|\\)(?P<date>\d{4}-\d{2}-\d{2})(?:\/|\\)(?P<number>\d{1,3})"
        spec = re.compile(patt)
        match = spec.search(session_path)
        if match is None:
            raise AttributeError(
                f"Session {self.session} alias {session_path} doesn't match the subject/date/nb pattern"
            )
        return dict(zip(spec.groupindex.keys(), match.groups()))

    def __str__(self):
        date = self.created_datetime.strftime("%d/%m/%Y at %H:%M")
        return "<Dataset %s %s '%s' by %s on %s>" % (
            str(self.pk)[:8],
            getattr(self.dataset_type, "name", ""),
            self.name,
            self.created_by,
            date,
        )

    def save(self, *args, **kwargs):
        # when a dataset is saved / created make sure the probe insertion is set in the reverse m2m

        def sanitize_folders(folder_field):
            if folder_field is None:
                return (  # as it is a char field, we prefer saving an empty char rather than null
                    # when using no collection
                    ""
                )
            folder_field = folder_field.strip(".").strip("\\").strip("/")
            return folder_field if folder_field == "" else os.path.normpath(folder_field)

        self.collection = sanitize_folders(self.collection)

        if self.data_repository is None:
            if self.session.default_data_repository is None:
                self.data_repository = self.session.project.default_data_repository
            else:
                self.data_repository = self.session.default_data_repository

        query_set = self.__class__.objects.filter(
            dataset_type=self.dataset_type,
            session=self.session,
            collection=self.collection,
        )
        if self.id is not None:
            query_set = query_set.exclude(id=self.id)

        if query_set.count():
            raise ValidationError(
                "Two datasets for the same session with the same dataset type and collection cannot exist"
            )

        self.name = self.dataset_type.object + "." + self.dataset_type.attribute + self.data_format.file_extension

        super(Dataset, self).save(*args, **kwargs)

        # save childs file records to update the changed collection or dataset type, if necessary.
        file_records = FileRecord.objects.filter(dataset=self)

        for file_record in file_records:
            file_record.save()

        # if self.collection is None:
        #    return

        # from ..experiments.models import ProbeInsertion
        # I guess this is weird things for electrophy probe insertion features. Need to check if we want to remove it
        # (still in the process of having a clean version without too much weird intricacies)
        # parts = self.collection.rsplit('/')
        # if len(parts) > 1:
        #    name = parts[1]
        #    pis = ProbeInsertion.objects.filter(session=self.session, name=name)
        #    if len(pis):
        #        self.probe_insertion.set(pis.values_list('pk', flat=True))

    @staticmethod
    def human_field_string():
        return "nickname"


# Files
# ------------------------------------------------------------------------------------------------
class FileRecordManager(models.Manager):
    def get_queryset(self):
        qs = super(FileRecordManager, self).get_queryset()
        qs = qs.select_related("dataset__data_repository")
        return qs


class FileRecord(BaseModel):
    """
    A single file on disk or tape. Normally specified by a path within an archive. If required,
    more details can be in the JSON
    """

    objects = FileRecordManager()

    dataset = models.ForeignKey(Dataset, related_name="file_records", on_delete=models.CASCADE)

    extra = models.CharField(
        blank=True,
        null=True,
        max_length=255,
        db_column="extras",  # adding this to migrate from "extra" to extra without having to copy/delete the column
        # https://stackoverflow.com/questions/3498140/migrating-django-model-field-name-change-without-losing-data
        help_text=(
            "extra of the file, separated by '.' or null if no extra. Example : pupil.00001. Null will be converted to"
            " '' internally"
        ),
    )

    exists = models.BooleanField(
        default=False,
        help_text="Whether the file exists in the data repository",
    )

    relative_path = models.CharField(blank=True, default="", max_length=1000, help_text="path name within repository")

    hash = models.CharField(
        blank=True,
        null=True,
        max_length=64,
        help_text="Hash of the data buffer, SHA-1 is 40 hex chars, while md5is 32 hex chars",
    )

    # METHODS RECALCULATING FROM SOURCES INSTEAD OF USING SAVED VERSIONS. USE FOR SAVING / UPDATING / SERIALIZING
    # EXAMPLE to illustrate all conditions below :
    # The file record is named
    # //cajal/cajal_data2/ONE/Adaptation/wm29/2023-05-25/002/trials/test_folder/trials.eventTimeline.special.001.tdms

    # @cached_property cached property cannot work with methods needing arguments
    def get_session_path(self, as_dict=False) -> str | dict:
        # returns wm29/2023-05-25/002
        session_path = self.dataset.session.alias
        if not as_dict:
            return session_path

        patt = r"(?P<subject>[\w-]+)(?:\/|\\)(?P<date>\d{4}-\d{2}-\d{2})(?:\/|\\)(?P<number>\d{1,3})"
        spec = re.compile(patt)
        match = spec.search(session_path)
        if match is None:
            raise AttributeError(
                f"Session {self.dataset.session} alias {session_path} doesn't match the subject/date/nb pattern"
            )
        return dict(zip(spec.groupindex.keys(), match.groups()))

    def get_relative_path(
        self,
    ):  # THIS IN THE ONLY FIELD THAT IS SAVED IN THE MODEL TABLE,FOR CHECKING THAT NO FILES HAVING THE SAME NAME
        # EXISTS FOR A GIVEN SESSION
        # returns for ex : wm29/2023-05-25/002/trials/test_folder/trials.eventTimeline.special.001.tdms
        return os.path.join(
            self.get_session_path(),
            self.collection,
            self.get_revision(with_hash=True),
            self.file_name,
        )

    def get_extra(self, with_dot=False):
        # returns .special.001
        dot = "." if with_dot else ""
        return dot + self.extra if (self.extra is not None and self.extra != "") else ""

    def get_revision(self, with_hash=False):
        if with_hash:
            return self.dataset.revision.hashed if self.dataset.revision is not None else ""
        return self.dataset.revision.name if self.dataset.revision is not None else ""

    @property
    def subject(self):
        return self.get_session_path(as_dict=True)["subject"]

    @property
    def date(self):
        return self.get_session_path(as_dict=True)["date"]

    @property
    def number(self):
        return self.get_session_path(as_dict=True)["number"]

    # CALCULATED FIELDS, FOR SERIALIZING
    @property
    def collection(self):
        return self.dataset.collection if self.dataset.collection is not None else ""

    @property
    def revision(self):
        return self.get_revision()

    @property
    def object(self):
        return self.dataset.object

    @property
    def attribute(self):
        return self.dataset.attribute

    @property
    def extension(self):
        return self.dataset.data_format.file_extension

    @property
    def session_path(self):
        return self.get_session_path()

    @property  # THIS IS THE CALCULATED FIELD (not kept inside the base) of the full filename on the remote location
    # only. Use relative_path to build a local path.
    def full_path(self):
        return os.path.join(self.remote_root, self.get_relative_path())

    @property
    def remote_root(self):
        return self.dataset.data_repository.data_path

    @property  # THIS IS THE CALCULATED FIELD (not kept inside the base) of the full filename on the remote location
    # only. Use relative_path to build a local path.
    def file_name(self):
        return self.object + "." + self.attribute + self.get_extra(with_dot=True) + self.extension

    def save(self, *args, **kwargs):
        # check how to run this on change in data repository related, or
        # dataset collection related or
        # session related ?
        """this is to trigger the update of the auto-date field"""

        # self.file_name = self.get_filename()
        # self.relative_path = self.get_relative_path()

        self.extra = self.get_extra()
        self.relative_path = self.get_relative_path()

        query_set = self.__class__.objects.filter(relative_path=self.relative_path)
        if self.id is not None:
            query_set = query_set.exclude(id=self.id)
        if query_set.count():
            raise ValidationError("Two files with the same session relative path cannot exist")

        super(FileRecord, self).save(*args, **kwargs)
        # Save the dataset as well to make sure the auto datetime in the dateset is updated when
        # associated file record is saved
        # self.dataset.save()

    def __str__(self):
        return "<FileRecord '%s' by %s>" % (self.relative_path, self.dataset.created_by)



It is quite long (several seconds, up to 10 or 30 for creating approximately 1200 files, and up to 1 / 2 seconds to get 1200 files)
to get serialized list of existing entries (get) / Creating new entries in dataset and then filrecords (put) 
from serialized data for a session that contains multimle datasets and  that themselves contain multiple filerecords.
How to make it faster ? Please explain and provide solutions that don't break to much things

# %%
connector.web_client.endpoint("dataset-types").actions["retrieve"].operation.parameters[0].required
# Out:
# True

# %%
connector.web_client.endpoint("dataset-types").actions["retrieve"].operation.parameters[0]
# Out:
# Parameter(name='name', location=<ParameterLocation.PATH: 'path'>, schema=String(type=<DataType.STRING: 'string'>, title=None, enum=[], example=None, description=None, default=None, nullable=False, read_only=False, write_only=False, deprecated=False, extensions={}, max_length=None, min_length=None, pattern=None, format=None), content=None, required=True, description=None, deprecated=False, style=<PathParameterStyle.SIMPLE: 'simple'>, explode=False, extensions={})

# %%
connector.search(endpoint="dataset-types")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:207, in Operateur.make_url(self, **kwargs)
#     206 try:
# --> 207     return self.path.make_url(**kwargs)
#     208 except ValueError as e:
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:116, in EndpointUrl.make_url(self, fragment, **kwargs)
#     112 query_dict, requirements_dict = self.separate_query_and_requirements(**kwargs)
#     113 url = UrlValidator.urlunparse(
#     114     protocol=self.client.protocol,  # http or https
#     115     netloc=self.client.netloc,  # netloc = host+port
# --> 116     path=self.finalized_path(**requirements_dict),  # path
#     117     query_string=self.make_query_string(query_dict),  # querystring example : ?thing=truc
#     118     fragment=fragment,  # basically an anchor, fragment example : #title1
#     119 )
#     120 return url
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:126, in EndpointUrl.finalized_path(self, **requirements_dict)
#     125 if (requirement_value := requirements_dict.get(requirement)) is None:
# --> 126     raise ValueError(f"You must provide a {requirement} keyword argument with the path {self}")
#     127 path = path.replace(f"{{{requirement}}}", str(requirement_value))
#
# ValueError: You must provide a name keyword argument with the path /dataset-types/{name}
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 connector.search(endpoint="dataset-types")
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\connector\core.py:80, in Connector.search(self, endpoint, id, details, **kwargs)
#      77 search_result = self.raise_if_search_empty(search_result)
#      79 if details and not id and endpoint_implements_retrieve:
# ---> 80     search_result = self.details_aggregation(search_result, endpoint)  # type: ignore
#      82 return self.results_to_pandas(search_result)
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\connector\core.py:151, in Connector.details_aggregation(self, search_result, endpoint)
#     147 detailed_results = []
#     148 for result in tqdm(
#     149     search_result, total=len(search_result), delay=2, desc=f"Loading {endpoint} details", file=stdout
#     150 ):
# --> 151     detailed_results.append(self.web_client.rest(endpoint, "retrieve", id=result["id"]))
#     152 return detailed_results
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\clients.py:97, in Client.rest(self, endpoint_name, action, timeout, **kwargs)
#      89 def rest(
#      90     self,
#      91     endpoint_name: str,
#    (...)     94     **kwargs,
#      95 ):
#      96     operateur = self.path(endpoint_name).endpoint.assert_exists().actions[action]
# ---> 97     return Request(self, operateur, timeout=timeout, **kwargs).handle()
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:299, in Request.handle(self)
#     298 def handle(self):
# --> 299     return self.handle_response(self.get_response())
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:292, in Request.get_response(self)
#     290 data = self.get_data()
#     291 files = self.get_files()
# --> 292 logger.debug(f"Sending a request with url={self.url}, headers={self.headers}")
#     293 r = self.request_method(
#     294     self.url, stream=True, headers=self.headers, data=data, files=files, timeout=self.timeout
#     295 )
#     296 return r
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:272, in Request.url(self)
#     270 @property
#     271 def url(self):
# --> 272     return self.operateur.make_url(**self.url_arguments)
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:209, in Operateur.make_url(self, **kwargs)
#     207     return self.path.make_url(**kwargs)
#     208 except ValueError as e:
# --> 209     raise ValueError(f"For the {self.action_name} action, " + str(e)) from e
#
# ValueError: For the retrieve action, You must provide a name keyword argument with the path /dataset-types/{name}

# %%
Config()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 Config()
#
# File ~\Documents\Python\__packages__\ONE-registrator\alyx_registrator\registration.py:692, in Config.__init__(self, rules_path, connector)
#     688 self.excluded_filenames = rules_config.get("excluded_filenames", [])
#     690 self.cleanup_folders = rules_config.get("cleanup_folders", [])
# --> 692 self.dataset_types = get_existing_datasets(connector)
#     693 if len(self.dataset_types) == 0:
#     694     raise ValueError(
#     695         "dataset_types is empty. Cannot register any dataset if no dataset type exists. Maybe one's connector"
#     696         " has a problem ?"
#     697     )
#
# File ~\Documents\Python\__packages__\ONE-registrator\alyx_registrator\utils.py:22, in get_existing_datasets(one_connector)
#      21 def get_existing_datasets(one_connector: Connector):
# ---> 22     existing_dst = one_connector.rest("dataset-types", "list", no_cache=True)
#      23     existing_types = [
#      24         dst["object"] + "." + dst["attribute"]
#      25         for dst in existing_dst
#      26         if dst["attribute"] != "" and dst["attribute"] != ""
#      27     ]
#      28     return existing_types
#
# AttributeError: 'Connector' object has no attribute 'rest'

# %%
from pathlib import Path

root = Path(r"\\cajal\cajal_data2\ONE\Adaptation\wm42\2025-03-27\003")


test = [ File.from_path(dir / file) for dir, folder, files in root.walk() for file in files]

# %%
Path("C:/test") == Path("C:/test")
# Out:
# True

# %%
connector.web_client.endpoint("dataset-types").actions.keys()
# Out:
# dict_keys(['list', 'create', 'retrieve', 'update', 'destroy'])

# %%
connector.web_client.rest("dataset-types", "list")
# Out:
# [{'id': '5ec9b957-d0b8-4343-8d32-e2bc40ce4c5d',
#   'name': 'audio_cues.times_mic',
#   'created_by': None,
#   'description': 'GoCue Times extracted from microphone data (s)',
#   'filename_pattern': '_iblmic_audioonsetgocue.times_mic.*',
#   'object': 'audio_cues',
#   'attribute': 'times_mic',
#   'admin_url': '/admin/data/datasettype/5ec9b957-d0b8-4343-8d32-e2bc40ce4c5d/change/'},
#  {'id': '6c784577-b1a4-4008-9851-27a70907df9b',
#   'name': 'behaviour.camera_settings',
#   'created_by': 'tjostmou',
#   'description': 'Camera settings for behaviour cameras. Usually in text file format, but can also be in other formats',
#   'filename_pattern': '',
#   'object': 'behaviour',
#   'attribute': 'camera_settings',
#   'admin_url': '/admin/data/datasettype/6c784577-b1a4-4008-9851-27a70907df9b/change/'},
#  {'id': 'e37eec5d-60be-4bdb-9c57-07fe17546459',
#   'name': 'behaviour.video',
#   'created_by': 'tjostmou',
#   'description': 'Behaviour videos',
#   'filename_pattern': 'behaviour.video.*',
#   'object': 'behaviour',
#   'attribute': 'video',
#   'admin_url': '/admin/data/datasettype/e37eec5d-60be-4bdb-9c57-07fe17546459/change/'},
#  {'id': '40e4bcfd-da44-485f-823e-ccdc267c1543',
#   'name': 'behaviour.video_compressed',
#   'created_by': 'tjostmou',
#   'description': 'Behaviour video file that have been compressed to a standard format (avi, mp4, etc)',
#   'filename_pattern': '',
#   'object': 'behaviour',
#   'attribute': 'video_compressed',
#   'admin_url': '/admin/data/datasettype/40e4bcfd-da44-485f-823e-ccdc267c1543/change/'},
#  {'id': '72f2bbae-713b-446f-a518-c7a4d5659a98',
#   'name': 'behaviour.video_compressed_meta',
#   'created_by': 'tjostmou',
#   'description': "Video compresssed metadata (if the standard video format such as .avi, .mp4 etc doesn't allow to specify some informations that where in the original raw data format)",
#   'filename_pattern': '',
#   'object': 'behaviour',
#   'attribute': 'video_compressed_meta',
#   'admin_url': '/admin/data/datasettype/72f2bbae-713b-446f-a518-c7a4d5659a98/change/'},
#  {'id': 'ffe43f90-d13f-42ad-b2c9-38603a9a5439',
#   'name': 'camera.dlc',
#   'created_by': None,
#   'description': 'Raw DLC output for Camera as numpy array',
#   'filename_pattern': '*camera.dlc.*',
#   'object': 'camera',
#   'attribute': 'dlc',
#   'admin_url': '/admin/data/datasettype/ffe43f90-d13f-42ad-b2c9-38603a9a5439/change/'},
#  {'id': '49adb321-17d3-43e5-8cf6-672236b0c345',
#   'name': 'camera.features',
#   'created_by': None,
#   'description': 'Contains features calculated from DLC traces, currently pupilDiameter_raw, pupilDiameter_smooth',
#   'filename_pattern': '*camera.features.*',
#   'object': 'camera',
#   'attribute': 'features',
#   'admin_url': '/admin/data/datasettype/49adb321-17d3-43e5-8cf6-672236b0c345/change/'},
#  {'id': '9ded820c-130d-4193-b279-ba167043acde',
#   'name': 'camera.ROIMotionEnergy',
#   'created_by': None,
#   'description': 'Motion energy across camera frames calculated within ROI (motionEnergy.position)',
#   'filename_pattern': '*camera.roimotionenergy.*',
#   'object': 'camera',
#   'attribute': 'ROIMotionEnergy',
#   'admin_url': '/admin/data/datasettype/9ded820c-130d-4193-b279-ba167043acde/change/'},
#  {'id': '8f36fa46-3fbc-4921-be8d-89f838c4ec42',
#   'name': 'camera.times',
#   'created_by': None,
#   'description': 'Synchronized time stamps for camera',
#   'filename_pattern': '*camera.times.*',
#   'object': 'camera',
#   'attribute': 'times',
#   'admin_url': '/admin/data/datasettype/8f36fa46-3fbc-4921-be8d-89f838c4ec42/change/'},
#  {'id': '08bde7fe-82bd-4697-8cf7-f1ee28467f34',
#   'name': 'channels.brainLocationIds_ccf_2017',
#   'created_by': None,
#   'description': 'Brain location id of channels following ephys alignment obtained from 25um resolution 2017 Allen Common Coordinate Framework',
#   'filename_pattern': 'channels.brainlocationids*.npy',
#   'object': 'channels',
#   'attribute': 'brainLocationIds_ccf_2017',
#   'admin_url': '/admin/data/datasettype/08bde7fe-82bd-4697-8cf7-f1ee28467f34/change/'},
#  {'id': '59c557be-7310-4c80-8bf8-51ef7c959dcf',
#   'name': 'channels.localCoordinates',
#   'created_by': None,
#   'description': 'relative to probe coordinate system (µm): x (first) dimension is on the width of the shank while (y) is the depth where 0 is the deepest site, and positive above this.',
#   'filename_pattern': 'channels.localcoordinates*.npy',
#   'object': 'channels',
#   'attribute': 'localCoordinates',
#   'admin_url': '/admin/data/datasettype/59c557be-7310-4c80-8bf8-51ef7c959dcf/change/'},
#  {'id': '5d2986b7-4ca7-44a2-8a9d-0df8dbf4b7be',
#   'name': 'channels.mlapdv',
#   'created_by': None,
#   'description': '3d location of the channels relative to bregma following ephys alignment - mediolateral; anterior-posterior; dorsoventral coordinates (um)',
#   'filename_pattern': 'channels.mlapdv.npy',
#   'object': 'channels',
#   'attribute': 'mlapdv',
#   'admin_url': '/admin/data/datasettype/5d2986b7-4ca7-44a2-8a9d-0df8dbf4b7be/change/'},
#  {'id': '6e777a97-f1f4-4cab-8c57-80ef5c7c7841',
#   'name': 'channels.probes',
#   'created_by': None,
#   'description': 'Probe assignments for each channel (integers counting from 0). Can be used as direct indexing for the probes.* attributes.',
#   'filename_pattern': 'channels.probes*.npy',
#   'object': 'channels',
#   'attribute': 'probes',
#   'admin_url': '/admin/data/datasettype/6e777a97-f1f4-4cab-8c57-80ef5c7c7841/change/'},
#  {'id': '9464bcd6-be30-4180-876a-93625c79977d',
#   'name': 'channels.rawInd',
#   'created_by': None,
#   'description': "[nch] Each channel's row in its home file (look up via probes.rawFileName), counting from zero. Note some rows don't have a channel, for example if they were sync pulses",
#   'filename_pattern': 'channels.rawind*.npy',
#   'object': 'channels',
#   'attribute': 'rawInd',
#   'admin_url': '/admin/data/datasettype/9464bcd6-be30-4180-876a-93625c79977d/change/'},
#  {'id': '28440e6f-5809-46e8-9a18-ee79c5f1aea4',
#   'name': 'clusters.amps',
#   'created_by': None,
#   'description': 'Mean amplitude of each cluster (V)',
#   'filename_pattern': 'clusters.amps*.npy',
#   'object': 'clusters',
#   'attribute': 'amps',
#   'admin_url': '/admin/data/datasettype/28440e6f-5809-46e8-9a18-ee79c5f1aea4/change/'},
#  {'id': '0916d181-94af-43a6-87b3-b499f940d424',
#   'name': 'clusters.brainLocationAcronyms_ccf_2017',
#   'created_by': None,
#   'description': 'Brain location acronym of clusters following ephys alignment obtained from 25um resolution 2017 Allen Common Coordinate Framework',
#   'filename_pattern': 'clusters.brainlocationacronyms*.npy',
#   'object': 'clusters',
#   'attribute': 'brainLocationAcronyms_ccf_2017',
#   'admin_url': '/admin/data/datasettype/0916d181-94af-43a6-87b3-b499f940d424/change/'},
#  {'id': 'f075a694-20f3-422a-86a5-577e3d34fa27',
#   'name': 'clusters.brainLocationIds_ccf_2017',
#   'created_by': None,
#   'description': 'Brain location id of clusters following ephys alignment obtained from 25um resolution 2017 Allen Common Coordinate Framework',
#   'filename_pattern': 'clusters.brainlocationids*.npy',
#   'object': 'clusters',
#   'attribute': 'brainLocationIds_ccf_2017',
#   'admin_url': '/admin/data/datasettype/f075a694-20f3-422a-86a5-577e3d34fa27/change/'},
#  {'id': 'fedf27ea-6428-4b14-bdf5-3863c9901a48',
#   'name': 'clusters.channels',
#   'created_by': None,
#   'description': "Channel which has the largest amplitude for this cluster. Note this counts all channels in the whole recording (starting from zero), rather than just the channels on this cluster's home probe - so if you want to find this cluster's brain location, it would be channels.brainLocation[clusters.peakChannel[i],:]",
#   'filename_pattern': 'clusters.channels*.npy',
#   'object': 'clusters',
#   'attribute': 'channels',
#   'admin_url': '/admin/data/datasettype/fedf27ea-6428-4b14-bdf5-3863c9901a48/change/'},
#  {'id': 'e154b9c5-81d7-4de1-96d3-e5372a325939',
#   'name': 'clusters.depths',
#   'created_by': None,
#   'description': '[nc] Depth of mean cluster waveform on probe (µm). 0 means deepest site, positive means above this.',
#   'filename_pattern': 'clusters.depths*.npy',
#   'object': 'clusters',
#   'attribute': 'depths',
#   'admin_url': '/admin/data/datasettype/e154b9c5-81d7-4de1-96d3-e5372a325939/change/'},
#  {'id': 'e71eae26-10ff-469a-a515-690791456df8',
#   'name': 'clusters.metrics',
#   'created_by': None,
#   'description': 'Quality control metrics at the cluster level. Fields may vary.',
#   'filename_pattern': 'clusters.metrics*.pqt',
#   'object': 'clusters',
#   'attribute': 'metrics',
#   'admin_url': '/admin/data/datasettype/e71eae26-10ff-469a-a515-690791456df8/change/'},
#  {'id': '36605ac4-eb3c-4748-888f-02a14b6b86a1',
#   'name': 'clusters.mlapdv',
#   'created_by': None,
#   'description': '3d location of the cluster relative to bregma following ephys alignment - mediolateral; anterior-posterior; dorsoventral coordinates (um)',
#   'filename_pattern': 'clusters.mlapdv.npy',
#   'object': 'clusters',
#   'attribute': 'mlapdv',
#   'admin_url': '/admin/data/datasettype/36605ac4-eb3c-4748-888f-02a14b6b86a1/change/'},
#  {'id': '856ad907-da77-4182-9a34-5eb02b217f2c',
#   'name': 'clusters.peakToTrough',
#   'created_by': None,
#   'description': 'Waveforms length in ms',
#   'filename_pattern': 'clusters.peaktotrough*.npy',
#   'object': 'clusters',
#   'attribute': 'peakToTrough',
#   'admin_url': '/admin/data/datasettype/856ad907-da77-4182-9a34-5eb02b217f2c/change/'},
#  {'id': 'f91db8df-ebdc-448a-9ba2-7b2d003f0c3d',
#   'name': 'clusters.probes',
#   'created_by': None,
#   'description': 'Probe assignments for each cluster (integers counting from 0). Can be used as direct indexing for the probes.* attributes.',
#   'filename_pattern': 'clusters.probes*.npy',
#   'object': 'clusters',
#   'attribute': 'probes',
#   'admin_url': '/admin/data/datasettype/f91db8df-ebdc-448a-9ba2-7b2d003f0c3d/change/'},
#  {'id': '334ac31e-49e2-480f-b1b3-661e4fae7bb2',
#   'name': 'clusters.uuids',
#   'created_by': None,
#   'description': 'Unique identifier assigned to each cluster when ALF files created and during manual curation.',
#   'filename_pattern': 'clusters.uuids*.csv',
#   'object': 'clusters',
#   'attribute': 'uuids',
#   'admin_url': '/admin/data/datasettype/334ac31e-49e2-480f-b1b3-661e4fae7bb2/change/'},
#  {'id': '93caf4ac-c39d-4723-aaac-d67123f687e4',
#   'name': 'clusters.waveforms',
#   'created_by': None,
#   'description': 'Waveform from spike sorting templates (stored as a sparse array, only for a subset of channels closest to the peak channel)',
#   'filename_pattern': 'clusters.waveforms.npy',
#   'object': 'clusters',
#   'attribute': 'waveforms',
#   'admin_url': '/admin/data/datasettype/93caf4ac-c39d-4723-aaac-d67123f687e4/change/'},
#  {'id': '0a79262d-9bc9-46d3-90ca-f53058448fdf',
#   'name': 'clusters.waveformsChannels',
#   'created_by': None,
#   'description': 'Index of channels that are stored for each cluster waveform. Sorted by increasing distance from the maximum amplitude channel.',
#   'filename_pattern': 'clusters.waveformschannels*.npy',
#   'object': 'clusters',
#   'attribute': 'waveformsChannels',
#   'admin_url': '/admin/data/datasettype/0a79262d-9bc9-46d3-90ca-f53058448fdf/change/'},
#  {'id': '3f075b50-df21-4eac-9ddd-4b750663e47c',
#   'name': 'DAQdata.raw',
#   'created_by': None,
#   'description': "The output of the DAQ software for a given device.  The namespace should identify the DAQ model, e.g. 'mcc', 'ni' or 'ni-usb-6211'.",
#   'filename_pattern': '_*_daqdata.raw*',
#   'object': 'DAQdata',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/3f075b50-df21-4eac-9ddd-4b750663e47c/change/'},
#  {'id': '24269ec5-687d-4b1d-ad12-3d7a6c474eb5',
#   'name': 'DAQdata.wiring',
#   'created_by': None,
#   'description': 'A map of the channel IDs and their corresponding device label, e.g. {ai1: bpod}.',
#   'filename_pattern': '_*_daqdata.wiring*',
#   'object': 'DAQdata',
#   'attribute': 'wiring',
#   'admin_url': '/admin/data/datasettype/24269ec5-687d-4b1d-ad12-3d7a6c474eb5/change/'},
#  {'id': '3389350b-bdab-4bcd-a76d-6568dd930bc5',
#   'name': 'drift_depths.um',
#   'created_by': None,
#   'description': 'For non-rigid registration, depth corresponding to each of the drift matrix column (um)',
#   'filename_pattern': 'drift_depths.um.npy',
#   'object': 'drift_depths',
#   'attribute': 'um',
#   'admin_url': '/admin/data/datasettype/3389350b-bdab-4bcd-a76d-6568dd930bc5/change/'},
#  {'id': '958e0b17-b739-41ff-8f35-00e854eb53cf',
#   'name': 'drift.times',
#   'created_by': None,
#   'description': 'Time of the probe corresponding to each of the drift matrix row (secs)',
#   'filename_pattern': 'drift.times.npy',
#   'object': 'drift',
#   'attribute': 'times',
#   'admin_url': '/admin/data/datasettype/958e0b17-b739-41ff-8f35-00e854eb53cf/change/'},
#  {'id': 'fb0bf47d-e393-4c32-bac7-69076140f7af',
#   'name': 'drift.um',
#   'created_by': None,
#   'description': 'Result of the drift registration. 1D vector of drift estimation in um. A cell moving downwards relative to the probe will show as negative drift (ie. it overlays on the raster). For non-rigid drift, 2D vector where the first dimension corresponds to the time of the estimation and the second dimension to the depth of the estimate (see the scale datasets)',
#   'filename_pattern': 'drift.um.npy',
#   'object': 'drift',
#   'attribute': 'um',
#   'admin_url': '/admin/data/datasettype/fb0bf47d-e393-4c32-bac7-69076140f7af/change/'},
#  {'id': 'e1cda381-5a32-4f76-927b-43bb7fbfc874',
#   'name': 'electrodeSites.brainLocationIds_ccf_2017',
#   'created_by': None,
#   'description': 'Brain location id of channels following ephys alignment obtained from 25um resolution 2017 Allen Common Coordinate Framework - straight mapping to the raw electrophysiology binary file channels.',
#   'filename_pattern': 'electrodesites.brainlocationids_ccf_2017*.npy',
#   'object': 'electrodeSites',
#   'attribute': 'brainLocationIds_ccf_2017',
#   'admin_url': '/admin/data/datasettype/e1cda381-5a32-4f76-927b-43bb7fbfc874/change/'},
#  {'id': '828c691b-1f94-4454-9477-a29e2e445b27',
#   'name': 'electrodeSites.localCoordinates',
#   'created_by': None,
#   'description': 'Location of each channel relative to probe coordinate system (µm): (first) dimension is on the width of the shank; Second is the depth where 0 is the deepest site, and positive above this. Straight mapping to the raw electrophysiology binary files',
#   'filename_pattern': 'electrodesites.localcoordinates*.npy',
#   'object': 'electrodeSites',
#   'attribute': 'localCoordinates',
#   'admin_url': '/admin/data/datasettype/828c691b-1f94-4454-9477-a29e2e445b27/change/'},
#  {'id': 'e9d47477-f4ee-4421-b2d0-817e7e889521',
#   'name': 'electrodeSites.mlapdv',
#   'created_by': None,
#   'description': '3d location of the channels relative to bregma following ephys alignment - mediolateral; anterior-posterior; dorsoventral coordinates (um) straight mapping to the raw electrophysiology binary file channels',
#   'filename_pattern': 'electrodesites.mlapdv*.npy',
#   'object': 'electrodeSites',
#   'attribute': 'mlapdv',
#   'admin_url': '/admin/data/datasettype/e9d47477-f4ee-4421-b2d0-817e7e889521/change/'},
#  {'id': '2aba753c-0316-44e7-ad54-b42c81a99349',
#   'name': 'ephysData.raw_ap',
#   'created_by': 'tjostmou',
#   'description': 'Action Potentials band of raw neurophysiology data - mtscomp compressed',
#   'filename_pattern': 'ephysdata.ap_cbin*',
#   'object': 'ephysData',
#   'attribute': 'raw_ap',
#   'admin_url': '/admin/data/datasettype/2aba753c-0316-44e7-ad54-b42c81a99349/change/'},
#  {'id': 'd0d22f62-1c16-435c-a437-c82474c42100',
#   'name': 'ephysData.raw_lowfband',
#   'created_by': 'tjostmou',
#   'description': 'Low Field band of raw neurophysiology data - mtscomp compressed',
#   'filename_pattern': '*ephysdata.lf_cbin',
#   'object': 'ephysData',
#   'attribute': 'raw_lowfband',
#   'admin_url': '/admin/data/datasettype/d0d22f62-1c16-435c-a437-c82474c42100/change/'},
#  {'id': 'f9f6df39-52af-4818-a502-845489d671f4',
#   'name': 'ephysData.raw_meta',
#   'created_by': 'tjostmou',
#   'description': 'Metadata text file for raw binary neurophysiology data',
#   'filename_pattern': '*ephysdata*.meta',
#   'object': 'ephysData',
#   'attribute': 'raw_meta',
#   'admin_url': '/admin/data/datasettype/f9f6df39-52af-4818-a502-845489d671f4/change/'},
#  {'id': '993e04d9-33f4-42c1-b665-3a39da26c72b',
#   'name': 'ephysData.raw_nidaq',
#   'created_by': 'tjostmou',
#   'description': 'Nidq breakout box binary data for Neuropixel 3B system - mtscomp compressed',
#   'filename_pattern': 'ephysdata.nidq_cbin',
#   'object': 'ephysData',
#   'attribute': 'raw_nidaq',
#   'admin_url': '/admin/data/datasettype/993e04d9-33f4-42c1-b665-3a39da26c72b/change/'},
#  {'id': '05981c26-6f62-4bb6-af22-745f9751c7be',
#   'name': 'ephysData.raw_sync',
#   'created_by': 'tjostmou',
#   'description': 'Synchronization file for multi-probes acquisitions.',
#   'filename_pattern': '*ephysdata*.sync.npy',
#   'object': 'ephysData',
#   'attribute': 'raw_sync',
#   'admin_url': '/admin/data/datasettype/05981c26-6f62-4bb6-af22-745f9751c7be/change/'},
#  {'id': '9e77de1e-b20b-4a84-b372-2c20907f95b6',
#   'name': 'ephysData.raw_timestamps',
#   'created_by': 'tjostmou',
#   'description': '2 columns file containing time synchronisation information for the AP binary file: sample index in the first column and session time in the second column. Note that sample indices may not be integers.',
#   'filename_pattern': '*ephysdata*.timestamps.npy',
#   'object': 'ephysData',
#   'attribute': 'raw_timestamps',
#   'admin_url': '/admin/data/datasettype/9e77de1e-b20b-4a84-b372-2c20907f95b6/change/'},
#  {'id': '524bc84c-bf31-481f-b9f7-73e87090bd39',
#   'name': 'ephysData.raw_wiring',
#   'created_by': 'tjostmou',
#   'description': 'Description of wiring of synchronization auxiliaries',
#   'filename_pattern': '*ephysdata*.wiring.json',
#   'object': 'ephysData',
#   'attribute': 'raw_wiring',
#   'admin_url': '/admin/data/datasettype/524bc84c-bf31-481f-b9f7-73e87090bd39/change/'},
#  {'id': '9d9f66f2-a783-46a7-ad03-1cad8aa7b4ab',
#   'name': 'extraRewards.times',
#   'created_by': None,
#   'description': 'Times of extra rewards',
#   'filename_pattern': '*extrarewards.times.*',
#   'object': 'extraRewards',
#   'attribute': 'times',
#   'admin_url': '/admin/data/datasettype/9d9f66f2-a783-46a7-ad03-1cad8aa7b4ab/change/'},
#  {'id': '9f117025-7dc7-4f9e-883c-c6caee7166cd',
#   'name': 'fpData.channels',
#   'created_by': None,
#   'description': 'Frame flag value for each LED channel [OFF, L415, L470, L560].  Each row corresponds to a different labelled condition.  See user manual at https://neurophotometrics.com/documentation',
#   'filename_pattern': '*fpdata.channels.*',
#   'object': 'fpData',
#   'attribute': 'channels',
#   'admin_url': '/admin/data/datasettype/9f117025-7dc7-4f9e-883c-c6caee7166cd/change/'},
#  {'id': '6a396eaa-7358-4df2-a793-b0aa6fe611ba',
#   'name': 'fpData.raw',
#   'created_by': None,
#   'description': 'Raw FP data dataframe containing fluorescence data for every active channel (max: isosbestic, red and green) as well as information of coactive components with each frame (E.g TTL syncing pulse).',
#   'filename_pattern': '_*_fpdata.raw*',
#   'object': 'fpData',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/6a396eaa-7358-4df2-a793-b0aa6fe611ba/change/'},
#  {'id': '57316c04-1a39-425e-908c-5c5897475fcb',
#   'name': '_ibl_experiment.description',
#   'created_by': None,
#   'description': 'A list of acquisition devices and behaviour protocols, along with the data and sync file location.  The root keys are (devices, sync, task, procedures).',
#   'filename_pattern': '_*_experiment.description.*',
#   'object': '_ibl_experiment',
#   'attribute': 'description',
#   'admin_url': '/admin/data/datasettype/57316c04-1a39-425e-908c-5c5897475fcb/change/'},
#  {'id': '33a5fc59-83ce-4671-a4f0-a1ad0ef53f28',
#   'name': '_ibl_lickPiezo.raw',
#   'created_by': None,
#   'description': 'Raw lick trace (1 column array',
#   'filename_pattern': '_ibl_lickpiezo.raw.*',
#   'object': '_ibl_lickPiezo',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/33a5fc59-83ce-4671-a4f0-a1ad0ef53f28/change/'},
#  {'id': '076dffde-7c7e-4636-99f1-3ae6e9d0fd4f',
#   'name': '_ibl_lickPiezo.timestamps',
#   'created_by': None,
#   'description': 'Timestamps for lick trace timeseries: 2 column array giving sample number and time in seconds',
#   'filename_pattern': '_ibl_lickpiezo.timestamps.*',
#   'object': '_ibl_lickPiezo',
#   'attribute': 'timestamps',
#   'admin_url': '/admin/data/datasettype/076dffde-7c7e-4636-99f1-3ae6e9d0fd4f/change/'},
#  {'id': '86f168dc-5a37-4e67-adfe-353cf6aed751',
#   'name': '_ibl_log.error',
#   'created_by': None,
#   'description': 'Log File for errored job',
#   'filename_pattern': '_ibl_log.error*.log',
#   'object': '_ibl_log',
#   'attribute': 'error',
#   'admin_url': '/admin/data/datasettype/86f168dc-5a37-4e67-adfe-353cf6aed751/change/'},
#  {'id': 'd3547560-7cd3-48e6-903c-427317a06a3b',
#   'name': '_ibl_log.info',
#   'created_by': None,
#   'description': 'Log File for normal job completion',
#   'filename_pattern': '_ibl_log.info*.log',
#   'object': '_ibl_log',
#   'attribute': 'info',
#   'admin_url': '/admin/data/datasettype/d3547560-7cd3-48e6-903c-427317a06a3b/change/'},
#  {'id': 'cad0b10e-ff17-4f31-a2d0-1be0de95b2d6',
#   'name': '_iblmic_audioSpectrogram.frequencies',
#   'created_by': None,
#   'description': 'Frequency scale of audio spectrogram from microphone (Hz)',
#   'filename_pattern': '_iblmic_audiospectrogram.frequencies.*',
#   'object': '_iblmic_audioSpectrogram',
#   'attribute': 'frequencies',
#   'admin_url': '/admin/data/datasettype/cad0b10e-ff17-4f31-a2d0-1be0de95b2d6/change/'},
#  {'id': 'd9d99abc-f14a-47c2-b61a-91efba29956a',
#   'name': '_iblmic_audioSpectrogram.power',
#   'created_by': None,
#   'description': 'Audio spectrogram from microphone, power',
#   'filename_pattern': '_iblmic_audiospectrogram.power.*',
#   'object': '_iblmic_audioSpectrogram',
#   'attribute': 'power',
#   'admin_url': '/admin/data/datasettype/d9d99abc-f14a-47c2-b61a-91efba29956a/change/'},
#  {'id': 'bed4e73c-8843-4fbe-8e6b-eb2d8cda5d8b',
#   'name': '_iblmic_audioSpectrogram.times_mic',
#   'created_by': None,
#   'description': 'Frequency scale of audio spectrogram from microphone (s)',
#   'filename_pattern': '_iblmic_audiospectrogram.times*.*',
#   'object': '_iblmic_audioSpectrogram',
#   'attribute': 'times_mic',
#   'admin_url': '/admin/data/datasettype/bed4e73c-8843-4fbe-8e6b-eb2d8cda5d8b/change/'},
#  {'id': '4375f1a9-8465-4ef1-86b0-8d51b373a38b',
#   'name': '_ibl_passiveGabor.table',
#   'created_by': None,
#   'description': 'Gabor patch presentations table: columns = [start, stop, position, contrast, phase], lines = nPresentations (180)',
#   'filename_pattern': '_ibl_passivegabor.table*.csv',
#   'object': '_ibl_passiveGabor',
#   'attribute': 'table',
#   'admin_url': '/admin/data/datasettype/4375f1a9-8465-4ef1-86b0-8d51b373a38b/change/'},
#  {'id': 'efdf0ab6-1d56-4936-9f4f-242113d215e1',
#   'name': '_ibl_passivePeriods.intervalsTable',
#   'created_by': None,
#   'description': "Table of times for different passiveCW periode: columns = ['passiveProtocol', 'spontaneousActivity', 'RFM', 'taskReplay'], lines = ['start', 'stop']",
#   'filename_pattern': '_ibl_passiveperiods.intervalstable*.csv',
#   'object': '_ibl_passivePeriods',
#   'attribute': 'intervalsTable',
#   'admin_url': '/admin/data/datasettype/efdf0ab6-1d56-4936-9f4f-242113d215e1/change/'},
#  {'id': '647ecd82-d357-434c-a921-6670f849606d',
#   'name': '_ibl_passiveRFM.times',
#   'created_by': None,
#   'description': 'Times of all frames presented during the receptive field mapping period',
#   'filename_pattern': '_ibl_passiverfm.times*.npy',
#   'object': '_ibl_passiveRFM',
#   'attribute': 'times',
#   'admin_url': '/admin/data/datasettype/647ecd82-d357-434c-a921-6670f849606d/change/'},
#  {'id': 'ea4cb820-2f13-48b2-9695-cbc927e2fa3a',
#   'name': '_ibl_passiveStims.table',
#   'created_by': None,
#   'description': 'All other stimuli times: columns = [valveOn, valveOff, toneOn, toneOff, noiseOn, noiseOff], lines = nStims = 40',
#   'filename_pattern': '_ibl_passivestims.table*.csv',
#   'object': '_ibl_passiveStims',
#   'attribute': 'table',
#   'admin_url': '/admin/data/datasettype/ea4cb820-2f13-48b2-9695-cbc927e2fa3a/change/'},
#  {'id': '1fd9c881-0c02-468a-ab0a-8974170bd875',
#   'name': '_iblqc_ephysChannels.labels',
#   'created_by': None,
#   'description': 'Raw spike rate per channel without clustering or collision handling - for early stages QC purposes. [Hz]',
#   'filename_pattern': '_iblqc_ephyschannels.*labels.*',
#   'object': '_iblqc_ephysChannels',
#   'attribute': 'labels',
#   'admin_url': '/admin/data/datasettype/1fd9c881-0c02-468a-ab0a-8974170bd875/change/'},
#  {'id': '935a4f55-4a9b-49c5-8898-661559b3616a',
#   'name': '_iblqc_ephysChannels.rawSpikeRates',
#   'created_by': None,
#   'description': 'Raw spike rate per channel without clustering or collision handling - for early stages QC purposes. [Hz]',
#   'filename_pattern': '_iblqc_ephyschannels.*rawspikerates.*',
#   'object': '_iblqc_ephysChannels',
#   'attribute': 'rawSpikeRates',
#   'admin_url': '/admin/data/datasettype/935a4f55-4a9b-49c5-8898-661559b3616a/change/'},
#  {'id': '2c56c793-c3ac-4968-9798-f31a6453c105',
#   'name': '_iblqc_ephysChannels.RMS',
#   'created_by': None,
#   'description': 'Median RMS per channel from samples of raw [nch, 0] and destriped [nch, 1] ephys data.',
#   'filename_pattern': '_iblqc_ephyschannels.*rms.*',
#   'object': '_iblqc_ephysChannels',
#   'attribute': 'RMS',
#   'admin_url': '/admin/data/datasettype/2c56c793-c3ac-4968-9798-f31a6453c105/change/'},
#  {'id': 'aced686b-6d9e-4094-bb3a-8e8a198cae28',
#   'name': '_iblqc_ephysSpectralDensity.freqs',
#   'created_by': None,
#   'description': 'Frequency scale for the spectrogram (Hz)',
#   'filename_pattern': '_iblqc_ephysspectraldensity*.freqs.npy',
#   'object': '_iblqc_ephysSpectralDensity',
#   'attribute': 'freqs',
#   'admin_url': '/admin/data/datasettype/aced686b-6d9e-4094-bb3a-8e8a198cae28/change/'},
#  {'id': 'e61ce46e-0412-4edc-8c38-50a5c60e3ee4',
#   'name': '_iblqc_ephysSpectralDensity.power',
#   'created_by': None,
#   'description': 'Spectral Density for all channels (V**2/Hz)',
#   'filename_pattern': '_iblqc_ephysspectraldensity*.power.npy',
#   'object': '_iblqc_ephysSpectralDensity',
#   'attribute': 'power',
#   'admin_url': '/admin/data/datasettype/e61ce46e-0412-4edc-8c38-50a5c60e3ee4/change/'},
#  {'id': '374e0fc2-58be-4670-b238-a43f82aae8a4',
#   'name': '_iblqc_ephysTimeRms.rms',
#   'created_by': None,
#   'description': 'RMS amplitude as a function of time (V)',
#   'filename_pattern': '_iblqc_ephystimerms*.rms.npy',
#   'object': '_iblqc_ephysTimeRms',
#   'attribute': 'rms',
#   'admin_url': '/admin/data/datasettype/374e0fc2-58be-4670-b238-a43f82aae8a4/change/'},
#  {'id': 'a02ab1c2-c881-4acc-9e3a-13c0a0c3e187',
#   'name': '_iblqc_ephysTimeRms.timestamps',
#   'created_by': None,
#   'description': 'Time scale for the RMS amplitude as a function of time, relative to the raw binary ephys file (s)',
#   'filename_pattern': '_iblqc_ephystimerms*.timestamps.npy',
#   'object': '_iblqc_ephysTimeRms',
#   'attribute': 'timestamps',
#   'admin_url': '/admin/data/datasettype/a02ab1c2-c881-4acc-9e3a-13c0a0c3e187/change/'},
#  {'id': '8d9e3083-9cb5-4f21-b945-cd445772d7a7',
#   'name': '_iblrig_ambientSensorData.raw',
#   'created_by': None,
#   'description': 'Temperature and humidity from sensor in rig',
#   'filename_pattern': '_iblrig_ambientsensordata.raw.*',
#   'object': '_iblrig_ambientSensorData',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/8d9e3083-9cb5-4f21-b945-cd445772d7a7/change/'},
#  {'id': 'a45137ea-d4bf-444d-aa83-d29950195cde',
#   'name': '_iblrig_Camera.frame_counter',
#   'created_by': None,
#   'description': 'Frame counter value from camera for each frame',
#   'filename_pattern': '_iblrig_*camera.frame_counter.bin',
#   'object': '_iblrig_Camera',
#   'attribute': 'frame_counter',
#   'admin_url': '/admin/data/datasettype/a45137ea-d4bf-444d-aa83-d29950195cde/change/'},
#  {'id': 'eb61ea65-870a-4ca8-9703-c7c595284ba4',
#   'name': '_iblrig_Camera.frameData',
#   'created_by': None,
#   'description': 'Table containing Timestamp, embeddedTimeStamp, embeddedFrameCounter, embeddedGPIOPinState for each video frame',
#   'filename_pattern': '_iblrig_*camera.framedata.*',
#   'object': '_iblrig_Camera',
#   'attribute': 'frameData',
#   'admin_url': '/admin/data/datasettype/eb61ea65-870a-4ca8-9703-c7c595284ba4/change/'},
#  {'id': '28554b3d-e4c7-47ac-b247-4ba31a994332',
#   'name': '_iblrig_Camera.GPIO',
#   'created_by': None,
#   'description': 'GPIO pin state for each camera frame',
#   'filename_pattern': '_iblrig_*camera.gpio.bin',
#   'object': '_iblrig_Camera',
#   'attribute': 'GPIO',
#   'admin_url': '/admin/data/datasettype/28554b3d-e4c7-47ac-b247-4ba31a994332/change/'},
#  {'id': 'e40899d0-a883-40ac-8214-344bcf249d09',
#   'name': '_iblrig_Camera.raw',
#   'created_by': None,
#   'description': '',
#   'filename_pattern': '_iblrig_*camera.raw.*',
#   'object': '_iblrig_Camera',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/e40899d0-a883-40ac-8214-344bcf249d09/change/'},
#  {'id': 'b5ec79de-9c9e-4009-8892-10aa2ddb9638',
#   'name': '_iblrig_Camera.timestamps',
#   'created_by': None,
#   'description': '',
#   'filename_pattern': '_iblrig_*camera.*timestamps.*',
#   'object': '_iblrig_Camera',
#   'attribute': 'timestamps',
#   'admin_url': '/admin/data/datasettype/b5ec79de-9c9e-4009-8892-10aa2ddb9638/change/'},
#  {'id': '91aec5d6-a10a-41e8-abcd-fbd7bacf69e3',
#   'name': '_iblrig_codeFiles.raw',
#   'created_by': None,
#   'description': 'Zip of Gabor2D and basicChoiceWorld code folders that generated the data',
#   'filename_pattern': '_iblrig_codefiles.raw.*',
#   'object': '_iblrig_codeFiles',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/91aec5d6-a10a-41e8-abcd-fbd7bacf69e3/change/'},
#  {'id': '62998630-0d69-45c1-9c5e-c74a1a509fb1',
#   'name': '_iblrig_encoderEvents.raw',
#   'created_by': None,
#   'description': 'Data file saved from Bonsai (Event, RE timestamp, Source, data, Bonsai Timestamp) - Each row is an event sent from the state machine (1, 2, 3 - stim off, on close loop)',
#   'filename_pattern': '_iblrig_encoderevents.raw.*',
#   'object': '_iblrig_encoderEvents',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/62998630-0d69-45c1-9c5e-c74a1a509fb1/change/'},
#  {'id': 'e0c77fba-1e8d-435a-b57e-b33c867ede83',
#   'name': '_iblrig_encoderPositions.raw',
#   'created_by': None,
#   'description': 'Data file saved from Bonsai (Position, RE timestamp, Position, Bonsai Timestamp) - Each row is a position change of the RE',
#   'filename_pattern': '_iblrig_encoderpositions.raw.*',
#   'object': '_iblrig_encoderPositions',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/e0c77fba-1e8d-435a-b57e-b33c867ede83/change/'},
#  {'id': 'a5ef4d78-e667-4e85-9fd7-141ae5ad3ae9',
#   'name': '_iblrig_encoderTrialInfo.raw',
#   'created_by': None,
#   'description': 'Raw trial data sent at beginning of trial from Bpod to Bonsai (TrialNum, init position of stim, stim_contrast, stim_freq, stim_angle, stim_gain, stim_sigma/size, Bonsai timestamp),',
#   'filename_pattern': '_iblrig_encodertrialinfo.raw.*',
#   'object': '_iblrig_encoderTrialInfo',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/a5ef4d78-e667-4e85-9fd7-141ae5ad3ae9/change/'},
#  {'id': '288b8f91-78b3-42bb-b90e-8bb2c82a35c9',
#   'name': '_iblrig_micData.raw',
#   'created_by': None,
#   'description': 'Microphone data lossless compression for ephys',
#   'filename_pattern': '_iblrig_micdata.raw.flac',
#   'object': '_iblrig_micData',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/288b8f91-78b3-42bb-b90e-8bb2c82a35c9/change/'},
#  {'id': '41068334-1826-42ee-a09a-759d907dd0cf',
#   'name': '_iblrig_RFMapStim.raw',
#   'created_by': None,
#   'description': 'Passive Visual stimulus raw information',
#   'filename_pattern': '_iblrig_rfmapstim.raw.bin',
#   'object': '_iblrig_RFMapStim',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/41068334-1826-42ee-a09a-759d907dd0cf/change/'},
#  {'id': 'c29a238f-95a4-4081-9ef2-7d0e0b225f20',
#   'name': '_iblrig_stimPositionScreen.raw',
#   'created_by': None,
#   'description': 'CSV file with 3 columns, CONTRAST [0->1], STIM_POSITION [visual deg], TIMESTAMP [isostandard] (saves stim positions and contrast every time they change)',
#   'filename_pattern': '_iblrig_stimpositionscreen.raw.csv',
#   'object': '_iblrig_stimPositionScreen',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/c29a238f-95a4-4081-9ef2-7d0e0b225f20/change/'},
#  {'id': '73ecfa96-b913-4807-ad35-e2c67f4ed01e',
#   'name': '_iblrig_syncSquareUpdate.raw',
#   'created_by': None,
#   'description': 'Timestamped sync square update commands',
#   'filename_pattern': '_iblrig_syncsquareupdate.raw.csv',
#   'object': '_iblrig_syncSquareUpdate',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/73ecfa96-b913-4807-ad35-e2c67f4ed01e/change/'},
#  {'id': 'b9898fac-8106-4db4-99a4-f81f6a53fc57',
#   'name': '_iblrig_taskData.raw',
#   'created_by': None,
#   'description': 'Data file saved by PyBpod in json serializable lines (file itself is not a json object, each line is a json object corresponding to a trial) - Training task w/ automated contrast',
#   'filename_pattern': '_iblrig_taskdata.raw.*',
#   'object': '_iblrig_taskData',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/b9898fac-8106-4db4-99a4-f81f6a53fc57/change/'},
#  {'id': '26e731af-67a7-4be0-9dbc-c25eb153da31',
#   'name': '_iblrig_taskSettings.raw',
#   'created_by': None,
#   'description': 'Metadata/Settings json (only one line). All information about the task, user, subject, contrasts, gain etc are included. (We should have a link with the structure of it somewhere)',
#   'filename_pattern': '_iblrig_tasksettings.raw.*',
#   'object': '_iblrig_taskSettings',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/26e731af-67a7-4be0-9dbc-c25eb153da31/change/'},
#  {'id': '02492ac1-d2a5-4ca9-b545-a9a18fbbc31b',
#   'name': '_iblrig_VideoCodeFiles.raw',
#   'created_by': None,
#   'description': '',
#   'filename_pattern': '_iblrig_videocodefiles.raw.*',
#   'object': '_iblrig_VideoCodeFiles',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/02492ac1-d2a5-4ca9-b545-a9a18fbbc31b/change/'},
#  {'id': '5d6c5026-31ec-45c8-8f37-f1304c360fb3',
#   'name': '_ibl_trials.laserIntervals',
#   'created_by': None,
#   'description': 'Time in seconds, relative to the session start, of the onset and offset of the laser stimulation.',
#   'filename_pattern': '_ibl_trials.laserintervals.npy',
#   'object': '_ibl_trials',
#   'attribute': 'laserIntervals',
#   'admin_url': '/admin/data/datasettype/5d6c5026-31ec-45c8-8f37-f1304c360fb3/change/'},
#  {'id': '2be5a2b1-4f52-4570-a2ac-3412dde50cc3',
#   'name': '_ibl_trials.laserStimulation',
#   'created_by': None,
#   'description': 'Whether or not the laser was actuating during the trial (outcome): 0:no laser, 1: laser, np.nan: no info',
#   'filename_pattern': '_ibl_trials.laserstimulation.npy',
#   'object': '_ibl_trials',
#   'attribute': 'laserStimulation',
#   'admin_url': '/admin/data/datasettype/2be5a2b1-4f52-4570-a2ac-3412dde50cc3/change/'},
#  {'id': '7e27c540-e61d-401f-b774-54d573886a6c',
#   'name': '_ibl_trials.stimOnTrigger_times',
#   'created_by': None,
#   'description': 'Times of stimulus onset trigger command',
#   'filename_pattern': '_ibl_trials.stimontrigger_times.*',
#   'object': '_ibl_trials',
#   'attribute': 'stimOnTrigger_times',
#   'admin_url': '/admin/data/datasettype/7e27c540-e61d-401f-b774-54d573886a6c/change/'},
#  {'id': '9b8499e9-2a51-4f53-87b0-935ceacedb59',
#   'name': 'imaging.fieldOfView',
#   'created_by': 'tjostmou',
#   'description': 'PNG or JPEG or any image snapshot of the field of view for imaging',
#   'filename_pattern': 'imaging.fieldofview.*',
#   'object': 'imaging',
#   'attribute': 'fieldOfView',
#   'admin_url': '/admin/data/datasettype/9b8499e9-2a51-4f53-87b0-935ceacedb59/change/'},
#  {'id': '3d615670-2a50-4749-9fb8-b4777ee568c5',
#   'name': 'imaging.frames',
#   'created_by': 'tjostmou',
#   'description': 'Frame images with the dimensions [nframes, nx, ny(, nchannels)].\r\nNot writen in the attribute name, but it is implied that this is two photon imaging.',
#   'filename_pattern': 'imaging.frames.*',
#   'object': 'imaging',
#   'attribute': 'frames',
#   'admin_url': '/admin/data/datasettype/3d615670-2a50-4749-9fb8-b4777ee568c5/change/'},
#  {'id': '9300f7a1-e438-477f-963f-1c31b77cd4b9',
#   'name': 'imaging.imagingLightSource',
#   'created_by': None,
#   'description': 'int representing which channel was acquired for each frame. 0 channel indicates no light.',
#   'filename_pattern': 'imaging.imaginglightsource*',
#   'object': 'imaging',
#   'attribute': 'imagingLightSource',
#   'admin_url': '/admin/data/datasettype/9300f7a1-e438-477f-963f-1c31b77cd4b9/change/'},
#  {'id': 'd7b6832a-a9b3-41b1-8296-6c5af9769af9',
#   'name': 'imaging_intrinsic.bin_delta_stim_images',
#   'created_by': 'tjostmou',
#   'description': 'These are the same as delta_stim_images, excep in a binary format readable by labview on the setup during the experiment',
#   'filename_pattern': '',
#   'object': 'imaging_intrinsic',
#   'attribute': 'bin_delta_stim_images',
#   'admin_url': '/admin/data/datasettype/d7b6832a-a9b3-41b1-8296-6c5af9769af9/change/'},
#  {'id': '6a98bba7-da9e-41d0-a5d7-44cb2715ae8d',
#   'name': 'imaging_intrinsic.delta_stim_images',
#   'created_by': 'tjostmou',
#   'description': 'A collection of images of delta pre-stim-post stim of intrinsic imaging data, in one file. Usually in tdms format.\r\nAll images are related to the same stimulation. (stimulating the same body area in the same way)\r\nEach image is associated to one repetition of this stimulation.\r\nThis is usually used for mapping areas of the brain somatotopically.\r\nThe average of all the images can help increase the reliability of the mapping.',
#   'filename_pattern': '',
#   'object': 'imaging_intrinsic',
#   'attribute': 'delta_stim_images',
#   'admin_url': '/admin/data/datasettype/6a98bba7-da9e-41d0-a5d7-44cb2715ae8d/change/'},
#  {'id': '99204399-63c9-4f02-b0ef-9577a0e29c29',
#   'name': 'imaging_intrinsic.vessels_reference',
#   'created_by': 'tjostmou',
#   'description': 'An image of the blood vessels reference. Usually in tif(f) format',
#   'filename_pattern': '',
#   'object': 'imaging_intrinsic',
#   'attribute': 'vessels_reference',
#   'admin_url': '/admin/data/datasettype/99204399-63c9-4f02-b0ef-9577a0e29c29/change/'},
#  {'id': '3356a302-2141-4ad3-a3a3-0388519e61bb',
#   'name': 'imagingLightSource.properties',
#   'created_by': None,
#   'description': 'A map of channels number, colour and wavelength.  NB: This is the light source wavelength, not the photosensor channel / emitted wavelength.',
#   'filename_pattern': '*imaginglightsource.properties*',
#   'object': 'imagingLightSource',
#   'attribute': 'properties',
#   'admin_url': '/admin/data/datasettype/3356a302-2141-4ad3-a3a3-0388519e61bb/change/'},
#  {'id': 'ab21cb39-540a-4686-988f-86a8d16d0d83',
#   'name': 'imaging.times',
#   'created_by': None,
#   'description': 'The times of frame acquisition.',
#   'filename_pattern': 'imaging.times*',
#   'object': 'imaging',
#   'attribute': 'times',
#   'admin_url': '/admin/data/datasettype/ab21cb39-540a-4686-988f-86a8d16d0d83/change/'},
#  {'id': '272873c9-7c77-4bdf-8401-f31eb3fc5369',
#   'name': '_kilosort_raw.output',
#   'created_by': None,
#   'description': 'Spike sorting output from kilosort',
#   'filename_pattern': '_kilosort_raw.output*.tar',
#   'object': '_kilosort_raw',
#   'attribute': 'output',
#   'admin_url': '/admin/data/datasettype/272873c9-7c77-4bdf-8401-f31eb3fc5369/change/'},
#  {'id': '6de900a3-20b4-4e73-be57-8e63bbfa73b5',
#   'name': 'kilosort.whitening_matrix',
#   'created_by': None,
#   'description': 'Whitening matrix applied by kilosort2, [nchannels, nchannels]',
#   'filename_pattern': '_kilosort_whitening.matrix.npy',
#   'object': 'kilosort',
#   'attribute': 'whitening_matrix',
#   'admin_url': '/admin/data/datasettype/6de900a3-20b4-4e73-be57-8e63bbfa73b5/change/'},
#  {'id': 'e03266de-098b-493d-a52b-a8967f9c58ae',
#   'name': 'licks.times',
#   'created_by': None,
#   'description': 'Times of licks as detected from DLC tongue traces.',
#   'filename_pattern': 'licks.times.*',
#   'object': 'licks',
#   'attribute': 'times',
#   'admin_url': '/admin/data/datasettype/e03266de-098b-493d-a52b-a8967f9c58ae/change/'},
#  {'id': '361ca040-16e5-45d8-8486-ba8d19538452',
#   'name': 'passiveBeeps.times',
#   'created_by': None,
#   'description': 'Times of the beep, equivilent to the go cue during the choice world task',
#   'filename_pattern': '*passivebeeps.times.*',
#   'object': 'passiveBeeps',
#   'attribute': 'times',
#   'admin_url': '/admin/data/datasettype/361ca040-16e5-45d8-8486-ba8d19538452/change/'},
#  {'id': '83c45a9b-3e78-460f-a035-cb00cf4f9709',
#   'name': 'passiveNoise.intervals',
#   'created_by': None,
#   'description': "2 column array giving each passive noise trial's start (i.e. beginning of quiescent period) and stop (i.e. end of iti) times of trials in universal seconds",
#   'filename_pattern': '*passivenoise.intervals.*',
#   'object': 'passiveNoise',
#   'attribute': 'intervals',
#   'admin_url': '/admin/data/datasettype/83c45a9b-3e78-460f-a035-cb00cf4f9709/change/'},
#  {'id': '9b929d17-bd42-459d-a604-b4251d847da8',
#   'name': 'passiveTrials.contrastLeft',
#   'created_by': None,
#   'description': 'contrast of left-side stimulus (0...1)',
#   'filename_pattern': '*passivetrials.contrastleft.*',
#   'object': 'passiveTrials',
#   'attribute': 'contrastLeft',
#   'admin_url': '/admin/data/datasettype/9b929d17-bd42-459d-a604-b4251d847da8/change/'},
#  {'id': 'b73caa77-3e26-44a4-9809-b0885b47e77e',
#   'name': 'passiveTrials.contrastRight',
#   'created_by': None,
#   'description': 'contrast of right-side stimulus (0...1)',
#   'filename_pattern': '*passivetrials.contrastright.*',
#   'object': 'passiveTrials',
#   'attribute': 'contrastRight',
#   'admin_url': '/admin/data/datasettype/b73caa77-3e26-44a4-9809-b0885b47e77e/change/'},
#  {'id': '07aea4a4-189c-46f7-867d-8179561caf94',
#   'name': 'passiveTrials.included',
#   'created_by': None,
#   'description': 'boolean suggesting which trials to include in analysis, chosen at experimenter discretion, e.g. by excluding the block of incorrect trials at the end of the session when the mouse has stopped',
#   'filename_pattern': '*passivetrials.included.*',
#   'object': 'passiveTrials',
#   'attribute': 'included',
#   'admin_url': '/admin/data/datasettype/07aea4a4-189c-46f7-867d-8179561caf94/change/'},
#  {'id': '0c635fca-650e-45c9-8e23-b22fe1f6e60e',
#   'name': 'passiveTrials.stimOn_times',
#   'created_by': None,
#   'description': 'Times of stimulus onset in absolute seconds',
#   'filename_pattern': '*passivetrials.stimon_times.*',
#   'object': 'passiveTrials',
#   'attribute': 'stimOn_times',
#   'admin_url': '/admin/data/datasettype/0c635fca-650e-45c9-8e23-b22fe1f6e60e/change/'},
#  {'id': '72d9e4b1-295a-4698-bca7-650e7a62a330',
#   'name': 'passiveValveClicks.times',
#   'created_by': None,
#   'description': 'Times of valve opening during passive trial presentation',
#   'filename_pattern': '*passivevalveclicks.times.*',
#   'object': 'passiveValveClicks',
#   'attribute': 'times',
#   'admin_url': '/admin/data/datasettype/72d9e4b1-295a-4698-bca7-650e7a62a330/change/'},
#  {'id': 'cbf4b6b1-9202-4468-bd65-22df1713ae60',
#   'name': 'passiveWhiteNoise.times',
#   'created_by': None,
#   'description': 'Times of white noise bursts, equivilent to the negative feedback sound during the choice world task',
#   'filename_pattern': '*passivewhitenoise.times.*',
#   'object': 'passiveWhiteNoise',
#   'attribute': 'times',
#   'admin_url': '/admin/data/datasettype/cbf4b6b1-9202-4468-bd65-22df1713ae60/change/'},
#  {'id': '0973b965-de7d-40e5-9340-74a0056d3554',
#   'name': 'photometryFibers.brainLocationAcronyms_ccf_2017',
#   'created_by': None,
#   'description': 'Extracted brainlocation after histology per ROI.',
#   'filename_pattern': '*photometryfibers.brainlocationacronyms_ccf_2017*',
#   'object': 'photometryFibers',
#   'attribute': 'brainLocationAcronyms_ccf_2017',
#   'admin_url': '/admin/data/datasettype/0973b965-de7d-40e5-9340-74a0056d3554/change/'},
#  {'id': 'be388590-ebf0-4663-88ee-1229982bed8c',
#   'name': 'photometry.ROIs',
#   'created_by': None,
#   'description': 'ROI integer for associateing with trajectory.',
#   'filename_pattern': '*photometry.rois*',
#   'object': 'photometry',
#   'attribute': 'ROIs',
#   'admin_url': '/admin/data/datasettype/be388590-ebf0-4663-88ee-1229982bed8c/change/'},
#  {'id': '371fa560-c63c-47a6-9efb-126f298c0edf',
#   'name': 'photometry.signal',
#   'created_by': None,
#   'description': 'the recorded signal for each frame.',
#   'filename_pattern': '*photometry.signal*',
#   'object': 'photometry',
#   'attribute': 'signal',
#   'admin_url': '/admin/data/datasettype/371fa560-c63c-47a6-9efb-126f298c0edf/change/'},
#  {'id': '02810655-413b-435e-a9ac-bcd35a9c3b19',
#   'name': '_phy_spikes_subset.channels',
#   'created_by': None,
#   'description': 'Channel index for sample waveforms, [nspikes, nchannelsmax]',
#   'filename_pattern': '_phy_spikes_subset.channels.npy',
#   'object': '_phy_spikes_subset',
#   'attribute': 'channels',
#   'admin_url': '/admin/data/datasettype/02810655-413b-435e-a9ac-bcd35a9c3b19/change/'},
#  {'id': 'db943040-ba0a-4446-b46f-0448248d721a',
#   'name': '_phy_spikes_subset.spikes',
#   'created_by': None,
#   'description': 'Spikes index for sample waveforms, [nspikes,]',
#   'filename_pattern': '_phy_spikes_subset.spikes.npy',
#   'object': '_phy_spikes_subset',
#   'attribute': 'spikes',
#   'admin_url': '/admin/data/datasettype/db943040-ba0a-4446-b46f-0448248d721a/change/'},
#  {'id': '550388e1-87eb-47d2-ab7b-2793676cc11f',
#   'name': '_phy_spikes_subset.waveforms',
#   'created_by': None,
#   'description': 'Sample waveforms, [nspikes, nsamples, nchannelsmax]',
#   'filename_pattern': '_phy_spikes_subset.waveforms.npy',
#   'object': '_phy_spikes_subset',
#   'attribute': 'waveforms',
#   'admin_url': '/admin/data/datasettype/550388e1-87eb-47d2-ab7b-2793676cc11f/change/'},
#  {'id': '9baab957-63d9-408d-ad65-1b163ffcd50b',
#   'name': 'probes.description',
#   'created_by': None,
#   'description': 'JSON with one entry per probe containing label, model (3A, 3B1, 3B2),serial and raw_file_name',
#   'filename_pattern': 'probes.description*.json',
#   'object': 'probes',
#   'attribute': 'description',
#   'admin_url': '/admin/data/datasettype/9baab957-63d9-408d-ad65-1b163ffcd50b/change/'},
#  {'id': 'f8598f8a-272e-4ae0-aaa9-77c3ac733aaf',
#   'name': 'probes.trajectory',
#   'created_by': None,
#   'description': 'JSON with one entry per probe containing the 7 parameters describing the probe trajectory. Refer to the coordinate section of this document for more information.\n \'x\':(um) medio-lateral coordinate relative to Bregma, left negative\n \'y\':(um) antero-posterior coordinate relative to Bregma, back negative\n \'z\':(um) dorso-ventral coordinate relative to Bregma, ventral negative\n \'phi\':(degrees)[-180 180] azimuth\n \'theta\':(degrees)[0 180] polar angle\n \'depth\':(um) insertion depth\n \'beta\' :(degrees) roll angle of the probe"',
#   'filename_pattern': 'probes.trajectory*.json',
#   'object': 'probes',
#   'attribute': 'trajectory',
#   'admin_url': '/admin/data/datasettype/f8598f8a-272e-4ae0-aaa9-77c3ac733aaf/change/'},
#  {'id': 'b7fe7846-731e-407c-8187-d2cfa3978587',
#   'name': '_rigbox_block.raw',
#   'created_by': None,
#   'description': 'File containing the session data, unparsed in Matlab format.',
#   'filename_pattern': '_rigbox_block.raw.mat',
#   'object': '_rigbox_block',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/b7fe7846-731e-407c-8187-d2cfa3978587/change/'},
#  {'id': 'fd0654a6-9d26-4e04-99cc-6608e9621684',
#   'name': '_rigbox_code.raw',
#   'created_by': None,
#   'description': 'Copy  of the expDef.m code file used for the session',
#   'filename_pattern': '_rigbox_code.raw.m',
#   'object': '_rigbox_code',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/fd0654a6-9d26-4e04-99cc-6608e9621684/change/'},
#  {'id': 'cecb16be-781f-4859-bfb9-47406bdb1724',
#   'name': '_rigbox_hardwareInfo.raw',
#   'created_by': None,
#   'description': 'Hardware configuration used for the task, json format',
#   'filename_pattern': '_rigbox_hardwareinfo.raw.json',
#   'object': '_rigbox_hardwareInfo',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/cecb16be-781f-4859-bfb9-47406bdb1724/change/'},
#  {'id': '8e896348-e852-49ec-b195-be56af9c0180',
#   'name': '_rigbox_jsonParameters.raw',
#   'created_by': None,
#   'description': 'Parameter structure used for the task in Json format.',
#   'filename_pattern': '_rigbox_jsonparameters.raw.json',
# ...
#   'name': 'templates.amps',
#   'created_by': None,
#   'description': 'Average peak/trough amplitude of templates',
#   'filename_pattern': 'templates.amps.npy',
#   'object': 'templates',
#   'attribute': 'amps',
#   'admin_url': '/admin/data/datasettype/1257f1c3-de6b-4d57-877d-1df12fcba074/change/'},
#  {'id': 'd917bfa4-9b7f-4b3f-b892-378f4bcafbe8',
#   'name': 'templates.waveforms',
#   'created_by': None,
#   'description': 'Waveform of automatic spike sorting templates (stored as a sparse array, only for a subset of channels closest to the peak channel)',
#   'filename_pattern': 'templates.waveforms.npy',
#   'object': 'templates',
#   'attribute': 'waveforms',
#   'admin_url': '/admin/data/datasettype/d917bfa4-9b7f-4b3f-b892-378f4bcafbe8/change/'},
#  {'id': 'b53f2d05-d491-43f8-992f-f5962a2727ed',
#   'name': 'templates.waveformsChannels',
#   'created_by': None,
#   'description': 'Index of channels that are stored for each template. Sorted by increasing distance from the maximum amplitude channel.',
#   'filename_pattern': 'templates.waveformschannels.npy',
#   'object': 'templates',
#   'attribute': 'waveformsChannels',
#   'admin_url': '/admin/data/datasettype/b53f2d05-d491-43f8-992f-f5962a2727ed/change/'},
#  {'id': '378aa050-4924-4a9b-9fe7-b7cf86dff93f',
#   'name': 'trials.choice',
#   'created_by': None,
#   'description': 'which choice was made in choiceworld: -1 (turn CCW), +1 (turn CW), or 0 (nogo)',
#   'filename_pattern': '*trials.choice.*',
#   'object': 'trials',
#   'attribute': 'choice',
#   'admin_url': '/admin/data/datasettype/378aa050-4924-4a9b-9fe7-b7cf86dff93f/change/'},
#  {'id': '979f9f7c-7d67-48d5-9042-a9000a8e66a2',
#   'name': 'trials.contrastLeft',
#   'created_by': None,
#   'description': 'contrast of left-side stimulus (0...1) nan if trial is on other side',
#   'filename_pattern': '*trials.contrastleft.*',
#   'object': 'trials',
#   'attribute': 'contrastLeft',
#   'admin_url': '/admin/data/datasettype/979f9f7c-7d67-48d5-9042-a9000a8e66a2/change/'},
#  {'id': '9d44dc73-67cd-4de7-b115-7d25723bc0da',
#   'name': 'trials.contrastRight',
#   'created_by': None,
#   'description': 'contrast of right-side stimulus (0...1) nan if trial is on other side',
#   'filename_pattern': '*trials.contrastright.*',
#   'object': 'trials',
#   'attribute': 'contrastRight',
#   'admin_url': '/admin/data/datasettype/9d44dc73-67cd-4de7-b115-7d25723bc0da/change/'},
#  {'id': 'd130f5fe-42ae-4e4f-9664-1657e811cc89',
#   'name': 'trials.eventTimeline',
#   'created_by': 'tjostmou',
#   'description': 'Detailed timeline of the trial. Usually saved inside a tdms file including a mix of mouse actions (licks, levers, readout, etc) and setup actuations (stimulations, cues etc..)',
#   'filename_pattern': 'trials.eventtimeline.*',
#   'object': 'trials',
#   'attribute': 'eventTimeline',
#   'admin_url': '/admin/data/datasettype/d130f5fe-42ae-4e4f-9664-1657e811cc89/change/'},
#  {'id': 'a60425e9-c5ab-4827-88a3-79b4eb68f989',
#   'name': 'trials.feedback_times',
#   'created_by': None,
#   'description': 'Time of feedback delivery (reward or not) in choiceworld - in absolute seconds, rather than relative to trial onset',
#   'filename_pattern': '*trials.feedback_times.*',
#   'object': 'trials',
#   'attribute': 'feedback_times',
#   'admin_url': '/admin/data/datasettype/a60425e9-c5ab-4827-88a3-79b4eb68f989/change/'},
#  {'id': '2a9092b0-c9fc-4740-bb43-28b254e3386e',
#   'name': 'trials.feedbackType',
#   'created_by': None,
#   'description': 'Whether feedback is positive or negative in choiceworld (-1 for negative, +1 for positive)',
#   'filename_pattern': '*trials.feedbacktype.*',
#   'object': 'trials',
#   'attribute': 'feedbackType',
#   'admin_url': '/admin/data/datasettype/2a9092b0-c9fc-4740-bb43-28b254e3386e/change/'},
#  {'id': '921d2a34-9bcf-430f-a762-2f4051902e56',
#   'name': 'trials.firstMovement_times',
#   'created_by': None,
#   'description': 'Movement onset (absolute from session start) extracted from the rotary encoder ',
#   'filename_pattern': '*trials.firstmovement_times.*',
#   'object': 'trials',
#   'attribute': 'firstMovement_times',
#   'admin_url': '/admin/data/datasettype/921d2a34-9bcf-430f-a762-2f4051902e56/change/'},
#  {'id': 'f7dbfad8-1cfc-459e-874f-4065cf9def86',
#   'name': 'trials.goCue_times',
#   'created_by': None,
#   'description': 'Time of go cues in choiceworld - in absolute seconds, rather than relative to trial onset',
#   'filename_pattern': '*trials.gocue_times.*',
#   'object': 'trials',
#   'attribute': 'goCue_times',
#   'admin_url': '/admin/data/datasettype/f7dbfad8-1cfc-459e-874f-4065cf9def86/change/'},
#  {'id': '63ea5aaa-1b51-4378-b515-2b6ec0502e05',
#   'name': 'trials.goCueTrigger_times',
#   'created_by': None,
#   'description': 'Time of go cues in choiceworld - in absolute seconds, rather than relative to trial onset NOTE: this is the time the trigger command is sent by Bpod',
#   'filename_pattern': '_ibl_trials.gocuetrigger_times.*',
#   'object': 'trials',
#   'attribute': 'goCueTrigger_times',
#   'admin_url': '/admin/data/datasettype/63ea5aaa-1b51-4378-b515-2b6ec0502e05/change/'},
#  {'id': 'd6584a34-f9dd-4870-ac02-0feb50fdf5f6',
#   'name': 'trials.included',
#   'created_by': None,
#   'description': 'boolean suggesting which trials to include in analysis, chosen at experimenter discretion, e.g. by excluding the block of incorrect trials at the end of the session when the mouse has stopped',
#   'filename_pattern': '*trials.included.*',
#   'object': 'trials',
#   'attribute': 'included',
#   'admin_url': '/admin/data/datasettype/d6584a34-f9dd-4870-ac02-0feb50fdf5f6/change/'},
#  {'id': '678a7e65-1dd1-4bff-b8c9-508e1f3a1cdc',
#   'name': 'trials.intervals',
#   'created_by': None,
#   'description': '2 column array giving each trials start (i.e. beginning of quiescent period) and stop (i.e. end of iti) times of trials in universal seconds',
#   'filename_pattern': '*trials.intervals*.*',
#   'object': 'trials',
#   'attribute': 'intervals',
#   'admin_url': '/admin/data/datasettype/678a7e65-1dd1-4bff-b8c9-508e1f3a1cdc/change/'},
#  {'id': '426d3490-e0d6-4a49-91fc-39eeed279475',
#   'name': 'trials.laserProbability',
#   'created_by': None,
#   'description': 'Probability of stimulation to be turned on within the trial',
#   'filename_pattern': '_*_trials.laserprobability.*',
#   'object': 'trials',
#   'attribute': 'laserProbability',
#   'admin_url': '/admin/data/datasettype/426d3490-e0d6-4a49-91fc-39eeed279475/change/'},
#  {'id': '9295f7a4-dd1b-440e-8ad0-53223aebab81',
#   'name': 'trials.probabilityLeft',
#   'created_by': None,
#   'description': 'Probability that the stimulus will be on the left hand side for the current block. The probability of right is 1 minus this',
#   'filename_pattern': '_ibl_trials.probabilityleft.*',
#   'object': 'trials',
#   'attribute': 'probabilityLeft',
#   'admin_url': '/admin/data/datasettype/9295f7a4-dd1b-440e-8ad0-53223aebab81/change/'},
#  {'id': 'fa05d8a7-5ce5-42a6-9941-69ffe3acc1c1',
#   'name': 'trials.probabilityRewardLeft',
#   'created_by': None,
#   'description': 'probability of a left response (i.e. CW turn) being rewarded. The probability of the right response being rewarded is 1-probabilityRewardLeft. The two probabilities are sampled independently therefore both sides may or may not be rewarded.',
#   'filename_pattern': '*trials.probabilityrewardleft.npy',
#   'object': 'trials',
#   'attribute': 'probabilityRewardLeft',
#   'admin_url': '/admin/data/datasettype/fa05d8a7-5ce5-42a6-9941-69ffe3acc1c1/change/'},
#  {'id': '4cd7dcc9-62c1-4471-afa7-60544fc7e1ff',
#   'name': 'trials.repNum',
#   'created_by': None,
#   'description': 'the repetition number of the trial, i.e. how many trials have been repeated on this side (counting from 1)',
#   'filename_pattern': '*trials.repnum.*',
#   'object': 'trials',
#   'attribute': 'repNum',
#   'admin_url': '/admin/data/datasettype/4cd7dcc9-62c1-4471-afa7-60544fc7e1ff/change/'},
#  {'id': '5df90bef-df4f-4850-92b4-f0e43d619a0a',
#   'name': 'trials.response_times',
#   'created_by': None,
#   'description': 'Time of "response" in choiceworld- in absolute seconds, rather than relative to trial onset. This is when one of the three possible choices is registered in software, will not be the same as when the mouse\'s movement to generate that response begins.',
#   'filename_pattern': '*trials.response_times.*',
#   'object': 'trials',
#   'attribute': 'response_times',
#   'admin_url': '/admin/data/datasettype/5df90bef-df4f-4850-92b4-f0e43d619a0a/change/'},
#  {'id': '30717938-d036-40de-942f-b3dfe0c39c3b',
#   'name': 'trials.rewardVolume',
#   'created_by': None,
#   'description': 'volume of reward given each trial in µl',
#   'filename_pattern': '*trials.rewardvolume.*',
#   'object': 'trials',
#   'attribute': 'rewardVolume',
#   'admin_url': '/admin/data/datasettype/30717938-d036-40de-942f-b3dfe0c39c3b/change/'},
#  {'id': '79f7f786-f77a-4e80-97a5-65f68264049e',
#   'name': 'trials.stimOff_times',
#   'created_by': None,
#   'description': 'Times of stimuli in choiceworld - in absolute seconds, rather than relative to trial onset',
#   'filename_pattern': '*trials.stimoff_times.*',
#   'object': 'trials',
#   'attribute': 'stimOff_times',
#   'admin_url': '/admin/data/datasettype/79f7f786-f77a-4e80-97a5-65f68264049e/change/'},
#  {'id': '72344745-c248-45e5-bf73-a9329c1720d2',
#   'name': 'trials.stimOn_times',
#   'created_by': None,
#   'description': 'Times of stimuli in choiceworld - in absolute seconds, rather than relative to trial onset',
#   'filename_pattern': '*trials.stimon_times.*',
#   'object': 'trials',
#   'attribute': 'stimOn_times',
#   'admin_url': '/admin/data/datasettype/72344745-c248-45e5-bf73-a9329c1720d2/change/'},
#  {'id': 'c634bb4d-a152-4e6f-930d-516957b433e6',
#   'name': 'trials.table',
#   'created_by': None,
#   'description': 'A table of trial events, one per trial. Events include: intervals, goCue_times, response_times, choice, stimOn_times, contrastLeft, contrastRight, feedback_times, feedbackType, rewardVolume, probabilityLeft, firstMovement_times',
#   'filename_pattern': '*trials.table*',
#   'object': 'trials',
#   'attribute': 'table',
#   'admin_url': '/admin/data/datasettype/c634bb4d-a152-4e6f-930d-516957b433e6/change/'},
#  {'id': '21980a44-d25a-493f-b40f-b72cdc1e3a72',
#   'name': 'unknown',
#   'created_by': None,
#   'description': '',
#   'filename_pattern': '',
#   'object': '',
#   'attribute': '',
#   'admin_url': '/admin/data/datasettype/21980a44-d25a-493f-b40f-b72cdc1e3a72/change/'},
#  {'id': 'dea53510-d3e0-4b94-9739-2fe548a6f898',
#   'name': 'wheelMoves.intervals',
#   'created_by': None,
#   'description': '2 column array with onset and offset times of detected wheel movements in seconds',
#   'filename_pattern': '*wheelmoves.intervals.*',
#   'object': 'wheelMoves',
#   'attribute': 'intervals',
#   'admin_url': '/admin/data/datasettype/dea53510-d3e0-4b94-9739-2fe548a6f898/change/'},
#  {'id': 'a66e41a2-09b8-4761-9fbb-5fe5168cc088',
#   'name': 'wheelMoves.peakAmplitude',
#   'created_by': None,
#   'description': 'amplitude of the wheel move',
#   'filename_pattern': '*wheelmoves.peakamplitude.*',
#   'object': 'wheelMoves',
#   'attribute': 'peakAmplitude',
#   'admin_url': '/admin/data/datasettype/a66e41a2-09b8-4761-9fbb-5fe5168cc088/change/'},
#  {'id': '81ea14a9-1512-4c1c-94e3-ccb7b42f6755',
#   'name': 'wheelMoves.type',
#   'created_by': None,
#   'description': "string array containing classified type of movement ('CW', 'CCW', 'Flinch', 'Other')",
#   'filename_pattern': '*wheelmoves.type.*',
#   'object': 'wheelMoves',
#   'attribute': 'type',
#   'admin_url': '/admin/data/datasettype/81ea14a9-1512-4c1c-94e3-ccb7b42f6755/change/'},
#  {'id': '54c9a39c-665c-4cf6-b06c-d7f18dae1e78',
#   'name': 'wheel.position',
#   'created_by': None,
#   'description': 'Absolute position of wheel.',
#   'filename_pattern': '*wheel.position.*',
#   'object': 'wheel',
#   'attribute': 'position',
#   'admin_url': '/admin/data/datasettype/54c9a39c-665c-4cf6-b06c-d7f18dae1e78/change/'},
#  {'id': '74c0120c-7515-478f-9725-53d587d86c49',
#   'name': 'wheel.timestamps',
#   'created_by': None,
#   'description': 'Timestamps for wheel timeseries',
#   'filename_pattern': '*wheel.times*',
#   'object': 'wheel',
#   'attribute': 'timestamps',
#   'admin_url': '/admin/data/datasettype/74c0120c-7515-478f-9725-53d587d86c49/change/'},
#  {'id': 'e1542d34-9618-4369-aab7-0489484f6a12',
#   'name': 'wheel.velocity',
#   'created_by': None,
#   'description': 'Signed velocity of wheel',
#   'filename_pattern': '*wheel.velocity.*',
#   'object': 'wheel',
#   'attribute': 'velocity',
#   'admin_url': '/admin/data/datasettype/e1542d34-9618-4369-aab7-0489484f6a12/change/'},
#  {'id': 'b23b5e73-0278-49e9-ab22-08663aa48555',
#   'name': 'widefieldChannels.frameAverage',
#   'created_by': None,
#   'description': 'average across all frames for each channel of imaging',
#   'filename_pattern': 'widefieldchannels.frameaverage*',
#   'object': 'widefieldChannels',
#   'attribute': 'frameAverage',
#   'admin_url': '/admin/data/datasettype/b23b5e73-0278-49e9-ab22-08663aa48555/change/'},
#  {'id': '944889c0-5b5d-4ca3-b4df-740ef441135f',
#   'name': 'widefieldChannels.wiring',
#   'created_by': None,
#   'description': 'For each LED channel there is an indentifier (typically an int channel number) and a corresponding wavelength.',
#   'filename_pattern': '*widefieldchannels.wiring*',
#   'object': 'widefieldChannels',
#   'attribute': 'wiring',
#   'admin_url': '/admin/data/datasettype/944889c0-5b5d-4ca3-b4df-740ef441135f/change/'},
#  {'id': '9f5ec125-b5e2-4d6b-b656-c7319c5ed5f7',
#   'name': 'widefieldEvents.raw',
#   'created_by': None,
#   'description': 'Widefield frame information and IO states; 2 columns are (frame#, timestamp)',
#   'filename_pattern': 'widefieldevents.raw.*',
#   'object': 'widefieldEvents',
#   'attribute': 'raw',
#   'admin_url': '/admin/data/datasettype/9f5ec125-b5e2-4d6b-b656-c7319c5ed5f7/change/'},
#  {'id': '8eed6442-7923-4437-b288-f66adb08df09',
#   'name': 'widefieldLandmarks.dorsalCortex',
#   'created_by': None,
#   'description': 'Manually identified dorsal cortex landmark coordinates for alignment',
#   'filename_pattern': 'widefieldlandmarks.dorsalcortex.*',
#   'object': 'widefieldLandmarks',
#   'attribute': 'dorsalCortex',
#   'admin_url': '/admin/data/datasettype/8eed6442-7923-4437-b288-f66adb08df09/change/'},
#  {'id': '525e8cc8-17e2-4946-8d7d-c554ff00928c',
#   'name': 'widefield.raw_meta',
#   'created_by': 'tjostmou',
#   'description': 'information about the dataset such as frame rate and number of channels',
#   'filename_pattern': 'widefield.raw_meta.*',
#   'object': 'widefield',
#   'attribute': 'raw_meta',
#   'admin_url': '/admin/data/datasettype/525e8cc8-17e2-4946-8d7d-c554ff00928c/change/'},
#  {'id': '0fd7283b-4729-4350-ab8d-74d532fcb31a',
#   'name': 'widefieldSVT.haemoCorrected',
#   'created_by': None,
#   'description': 'hemodynamic corrected temporal SVD components with dimensions [nComponents, nFrames]',
#   'filename_pattern': 'widefieldsvt.haemocorrected.*',
#   'object': 'widefieldSVT',
#   'attribute': 'haemoCorrected',
#   'admin_url': '/admin/data/datasettype/0fd7283b-4729-4350-ab8d-74d532fcb31a/change/'},
#  {'id': 'f5e48503-c71a-4aca-beec-86b32837f8bb',
#   'name': 'widefieldSVT.uncorrected',
#   'created_by': None,
#   'description': 'temporal SVD components (denoised/decomposed), s·Vᵀ with dimensions [nComponents, nFrames]',
#   'filename_pattern': 'widefieldsvt.uncorrected.*',
#   'object': 'widefieldSVT',
#   'attribute': 'uncorrected',
#   'admin_url': '/admin/data/datasettype/f5e48503-c71a-4aca-beec-86b32837f8bb/change/'},
#  {'id': '12636b73-cda0-4637-8c6a-0440386b3f3c',
#   'name': 'widefield.times',
#   'created_by': None,
#   'description': 'the time of each frame in seconds from experiment start',
#   'filename_pattern': 'widefield.times*',
#   'object': 'widefield',
#   'attribute': 'times',
#   'admin_url': '/admin/data/datasettype/12636b73-cda0-4637-8c6a-0440386b3f3c/change/'},
#  {'id': 'fa077e46-c7b1-4f95-afb6-7bc1faa6adba',
#   'name': 'widefieldU.images',
#   'created_by': None,
#   'description': 'Projected SVD spatial components (denoised/decomposed) with the shape [H, W, nComponents] where H and W are the dimensions of a single frame.',
#   'filename_pattern': 'widefieldu.images*',
#   'object': 'widefieldU',
#   'attribute': 'images',
#   'admin_url': '/admin/data/datasettype/fa077e46-c7b1-4f95-afb6-7bc1faa6adba/change/'}]

# %%
connector.search(endpoint="dataset-types")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:207, in Operateur.make_url(self, **kwargs)
#     206 try:
# --> 207     return self.path.make_url(**kwargs)
#     208 except ValueError as e:
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:116, in EndpointUrl.make_url(self, fragment, **kwargs)
#     112 query_dict, requirements_dict = self.separate_query_and_requirements(**kwargs)
#     113 url = UrlValidator.urlunparse(
#     114     protocol=self.client.protocol,  # http or https
#     115     netloc=self.client.netloc,  # netloc = host+port
# --> 116     path=self.finalized_path(**requirements_dict),  # path
#     117     query_string=self.make_query_string(query_dict),  # querystring example : ?thing=truc
#     118     fragment=fragment,  # basically an anchor, fragment example : #title1
#     119 )
#     120 return url
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:126, in EndpointUrl.finalized_path(self, **requirements_dict)
#     125 if (requirement_value := requirements_dict.get(requirement)) is None:
# --> 126     raise ValueError(f"You must provide a {requirement} keyword argument with the path {self}")
#     127 path = path.replace(f"{{{requirement}}}", str(requirement_value))
#
# ValueError: You must provide a name keyword argument with the path /dataset-types/{name}
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 connector.search(endpoint="dataset-types")
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\connector\core.py:80, in Connector.search(self, endpoint, id, details, **kwargs)
#      77 search_result = self.raise_if_search_empty(search_result)
#      79 if details and not id and endpoint_implements_retrieve:
# ---> 80     search_result = self.details_aggregation(search_result, endpoint)  # type: ignore
#      82 return self.results_to_pandas(search_result)
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\connector\core.py:151, in Connector.details_aggregation(self, search_result, endpoint)
#     147 detailed_results = []
#     148 for result in tqdm(
#     149     search_result, total=len(search_result), delay=2, desc=f"Loading {endpoint} details", file=stdout
#     150 ):
# --> 151     detailed_results.append(self.web_client.rest(endpoint, "retrieve", id=result["id"]))
#     152 return detailed_results
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\clients.py:97, in Client.rest(self, endpoint_name, action, timeout, **kwargs)
#      89 def rest(
#      90     self,
#      91     endpoint_name: str,
#    (...)     94     **kwargs,
#      95 ):
#      96     operateur = self.path(endpoint_name).endpoint.assert_exists().actions[action]
# ---> 97     return Request(self, operateur, timeout=timeout, **kwargs).handle()
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:299, in Request.handle(self)
#     298 def handle(self):
# --> 299     return self.handle_response(self.get_response())
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:292, in Request.get_response(self)
#     290 data = self.get_data()
#     291 files = self.get_files()
# --> 292 logger.debug(f"Sending a request with url={self.url}, headers={self.headers}")
#     293 r = self.request_method(
#     294     self.url, stream=True, headers=self.headers, data=data, files=files, timeout=self.timeout
#     295 )
#     296 return r
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:272, in Request.url(self)
#     270 @property
#     271 def url(self):
# --> 272     return self.operateur.make_url(**self.url_arguments)
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:209, in Operateur.make_url(self, **kwargs)
#     207     return self.path.make_url(**kwargs)
#     208 except ValueError as e:
# --> 209     raise ValueError(f"For the {self.action_name} action, " + str(e)) from e
#
# ValueError: For the retrieve action, You must provide a name keyword argument with the path /dataset-types/{name}

# %%
import smtplib
from email.message import EmailMessage

def get_mx_record(domain):
    import dns.resolver
    records = dns.resolver.resolve(domain, 'MX')
    mx_record = sorted(records, key=lambda r: r.preference)[0].exchange.to_text()
    return mx_record

def send_email_directly(from_addr, to_addr, subject, body, smtp_host = None):
    if smtp_host :
        host = smtp_host
    else :
        domain = to_addr.split('@')[1]
        host = get_mx_record(domain)

    msg = EmailMessage()
    msg['From'] = from_addr
    msg['To'] = to_addr
    msg['Subject'] = subject
    msg.set_content(body)

    with smtplib.SMTP(host, 25) as smtp:
        smtp.send_message(msg)

# Example usage:
send_email_directly(
    from_addr='noreply@alyx-local.fr',
    to_addr='timothe.jost-mousseau@pasteur.fr',
    subject='Test Email',
    body='This is a test email sent directly via SMTP.',
    smtp_host="email.pasteur.fr"
)

# %%
from pandas import DataFrame
DataFrame([x.to_series() for x in test])
# Out:
#                                     root subject        date number  \
# 0     \\cajal\cajal_data2\ONE\Adaptation    wm42  2025-03-27    003
# 1     \\cajal\cajal_data2\ONE\Adaptation    wm42  2025-03-27    003
# 2     \\cajal\cajal_data2\ONE\Adaptation    wm42  2025-03-27    003
# 3     \\cajal\cajal_data2\ONE\Adaptation    wm42  2025-03-27    003
# 4     \\cajal\cajal_data2\ONE\Adaptation    wm42  2025-03-27    003
# ...                                  ...     ...         ...    ...
# 1673  \\cajal\cajal_data2\ONE\Adaptation    wm42  2025-03-27    003
# 1674  \\cajal\cajal_data2\ONE\Adaptation    wm42  2025-03-27    003
# 1675  \\cajal\cajal_data2\ONE\Adaptation    wm42  2025-03-27    003
# 1676  \\cajal\cajal_data2\ONE\Adaptation    wm42  2025-03-27    003
# 1677  \\cajal\cajal_data2\ONE\Adaptation    wm42  2025-03-27    003
#
#                         collection revision             object      attribute  \
# 0                             None     None             trials  eventTimeline
# 1                     imaging_data     None            imaging         frames
# 2                     imaging_data     None            imaging         frames
# 3                     imaging_data     None            imaging         frames
# 4                     imaging_data     None            imaging         frames
# ...                            ...      ...                ...            ...
# 1673  suite2p\plane0\reg_tif_chan2     None  file0082000_chan1           None
# 1674  suite2p\plane0\reg_tif_chan2     None  file0082500_chan1           None
# 1675  suite2p\plane0\reg_tif_chan2     None   file008500_chan1           None
# 1676  suite2p\plane0\reg_tif_chan2     None   file009000_chan1           None
# 1677  suite2p\plane0\reg_tif_chan2     None   file009500_chan1           None
#
#       extra extension
# 0      None      tdms
# 1     00001       tif
# 2     00002       tif
# 3     00003       tif
# 4     00004       tif
# ...     ...       ...
# 1673   None       tif
# 1674   None       tif
# 1675   None       tif
# 1676   None       tif
# 1677   None       tif
#
# [1678 rows x 10 columns]

# %%
file = File.from_path(r"C:/testounet/wm32/2025-06-05/001/imaging_data/file.jpg")
file.dataset_type
# Out:
# 'file'

# %%
connector
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 connector
#
# NameError: name 'connector' is not defined

# %%
import one_registrator 
one_registrator.Config()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 import one_registrator
# ----> 2 one_registrator.Config()
#
# File ~\Documents\Python\__packages__\ONE-registrator\one_registrator\registration.py:692, in Config.__init__(self, rules_path, connector)
#     688 self.excluded_filenames = rules_config.get("excluded_filenames", [])
#     690 self.cleanup_folders = rules_config.get("cleanup_folders", [])
# --> 692 self.dataset_types = get_existing_datasets(connector)
#     693 if len(self.dataset_types) == 0:
#     694     raise ValueError(
#     695         "dataset_types is empty. Cannot register any dataset if no dataset type exists. Maybe one's connector"
#     696         " has a problem ?"
#     697     )
#
# File ~\Documents\Python\__packages__\ONE-registrator\one_registrator\utils.py:21, in get_existing_datasets(one_connector)
#      20 def get_existing_datasets(one_connector):
# ---> 21     existing_dst = one_connector.alyx.rest("dataset-types", "list", no_cache=True)
#      22     existing_types = [
#      23         dst["object"] + "." + dst["attribute"]
#      24         for dst in existing_dst
#      25         if dst["attribute"] != "" and dst["attribute"] != ""
#      26     ]
#      27     return existing_types
#
# AttributeError: 'Connector' object has no attribute 'alyx'

# %%
from re import Pattern

# %%
file.subject = "ROBERT"
file
# Out:
#         <div class="table-container">
#             <table>
#                 <thead>
#                     <th class="title" colspan="10">File :</th>
#                 </thead>
#                 <thead class="head">
#                     <tr>
#                         <th>root</th>
#                         <th>subject</th>
#                         <th>date</th>
#                         <th>number</th>
#                         <th>collection</th>
#                         <th>revision</th>
#                         <th>object</th>
#                         <th>attribute</th>
#                         <th>extra</th>
#                         <th>extension</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr>
#                         <td>C:\testounet</td>
#                         <td>ROBERT</td>
#                         <td>2025-06-05</td>
#                         <td>001</td>
#                         <td>imaging_data</td>
#                         <td></td>
#                         <td>file</td>
#                         <td></td>
#                         <td></td>
#                         <td>jpg</td>
#                     </tr>
#                 </tbody>
#             </table>
#         </div>
#         <style>
#             .table-container{
#                 border: 1px solid rgb(173, 173, 173);
#                 border-radius: 5px;
#                 overflow: hidden;
#                 display: inline-block;
#             }
#             .title{
#                 text-align: left;
#                 white-space: pre;
#                 font-weight: bolder;
#             }
#             table {
#                 font-family: consolas;
#                 border-collapse: collapse;
#             }
#             th, td {
#                 border: 1px solid rgb(160 160 160);
#             }
#             thead:first-of-type th {
#                 border-top: none;
#             }
#             td {
#                 border-bottom: 0px;
#             }
#             th:first-of-type, td:first-of-type {
#                 border-left: none;
#             }
#             td:last-of-type, th:last-of-type {
#                 border-right: none;
#             }
#             thead > tr > th:hover, tbody > tr > td:hover{
#                 background-color: rgba(111, 110, 160, 0.267);
#             }
#         </style>

# %%
file2 = file.copy()

# %%
file2
# Out:
#         <div class="table-container">
#             <table>
#                 <thead>
#                     <th class="title" colspan="10">File :</th>
#                 </thead>
#                 <thead class="head">
#                     <tr>
#                         <th>root</th>
#                         <th>subject</th>
#                         <th>date</th>
#                         <th>number</th>
#                         <th>collection</th>
#                         <th>revision</th>
#                         <th>object</th>
#                         <th>attribute</th>
#                         <th>extra</th>
#                         <th>extension</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr>
#                         <td>C:\testounet</td>
#                         <td>wm32</td>
#                         <td>2025-06-05</td>
#                         <td>001</td>
#                         <td>imaging_data</td>
#                         <td></td>
#                         <td>file</td>
#                         <td></td>
#                         <td></td>
#                         <td>jpg</td>
#                     </tr>
#                 </tbody>
#             </table>
#         </div>
#         <style>
#             .table-container{
#                 border: 1px solid rgb(173, 173, 173);
#                 border-radius: 5px;
#                 overflow: hidden;
#                 display: inline-block;
#             }
#             .title{
#                 text-align: left;
#                 white-space: pre;
#                 font-weight: bolder;
#             }
#             table {
#                 font-family: consolas;
#                 border-collapse: collapse;
#             }
#             th, td {
#                 border: 1px solid rgb(160 160 160);
#             }
#             thead:first-of-type th {
#                 border-top: none;
#             }
#             td {
#                 border-bottom: 0px;
#             }
#             th:first-of-type, td:first-of-type {
#                 border-left: none;
#             }
#             td:last-of-type, th:last-of-type {
#                 border-right: none;
#             }
#             thead > tr > th:hover, tbody > tr > td:hover{
#                 background-color: rgba(111, 110, 160, 0.267);
#             }
#         </style>

# %%
file = File.from_parts(subject = "str")

# %%
file.has_session()
# Out:
# False

# %%
file.object = "testounet"
file.session_name = "wm32/2025-03-12/001"
file.collection = "test/folder"
file.extras = ["testounet", "booyah", "foobar"]
file.root = "//qzd/test/zbrah"

# %%
file
# Out:
#         <div class="table-container">
#             <table>
#                 <thead>
#                     <th class="title" colspan="10">File :</th>
#                 </thead>
#                 <thead class="head">
#                     <tr>
#                         <th>root</th>
#                         <th>subject</th>
#                         <th>date</th>
#                         <th>number</th>
#                         <th>collection</th>
#                         <th>revision</th>
#                         <th>object</th>
#                         <th>attribute</th>
#                         <th>extra</th>
#                         <th>extension</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr>
#                         <td>\\qzd\test\zbrah</td>
#                         <td>wm32</td>
#                         <td>2025-03-12</td>
#                         <td>001</td>
#                         <td>test\folder</td>
#                         <td></td>
#                         <td>testounet</td>
#                         <td></td>
#                         <td>testounet.booyah.foobar</td>
#                         <td></td>
#                     </tr>
#                 </tbody>
#             </table>
#         </div>
#         <style>
#             .table-container{
#                 border: 1px solid rgb(173, 173, 173);
#                 border-radius: 5px;
#                 overflow: hidden;
#                 display: inline-block;
#             }
#             .title{
#                 text-align: left;
#                 white-space: pre;
#                 font-weight: bolder;
#             }
#             table {
#                 font-family: consolas;
#                 border-collapse: collapse;
#             }
#             th, td {
#                 border: 1px solid rgb(160 160 160);
#             }
#             thead:first-of-type th {
#                 border-top: none;
#             }
#             td {
#                 border-bottom: 0px;
#             }
#             th:first-of-type, td:first-of-type {
#                 border-left: none;
#             }
#             td:last-of-type, th:last-of-type {
#                 border-right: none;
#             }
#             thead > tr > th:hover, tbody > tr > td:hover{
#                 background-color: rgba(111, 110, 160, 0.267);
#             }
#         </style>

# %%
file.filename = "janmiche.bonjour.exta1.extra2.textra3.jpg"

# %%
file.revision = "chien"
file
# Out:
#         <div class="table-container">
#             <table>
#                 <thead>
#                     <th class="title" colspan="10">File :</th>
#                 </thead>
#                 <thead class="head">
#                     <tr>
#                         <th>root</th>
#                         <th>subject</th>
#                         <th>date</th>
#                         <th>number</th>
#                         <th>collection</th>
#                         <th>revision</th>
#                         <th>object</th>
#                         <th>attribute</th>
#                         <th>extra</th>
#                         <th>extension</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr>
#                         <td>\\qzd\test\zbrah</td>
#                         <td>wm32</td>
#                         <td>2025-03-12</td>
#                         <td>001</td>
#                         <td>test\folder</td>
#                         <td>chien</td>
#                         <td>janmiche</td>
#                         <td>bonjour</td>
#                         <td>exta1.extra2.textra3</td>
#                         <td>jpg</td>
#                     </tr>
#                 </tbody>
#             </table>
#         </div>
#         <style>
#             .table-container{
#                 border: 1px solid rgb(173, 173, 173);
#                 border-radius: 5px;
#                 overflow: hidden;
#                 display: inline-block;
#             }
#             .title{
#                 text-align: left;
#                 white-space: pre;
#                 font-weight: bolder;
#             }
#             table {
#                 font-family: consolas;
#                 border-collapse: collapse;
#             }
#             th, td {
#                 border: 1px solid rgb(160 160 160);
#             }
#             thead:first-of-type th {
#                 border-top: none;
#             }
#             td {
#                 border-bottom: 0px;
#             }
#             th:first-of-type, td:first-of-type {
#                 border-left: none;
#             }
#             td:last-of-type, th:last-of-type {
#                 border-right: none;
#             }
#             thead > tr > th:hover, tbody > tr > td:hover{
#                 background-color: rgba(111, 110, 160, 0.267);
#             }
#         </style>

# %%
file.from
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 file.to_series
#
# AttributeError: 'File' object has no attribute 'to_series'

# %%
File.from_path(file.fullpath)
# Out:
#         <div class="table-container">
#             <table>
#                 <thead>
#                     <th class="title" colspan="10">File :</th>
#                 </thead>
#                 <thead class="head">
#                     <tr>
#                         <th>root</th>
#                         <th>subject</th>
#                         <th>date</th>
#                         <th>number</th>
#                         <th>collection</th>
#                         <th>revision</th>
#                         <th>object</th>
#                         <th>attribute</th>
#                         <th>extra</th>
#                         <th>extension</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr>
#                         <td>\\qzd\test\zbrah</td>
#                         <td>wm32</td>
#                         <td>2025-03-12</td>
#                         <td>001</td>
#                         <td>test\folder</td>
#                         <td>chien</td>
#                         <td>janmiche</td>
#                         <td>bonjour</td>
#                         <td>exta1.extra2.textra3</td>
#                         <td>jpg</td>
#                     </tr>
#                 </tbody>
#             </table>
#         </div>
#         <style>
#             .table-container{
#                 border: 1px solid rgb(173, 173, 173);
#                 border-radius: 5px;
#                 overflow: hidden;
#                 display: inline-block;
#             }
#             .title{
#                 text-align: left;
#                 white-space: pre;
#                 font-weight: bolder;
#             }
#             table {
#                 font-family: consolas;
#                 border-collapse: collapse;
#             }
#             th, td {
#                 border: 1px solid rgb(160 160 160);
#             }
#             thead:first-of-type th {
#                 border-top: none;
#             }
#             td {
#                 border-bottom: 0px;
#             }
#             th:first-of-type, td:first-of-type {
#                 border-left: none;
#             }
#             td:last-of-type, th:last-of-type {
#                 border-right: none;
#             }
#             thead > tr > th:hover, tbody > tr > td:hover{
#                 background-color: rgba(111, 110, 160, 0.267);
#             }
#         </style>

# %%
file.fullpath
# Out:
# WindowsPath('//qzd/test/zbrah/wm32/2025-03-12/001/test/folder/#chien#/janmiche.bonjour.exta1.extra2.textra3.jpg')

# %%
connector = Connector(url="127.0.0.1")

# %%
connector = Connector(url="haiss-alyx-dev")

# %%
result = connector.search(subject = "wm28", endpoint = "datasets")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\urllib3\connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\urllib3\connection.py:445, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     444     self.putheader(header, value)
# --> 445 self.endheaders()
#     447 # If we're given a body we start sending that in chunks.
#
# File C:\Python312\Lib\http\client.py:1314, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1313     raise CannotSendHeader()
# -> 1314 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File C:\Python312\Lib\http\client.py:1074, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1073 del self._buffer[:]
# -> 1074 self.send(msg)
#    1076 if message_body is not None:
#    1077
#    1078     # create a consistent interface to message_body
#
# File C:\Python312\Lib\http\client.py:1018, in HTTPConnection.send(self, data)
#    1017 if self.auto_open:
# -> 1018     self.connect()
#    1019 else:
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\urllib3\connection.py:276, in HTTPConnection.connect(self)
#     275 def connect(self) -> None:
# --> 276     self.sock = self._new_conn()
#     277     if self._tunnel_host:
#     278         # If we're tunneling it means we're connected to our proxy.
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\urllib3\connection.py:213, in HTTPConnection._new_conn(self)
#     212 except OSError as e:
# --> 213     raise NewConnectionError(
#     214         self, f"Failed to establish a new connection: {e}"
#     215     ) from e
#     217 sys.audit("http.client.connect", self, self.host, self.port)
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000017630F441D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=80): Max retries exceeded with url: /api/schema (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000017630F441D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\openapi_parser\resolver.py:36, in OpenAPIResolver.resolve(self)
#      35 logger.debug(f"Resolving specification file")
# ---> 36 self._resolver.parse()
#      37 return self._resolver.specification
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\prance\__init__.py:135, in BaseParser.parse(self)
#     134     encoding = self.options.get("encoding", None)
# --> 135     self.specification = fetch_url(self.url, encoding=encoding, strict=strict)
#     137 # If we have a spec string, try to parse it.
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\prance\util\url.py:240, in fetch_url(url, cache, encoding, strict)
#     239 # Fetch URL text
# --> 240 content, content_type = fetch_url_text(url, cache, encoding=encoding)
#     242 # Parse the result
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\prance\util\url.py:205, in fetch_url_text(url, cache, encoding)
#     203 import requests
# --> 205 response = requests.get(url.geturl())
#     206 if not response.ok:  # pragma: nocover
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)     70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\requests\adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='127.0.0.1', port=80): Max retries exceeded with url: /api/schema (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000017630F441D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:45, in OpenAPISpecification.from_url(url)
#      44 with filter_message(logger, "Implicit type assignment: schema does not contain 'type' property"):
# ---> 45     specification = parse_openapi_schema(url)
#      46 specification.paths_dict = {path.url: path for path in specification.paths}  # type: ignore
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\openapi_parser\parser.py:142, in parse(uri, spec_string, strict_enum)
#     141 resolver = OpenAPIResolver(uri, spec_string)
# --> 142 specification = resolver.resolve()
#     144 parser = _create_parser(strict_enum=strict_enum)
#
# File c:\Users\tjostmou\Documents\Python\__packages__\alyx-connector\.venv\Lib\site-packages\openapi_parser\resolver.py:41, in OpenAPIResolver.resolve(self)
#      40 except Exception as error:
# ---> 41     raise ParserError(f"OpenAPI file parsing error: {error}")
#
# ParserError: OpenAPI file parsing error: HTTPConnectionPool(host='127.0.0.1', port=80): Max retries exceeded with url: /api/schema (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000017630F441D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 result = connector.search(subject = "wm28", endpoint = "datasets")
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\connector\core.py:65, in Connector.search(self, endpoint, id, details, **kwargs)
#      45 """Search for items in a specified endpoint.
#      46
#      47 This method allows you to search for items in a given endpoint, with the option to retrieve details for a
#    (...)     62     ValueError: If the search result is empty and details are requested.
#      63 """
#      64 action = "list"
# ---> 65 endpoint_implements_retrieve = "retrieve" in self.web_client.endpoint(endpoint).actions.keys()
#      67 if id and endpoint_implements_retrieve:
#      68     action = "retrieve"
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:168, in Endpoint.actions(self)
#     164 @property
#     165 def actions(self):
#     166     return {
#     167         operation.operation_id.split("_")[-1]: Operateur(route, self.client, operation)
# --> 168         for route in self.routes
#     169         for operation in self.client.schema.paths_dict[route].operations
#     170         if operation.operation_id is not None
#     171     }
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:162, in Endpoint.routes(self)
#     160 search_path = self.path.replace("/", r"\/")
#     161 pattern = re.compile(rf"^{search_path}(?:(?=\/{{).*)?$")
# --> 162 return [EndpointUrl(key, self.client) for key in self.client.schema.paths_dict.keys() if pattern.match(key)]
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\clients.py:70, in Client.schema(self)
#      67 @property
#      68 def schema(self) -> Specification:
#      69     if not hasattr(self, "_schema"):
# ---> 70         self._schema = self.specification_class.from_url(self.url + self.schema_endpoint)
#      71     return self._schema
#
# File ~\Documents\Python\__packages__\alyx-connector\src\alyx_connector\web\api.py:49, in OpenAPISpecification.from_url(url)
#      47     return specification  # type: ignore
#      48 except ParserError:
# ---> 49     raise ConnectionError(
#      50         f"Can't connect to {url}.\n" + "Check your internet connections and Alyx database firewall"
#      51     )
#
# ConnectionError: Can't connect to http://127.0.0.1:80/api/schema.
# Check your internet connections and Alyx database firewall

# %%
connector.web_client.endpoint("surgeries").actions.keys()
# Out:
# dict_keys(['list'])

# %%
from alyx_connector.web.clients import WebClient
client = WebClient(username="tjostmou")
client.config.current_user_config.make_all_default()
result = client.rest("sessions","retrieve", id = '1cae805a-5fd8-4798-ac83-64ac1850f29d')
# Out:
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property
# Implicit type assignment: schema does not contain 'type' property

# %%
result
# Out:
# {'id': '1cae805a-5fd8-4798-ac83-64ac1850f29d',
#  'subject': 'ea04',
#  'users': ['eachirou'],
#  'location': None,
#  'procedures': ['Two photon Imaging'],
#  'lab': 'HaissLab',
#  'projects': ['MotorSense'],
#  'type': None,
#  'task_protocol': '',
#  'number': 1,
#  'start_time': '2024-04-04T17:08:00+02:00',
#  'end_time': '2024-04-04T17:50:04+02:00',
#  'narrative': 'stims :\r\n- B3 : right\r\n- Nothing : left\r\n\r\nTrapezoidal stimuli\r\n30ms 0.5 ramp',
#  'parent_session': None,
#  'n_correct_trials': None,
#  'n_trials': None,
#  'url': 'http://127.0.0.1/sessions/1cae805a-5fd8-4798-ac83-64ac1850f29d',
#  'extended_qc': None,
#  'qc': 'NOT_SET',
#  'wateradmin_session_related': [],
#  'data_dataset_session_related': [{'id': '74ccec69-41d2-40f0-894e-cca9f8e89a56',
#    'url': 'http://127.0.0.1/datasets/74ccec69-41d2-40f0-894e-cca9f8e89a56',
#    'admin_url': '/admin/data/dataset/74ccec69-41d2-40f0-894e-cca9f8e89a56/change/',
#    'name': 'behaviour.video.tdms',
#    'created_by': 'eachirou',
#    'created_datetime': '2024-04-04T20:26:02.509369+02:00',
#    'data_repository': 'Cajal2MotorSense',
#    'file_size': None,
#    'version': None,
#    'auto_datetime': '2024-04-04T20:26:02.511610+02:00',
#    'dataset_type': 'behaviour.video',
#    'default_dataset': True,
#    'tags': [],
#    'session': 'ea04_2024-04-04_001',
#    'data_format': '.tdms',
#    'data_repository_pk': '70a43e0f-09b3-4c0f-996c-12edbdaff06d',
#    'data_format_pk': '47bcdd69-8754-4045-ba05-0b59c9dba75b',
#    'revision_pk': None,
#    'dataset_type_pk': 'e37eec5d-60be-4bdb-9c57-07fe17546459',
#    'session_pk': '1cae805a-5fd8-4798-ac83-64ac1850f29d',
#    'remote_root': '//cajal/cajal_data2/ONE/MotorSense',
#    'subject': 'ea04',
#    'date': '2024-04-04',
#    'number': 1,
#    'collection': 'behaviour_imaging/whiskers',
#    'revision': '',
#    'object': 'behaviour',
#    'attribute': 'video',
#    'extension': '.tdms',
#    'file_records': [{'id': '460aadbf-4038-4b59-9362-9b7c1f4dba60',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00000.tdms',
#      'extra': 'whiskers.00000',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00000.tdms',
#      'hash': None},
#     {'id': '006133a8-b3c7-4a52-88db-dc46968c5774',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00001.tdms',
#      'extra': 'whiskers.00001',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00001.tdms',
#      'hash': None},
#     {'id': 'c70199aa-ffcf-4c58-aa14-53c0195f5cf6',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00010.tdms',
#      'extra': 'whiskers.00010',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00010.tdms',
#      'hash': None},
#     {'id': 'dd18dc6f-f58e-44ef-a595-0dca48d41b2f',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00100.tdms',
#      'extra': 'whiskers.00100',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00100.tdms',
#      'hash': None},
#     {'id': 'f363955b-0780-49c7-bce8-f98b58003836',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00101.tdms',
#      'extra': 'whiskers.00101',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00101.tdms',
#      'hash': None},
#     {'id': '470cb92f-da06-4d74-810d-20b096f8cbac',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00102.tdms',
#      'extra': 'whiskers.00102',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00102.tdms',
#      'hash': None},
#     {'id': '46b73fa9-2659-4a64-84b9-78d43bf77054',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00103.tdms',
#      'extra': 'whiskers.00103',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00103.tdms',
#      'hash': None},
#     {'id': '0d5b25e2-5298-4edf-a200-a614c481498e',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00104.tdms',
#      'extra': 'whiskers.00104',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00104.tdms',
#      'hash': None},
#     {'id': 'fc7204d2-3c95-4b71-aa5b-0a1c43e04051',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00105.tdms',
#      'extra': 'whiskers.00105',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00105.tdms',
#      'hash': None},
#     {'id': 'ce474c9b-7642-4444-95de-a2e9b2c05fcd',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00106.tdms',
#      'extra': 'whiskers.00106',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00106.tdms',
#      'hash': None},
#     {'id': '8ffcd120-29fd-4590-93fb-432909e5068e',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00107.tdms',
#      'extra': 'whiskers.00107',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00107.tdms',
#      'hash': None},
#     {'id': '0d1d4af3-2cce-46dc-8682-9ae8f2c1fdf1',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00108.tdms',
#      'extra': 'whiskers.00108',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00108.tdms',
#      'hash': None},
#     {'id': '8acec201-2769-48ee-ae12-7747b8a4aeb4',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00109.tdms',
#      'extra': 'whiskers.00109',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00109.tdms',
#      'hash': None},
#     {'id': '91d9360c-4d86-4abb-92e3-af7133f1e2ef',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00011.tdms',
#      'extra': 'whiskers.00011',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00011.tdms',
#      'hash': None},
#     {'id': 'f7c42fa0-9929-4444-be5e-d978d299bdfc',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00110.tdms',
#      'extra': 'whiskers.00110',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00110.tdms',
#      'hash': None},
#     {'id': 'ff081868-37be-4551-adae-33c7399ea70d',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00111.tdms',
#      'extra': 'whiskers.00111',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00111.tdms',
#      'hash': None},
#     {'id': '6543600d-e929-4cc7-9e8d-efc6a866f4d1',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00112.tdms',
#      'extra': 'whiskers.00112',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00112.tdms',
#      'hash': None},
#     {'id': 'a8d38a91-2778-411c-87f8-3db7cb9b5a4b',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00113.tdms',
#      'extra': 'whiskers.00113',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00113.tdms',
#      'hash': None},
#     {'id': '8eebabe0-c020-46e4-a669-722b0b32d56c',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00114.tdms',
#      'extra': 'whiskers.00114',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00114.tdms',
#      'hash': None},
#     {'id': '2c980225-0283-46c4-b8c7-e4c00486bf7b',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00115.tdms',
#      'extra': 'whiskers.00115',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00115.tdms',
#      'hash': None},
#     {'id': 'da2c749a-fdcb-4fb5-a89e-cde34404dfcf',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00116.tdms',
#      'extra': 'whiskers.00116',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00116.tdms',
#      'hash': None},
#     {'id': 'd32763b8-5610-463a-bcb6-f60286b6fa73',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00117.tdms',
#      'extra': 'whiskers.00117',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00117.tdms',
#      'hash': None},
#     {'id': 'f0399b63-4912-42d7-bace-916103eb1a8d',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00118.tdms',
#      'extra': 'whiskers.00118',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00118.tdms',
#      'hash': None},
#     {'id': 'a184bcb0-2ad8-4fc0-897b-3b82a1696d56',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00119.tdms',
#      'extra': 'whiskers.00119',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00119.tdms',
#      'hash': None},
#     {'id': '19a0ba7b-c70c-4f2e-b8de-f27225989d08',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00012.tdms',
#      'extra': 'whiskers.00012',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00012.tdms',
#      'hash': None},
#     {'id': '3309c0c8-1e8e-47cb-814e-8e4daed2988b',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00120.tdms',
#      'extra': 'whiskers.00120',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00120.tdms',
#      'hash': None},
#     {'id': '68367791-3a36-43b5-beae-62aadbf3492a',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00121.tdms',
#      'extra': 'whiskers.00121',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00121.tdms',
#      'hash': None},
#     {'id': '1ae1618f-39b3-454f-a721-25538723e867',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00122.tdms',
#      'extra': 'whiskers.00122',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00122.tdms',
#      'hash': None},
#     {'id': 'f5ebebfc-718b-49a5-bff7-7ce50431792f',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00123.tdms',
#      'extra': 'whiskers.00123',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00123.tdms',
#      'hash': None},
#     {'id': '85f46aff-1f07-4aea-8e08-854fc2007af8',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00124.tdms',
#      'extra': 'whiskers.00124',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00124.tdms',
#      'hash': None},
#     {'id': '9ee50cac-c327-4160-a2ed-79a5a66a58f4',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00125.tdms',
#      'extra': 'whiskers.00125',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00125.tdms',
#      'hash': None},
#     {'id': '4252b289-0af8-442d-bfc8-5098d1994d23',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00126.tdms',
#      'extra': 'whiskers.00126',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00126.tdms',
#      'hash': None},
#     {'id': '4257095d-e533-42b7-913f-d9312da6367b',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00127.tdms',
#      'extra': 'whiskers.00127',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00127.tdms',
#      'hash': None},
#     {'id': 'd47809cb-6361-4fb2-bc03-59374c813df5',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00128.tdms',
#      'extra': 'whiskers.00128',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00128.tdms',
#      'hash': None},
#     {'id': '2f8cdd91-4836-427c-b6a5-ec38693e52f9',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00129.tdms',
#      'extra': 'whiskers.00129',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00129.tdms',
#      'hash': None},
#     {'id': 'cfa7fedc-55e4-4857-81a2-7de9e78270fb',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00013.tdms',
#      'extra': 'whiskers.00013',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00013.tdms',
#      'hash': None},
#     {'id': '0c12178f-39dc-47f7-9740-3f85d293c4ee',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00130.tdms',
#      'extra': 'whiskers.00130',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00130.tdms',
#      'hash': None},
#     {'id': '28e73787-0ae0-440d-9eb9-3f7cd5eaf109',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00131.tdms',
#      'extra': 'whiskers.00131',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00131.tdms',
#      'hash': None},
#     {'id': 'd597ca99-47f6-40d8-bbba-4c36a88ab5d8',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00132.tdms',
#      'extra': 'whiskers.00132',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00132.tdms',
#      'hash': None},
#     {'id': '1ada4b0a-558f-4241-9415-fb36ee9b7d5a',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00133.tdms',
#      'extra': 'whiskers.00133',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00133.tdms',
#      'hash': None},
#     {'id': '50c3c3c5-c8fd-4651-b638-0b05df38fe59',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00134.tdms',
#      'extra': 'whiskers.00134',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00134.tdms',
#      'hash': None},
#     {'id': '3f20b02a-e084-4459-a92a-cae444cc2441',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00135.tdms',
#      'extra': 'whiskers.00135',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00135.tdms',
#      'hash': None},
#     {'id': '35482bec-3ad8-44d9-8748-9404048f35c6',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00136.tdms',
#      'extra': 'whiskers.00136',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00136.tdms',
#      'hash': None},
#     {'id': 'a3cfab64-f942-4b44-b85d-ab2075d05abe',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00137.tdms',
#      'extra': 'whiskers.00137',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00137.tdms',
#      'hash': None},
#     {'id': 'f666aa39-fed3-4000-8cdc-5b532066beb5',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00138.tdms',
#      'extra': 'whiskers.00138',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00138.tdms',
#      'hash': None},
#     {'id': '494cdd8a-2b1c-472e-b2b9-321c3131c266',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00139.tdms',
#      'extra': 'whiskers.00139',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00139.tdms',
#      'hash': None},
#     {'id': 'e09aff3c-bf2c-42f1-80f4-1a21249bd3d7',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00014.tdms',
#      'extra': 'whiskers.00014',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00014.tdms',
#      'hash': None},
#     {'id': '0b3830f1-6bbe-4000-b224-02db5a68219e',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00140.tdms',
#      'extra': 'whiskers.00140',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00140.tdms',
#      'hash': None},
#     {'id': 'c158f9bc-bc60-47e4-ba4e-9029cddbf366',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00141.tdms',
#      'extra': 'whiskers.00141',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00141.tdms',
#      'hash': None},
#     {'id': 'd2490140-652b-4c25-9db5-e1a946259b40',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00142.tdms',
#      'extra': 'whiskers.00142',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00142.tdms',
#      'hash': None},
#     {'id': '81ca16fe-389a-4e0a-95e5-5a171cb48e81',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00143.tdms',
#      'extra': 'whiskers.00143',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00143.tdms',
#      'hash': None},
#     {'id': 'ac6716ca-1359-46c6-88d3-b09362e52239',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00144.tdms',
#      'extra': 'whiskers.00144',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00144.tdms',
#      'hash': None},
#     {'id': '8de34751-f558-4268-b45f-77127de88ce4',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00145.tdms',
#      'extra': 'whiskers.00145',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00145.tdms',
#      'hash': None},
#     {'id': '1be319c3-22f4-43c6-8ff6-b6200c8b4dca',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00146.tdms',
#      'extra': 'whiskers.00146',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00146.tdms',
#      'hash': None},
#     {'id': 'eb780981-b8d9-4517-92f1-a4179b88104d',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00147.tdms',
#      'extra': 'whiskers.00147',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00147.tdms',
#      'hash': None},
#     {'id': '36efc676-c569-4ec9-8699-bb517b5a6e3c',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00148.tdms',
#      'extra': 'whiskers.00148',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00148.tdms',
#      'hash': None},
#     {'id': 'f67fc402-9f67-4f8c-a298-024cf7b39199',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00149.tdms',
#      'extra': 'whiskers.00149',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00149.tdms',
#      'hash': None},
#     {'id': '78aa2bda-5949-410a-8bc0-9d82b515b9cd',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00015.tdms',
#      'extra': 'whiskers.00015',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00015.tdms',
#      'hash': None},
#     {'id': 'db88776d-358f-499d-b9cb-8c2d50e6bd32',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00150.tdms',
#      'extra': 'whiskers.00150',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00150.tdms',
#      'hash': None},
#     {'id': 'a648dc53-2c09-44ad-8e7c-176c8cf2e3b7',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00151.tdms',
#      'extra': 'whiskers.00151',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00151.tdms',
#      'hash': None},
#     {'id': '7043ba5c-919a-4d0b-8189-75f401eaf604',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00152.tdms',
#      'extra': 'whiskers.00152',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00152.tdms',
#      'hash': None},
#     {'id': 'd1e2b459-4ef5-4b1e-b64e-6507eabc10c1',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00153.tdms',
#      'extra': 'whiskers.00153',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00153.tdms',
#      'hash': None},
#     {'id': '68c9b892-bae3-4d2a-9318-d2a2c4579090',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00154.tdms',
#      'extra': 'whiskers.00154',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00154.tdms',
#      'hash': None},
#     {'id': '594cdd57-0764-4c43-aadf-5804cc414ae8',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00155.tdms',
#      'extra': 'whiskers.00155',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00155.tdms',
#      'hash': None},
#     {'id': '7bd74c11-b770-4e0b-8bbe-e342b7e62c67',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00156.tdms',
#      'extra': 'whiskers.00156',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00156.tdms',
#      'hash': None},
#     {'id': '4868cc0c-911d-4537-8ec6-c7c78d21b59e',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00157.tdms',
#      'extra': 'whiskers.00157',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00157.tdms',
#      'hash': None},
#     {'id': 'e76039c0-352c-4218-9dc5-4fde07946e22',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00158.tdms',
#      'extra': 'whiskers.00158',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00158.tdms',
#      'hash': None},
#     {'id': '9406fb49-7541-4d58-a476-faac3694fca7',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00159.tdms',
#      'extra': 'whiskers.00159',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00159.tdms',
#      'hash': None},
#     {'id': 'e5ce38ca-d6b4-47c8-8784-7299a90c93d0',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00016.tdms',
#      'extra': 'whiskers.00016',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00016.tdms',
#      'hash': None},
#     {'id': 'ac7c1756-82ad-4242-ae73-5afe58e696b8',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00160.tdms',
#      'extra': 'whiskers.00160',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00160.tdms',
#      'hash': None},
#     {'id': '4d2352ac-b40d-4317-b516-dea15e52b8ff',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00161.tdms',
#      'extra': 'whiskers.00161',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00161.tdms',
#      'hash': None},
#     {'id': 'd02444b2-6273-4741-b14c-e533ba058158',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00162.tdms',
#      'extra': 'whiskers.00162',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00162.tdms',
#      'hash': None},
#     {'id': '15c7cf4e-6271-4a3d-ad4e-5042f7196381',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00163.tdms',
#      'extra': 'whiskers.00163',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00163.tdms',
#      'hash': None},
#     {'id': '8bc4a96d-244d-4c54-bf3c-db559a5eb352',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00164.tdms',
#      'extra': 'whiskers.00164',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00164.tdms',
#      'hash': None},
#     {'id': '6c439ef2-7eb9-497a-b8c6-5ced010f7480',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00165.tdms',
#      'extra': 'whiskers.00165',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00165.tdms',
#      'hash': None},
#     {'id': '0fda38d6-48d9-4e6e-8e5b-7e2f2843e14a',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00166.tdms',
#      'extra': 'whiskers.00166',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00166.tdms',
#      'hash': None},
#     {'id': '0ff72d14-1b93-456f-8eaa-967fa5d2389b',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00167.tdms',
#      'extra': 'whiskers.00167',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00167.tdms',
#      'hash': None},
#     {'id': 'a0306d56-88b9-49f5-a166-1c1b44d172b0',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00168.tdms',
#      'extra': 'whiskers.00168',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00168.tdms',
#      'hash': None},
#     {'id': 'bc672d3b-2dad-43e5-87bd-fe3d0b07726f',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00169.tdms',
#      'extra': 'whiskers.00169',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00169.tdms',
#      'hash': None},
#     {'id': '7b4680c8-ab4d-49d1-8ff1-1712123029a2',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00017.tdms',
#      'extra': 'whiskers.00017',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00017.tdms',
#      'hash': None},
#     {'id': '72e80e11-6b62-4a83-b29d-266d62af4bf6',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00170.tdms',
#      'extra': 'whiskers.00170',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00170.tdms',
#      'hash': None},
#     {'id': '3d0bd910-54b6-42df-b8f0-eec01c6cf450',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00171.tdms',
#      'extra': 'whiskers.00171',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00171.tdms',
#      'hash': None},
#     {'id': '8aab42e9-21bd-41c0-a875-f51f9df8f03f',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00172.tdms',
#      'extra': 'whiskers.00172',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00172.tdms',
#      'hash': None},
#     {'id': 'c459dd9f-7665-4312-a168-2c3bb75aecca',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00173.tdms',
#      'extra': 'whiskers.00173',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00173.tdms',
#      'hash': None},
#     {'id': '220271c9-efe2-4fde-8a84-0a8828b160fb',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00174.tdms',
#      'extra': 'whiskers.00174',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00174.tdms',
#      'hash': None},
#     {'id': '521c6056-17a6-45e4-8d90-43cede0bb41e',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00175.tdms',
#      'extra': 'whiskers.00175',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00175.tdms',
#      'hash': None},
#     {'id': '9c445394-1433-4582-ba02-9dda6d3aade9',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00176.tdms',
#      'extra': 'whiskers.00176',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00176.tdms',
#      'hash': None},
#     {'id': 'b3313788-1ec4-40d3-9c0a-7a6b41500a6d',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00177.tdms',
#      'extra': 'whiskers.00177',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00177.tdms',
#      'hash': None},
#     {'id': '3ed0f086-9b5a-48ff-b949-5f8456d89c05',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00178.tdms',
#      'extra': 'whiskers.00178',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00178.tdms',
#      'hash': None},
#     {'id': '877c169f-1f16-44a8-8271-9b1a23480ca8',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00179.tdms',
#      'extra': 'whiskers.00179',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00179.tdms',
#      'hash': None},
#     {'id': '38ef5e58-28c7-41ad-9c20-10294c81d189',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00018.tdms',
#      'extra': 'whiskers.00018',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00018.tdms',
#      'hash': None},
#     {'id': 'b96dea37-9b34-41f3-91f8-a832f335170d',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00180.tdms',
#      'extra': 'whiskers.00180',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00180.tdms',
#      'hash': None},
#     {'id': '80d297be-ac33-4588-9d0c-4129e03a4293',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00181.tdms',
#      'extra': 'whiskers.00181',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00181.tdms',
#      'hash': None},
#     {'id': '902785f3-cfb4-41d9-9eca-f98eb6203456',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00182.tdms',
#      'extra': 'whiskers.00182',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00182.tdms',
#      'hash': None},
#     {'id': 'e885911e-b524-4521-a5bd-7ff01a398cd9',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00183.tdms',
#      'extra': 'whiskers.00183',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00183.tdms',
#      'hash': None},
#     {'id': '8a20d061-9be6-49ad-8533-d9c054066d32',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00184.tdms',
#      'extra': 'whiskers.00184',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00184.tdms',
#      'hash': None},
#     {'id': 'a1459703-aa26-4f5d-bb66-f89395db8b98',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00185.tdms',
#      'extra': 'whiskers.00185',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00185.tdms',
#      'hash': None},
#     {'id': '75d93e16-3ff0-47ae-a7f5-97b8fe303c3a',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00186.tdms',
#      'extra': 'whiskers.00186',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00186.tdms',
#      'hash': None},
#     {'id': '21a66918-a982-4e3d-b5b0-1bd518ae095d',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00187.tdms',
#      'extra': 'whiskers.00187',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00187.tdms',
#      'hash': None},
#     {'id': '2ebe9a75-6b13-4888-a971-9ac5292a4989',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00188.tdms',
#      'extra': 'whiskers.00188',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00188.tdms',
#      'hash': None},
#     {'id': 'a8606ee0-08d7-451c-baca-a19bffaaad6c',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00189.tdms',
#      'extra': 'whiskers.00189',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00189.tdms',
#      'hash': None},
#     {'id': '93b4c471-f540-4a5b-a334-0223ecc9c026',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00019.tdms',
#      'extra': 'whiskers.00019',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00019.tdms',
#      'hash': None},
#     {'id': '4a330457-a8b4-4941-950a-d6e01f69e757',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00190.tdms',
#      'extra': 'whiskers.00190',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00190.tdms',
#      'hash': None},
#     {'id': '969261ba-8bf3-41d9-b6c6-efacf24021af',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00191.tdms',
#      'extra': 'whiskers.00191',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00191.tdms',
#      'hash': None},
#     {'id': '0f220871-a82c-4971-8c7c-a558ae9b1fab',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00192.tdms',
#      'extra': 'whiskers.00192',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00192.tdms',
#      'hash': None},
#     {'id': '9de2e334-681d-4491-a866-105412f5ff96',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00193.tdms',
#      'extra': 'whiskers.00193',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00193.tdms',
#      'hash': None},
#     {'id': '0a298190-22a5-47ea-903d-08ad3e82def8',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00194.tdms',
#      'extra': 'whiskers.00194',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00194.tdms',
#      'hash': None},
#     {'id': 'bcbd6aec-7938-4bd2-9d17-b84b19c4c558',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00195.tdms',
#      'extra': 'whiskers.00195',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00195.tdms',
#      'hash': None},
#     {'id': '7e9f5273-f359-4f7d-82d5-d7a5b7926311',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00196.tdms',
#      'extra': 'whiskers.00196',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00196.tdms',
#      'hash': None},
#     {'id': 'a262d5ba-96ac-42b8-b7a5-08cab600e49b',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00197.tdms',
#      'extra': 'whiskers.00197',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00197.tdms',
#      'hash': None},
#     {'id': '5ab5de45-0f02-4acc-89bb-8b4c9cd25438',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00198.tdms',
#      'extra': 'whiskers.00198',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00198.tdms',
#      'hash': None},
#     {'id': 'f9896e43-2cb5-491f-b861-a290a32cb946',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00199.tdms',
#      'extra': 'whiskers.00199',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00199.tdms',
#      'hash': None},
#     {'id': '0249ee0f-a197-482a-97b7-cf49a4bbd3db',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00002.tdms',
#      'extra': 'whiskers.00002',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00002.tdms',
#      'hash': None},
#     {'id': 'e7ee4d9c-e2cc-4ff8-88f2-e71ff3f262e2',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00020.tdms',
#      'extra': 'whiskers.00020',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00020.tdms',
#      'hash': None},
#     {'id': 'b7d58b0b-06d2-46c0-a7e4-1d206055ce9e',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00200.tdms',
#      'extra': 'whiskers.00200',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00200.tdms',
#      'hash': None},
#     {'id': '15a57a4c-418b-44d8-8e5c-ab2ed66646f1',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00201.tdms',
#      'extra': 'whiskers.00201',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00201.tdms',
#      'hash': None},
#     {'id': '8a2279f7-61d6-40c0-8800-e6d0efb85683',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00202.tdms',
#      'extra': 'whiskers.00202',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00202.tdms',
#      'hash': None},
#     {'id': 'ea575024-8967-47a2-9656-6de84f0da7b5',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00203.tdms',
#      'extra': 'whiskers.00203',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00203.tdms',
#      'hash': None},
#     {'id': 'f71e0fab-aec8-4f82-8c86-4624aec141a7',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00204.tdms',
#      'extra': 'whiskers.00204',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00204.tdms',
#      'hash': None},
#     {'id': 'b2d909d4-9c21-462a-97ae-230d063cb2f7',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00205.tdms',
#      'extra': 'whiskers.00205',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00205.tdms',
#      'hash': None},
#     {'id': 'b07cfdf4-d650-4ec8-8b2f-038af41986a9',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00206.tdms',
#      'extra': 'whiskers.00206',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00206.tdms',
#      'hash': None},
#     {'id': '8f05a36e-0616-4d1c-89de-d80361e1841c',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00207.tdms',
#      'extra': 'whiskers.00207',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00207.tdms',
#      'hash': None},
#     {'id': '522af986-908b-4017-83ed-22d20f961c15',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00208.tdms',
#      'extra': 'whiskers.00208',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00208.tdms',
#      'hash': None},
#     {'id': '9edf2e90-ea48-4e91-b4c9-c222a9065f0a',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00209.tdms',
#      'extra': 'whiskers.00209',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00209.tdms',
#      'hash': None},
#     {'id': '431dd87f-f887-4328-8fc9-d493501b60b5',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00021.tdms',
#      'extra': 'whiskers.00021',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00021.tdms',
#      'hash': None},
#     {'id': 'af16c5f4-590d-4f3b-a7e0-b34f6d5c973f',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00210.tdms',
#      'extra': 'whiskers.00210',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00210.tdms',
#      'hash': None},
#     {'id': '616b8cf1-5b2b-4ee4-b522-5348eb35880b',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00211.tdms',
#      'extra': 'whiskers.00211',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00211.tdms',
#      'hash': None},
#     {'id': 'ef82f322-8f96-49ec-93a1-3546c4af192a',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00212.tdms',
#      'extra': 'whiskers.00212',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00212.tdms',
#      'hash': None},
#     {'id': '63cd3cfe-15e7-4a53-9c70-96023f361c6e',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00213.tdms',
#      'extra': 'whiskers.00213',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00213.tdms',
#      'hash': None},
#     {'id': '65d0b681-c5c3-4a14-8c60-ca98f35bd560',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00214.tdms',
#      'extra': 'whiskers.00214',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00214.tdms',
#      'hash': None},
#     {'id': '5b423f53-3255-4172-a457-dd05897c98db',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00215.tdms',
#      'extra': 'whiskers.00215',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00215.tdms',
#      'hash': None},
#     {'id': '36c84100-5626-4c64-84ff-a81982464bb0',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00216.tdms',
#      'extra': 'whiskers.00216',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00216.tdms',
#      'hash': None},
#     {'id': 'fd29d0ae-fdfc-4e74-81b5-8f5a880590c8',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00217.tdms',
#      'extra': 'whiskers.00217',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00217.tdms',
#      'hash': None},
#     {'id': '7a0fa05a-bd3c-4157-9094-89be60dc572b',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00218.tdms',
#      'extra': 'whiskers.00218',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00218.tdms',
#      'hash': None},
#     {'id': 'ac56abf0-3e97-4b31-a5b2-437eb3bc71bc',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00219.tdms',
#      'extra': 'whiskers.00219',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00219.tdms',
#      'hash': None},
#     {'id': 'e84fd382-6307-4137-b2d0-6424800ea718',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00022.tdms',
#      'extra': 'whiskers.00022',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00022.tdms',
#      'hash': None},
#     {'id': 'c829f4ee-2195-468d-87c8-2eb911548ae5',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00220.tdms',
#      'extra': 'whiskers.00220',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00220.tdms',
#      'hash': None},
#     {'id': 'e8f6a239-30f1-4f06-ae80-4ee172b0fb70',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00221.tdms',
#      'extra': 'whiskers.00221',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00221.tdms',
#      'hash': None},
#     {'id': 'cff74874-5316-42ef-9044-f125883331db',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00222.tdms',
#      'extra': 'whiskers.00222',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00222.tdms',
#      'hash': None},
#     {'id': '4e7fe4f6-7689-4847-8522-8e8a72f3a0ad',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00223.tdms',
#      'extra': 'whiskers.00223',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00223.tdms',
#      'hash': None},
#     {'id': '797a49bb-fde9-44de-b704-ed89caafe5ea',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00224.tdms',
#      'extra': 'whiskers.00224',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00224.tdms',
#      'hash': None},
#     {'id': '9ecd6e29-8228-4be3-93fd-482baa20e398',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00225.tdms',
#      'extra': 'whiskers.00225',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00225.tdms',
#      'hash': None},
#     {'id': '294a7af3-4ff5-45c4-b5a1-0d8497284083',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00226.tdms',
#      'extra': 'whiskers.00226',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00226.tdms',
#      'hash': None},
#     {'id': '221d66c2-edcc-4985-802c-1ac73e8bc3ac',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00227.tdms',
#      'extra': 'whiskers.00227',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00227.tdms',
#      'hash': None},
#     {'id': 'f984ba73-b893-48b8-aa71-3ef5e38e5561',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00228.tdms',
#      'extra': 'whiskers.00228',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00228.tdms',
#      'hash': None},
#     {'id': '09942f36-d299-4e33-9759-fd26fe1783f7',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00229.tdms',
#      'extra': 'whiskers.00229',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00229.tdms',
#      'hash': None},
#     {'id': '5ce95ad4-fb45-407b-bf69-c256ca0a3b5c',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00023.tdms',
#      'extra': 'whiskers.00023',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00023.tdms',
#      'hash': None},
#     {'id': '84dac6f7-657a-4bcc-a39a-d48bde3b024a',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00230.tdms',
#      'extra': 'whiskers.00230',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00230.tdms',
#      'hash': None},
#     {'id': '4ad6c9fe-9ee5-4197-9a1b-5d2df4c039c8',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00231.tdms',
#      'extra': 'whiskers.00231',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00231.tdms',
#      'hash': None},
#     {'id': 'fb527daf-3522-4f60-9890-eef128ff3f25',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00232.tdms',
#      'extra': 'whiskers.00232',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00232.tdms',
#      'hash': None},
#     {'id': '74b48521-8f0f-496f-983f-428c8c82391f',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00233.tdms',
#      'extra': 'whiskers.00233',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00233.tdms',
#      'hash': None},
#     {'id': 'f4e91c5f-9d39-49ca-9203-34f25798028e',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00234.tdms',
#      'extra': 'whiskers.00234',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00234.tdms',
#      'hash': None},
#     {'id': '9db3a73f-d6fd-4cb0-ae0b-bf27431390ed',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00235.tdms',
#      'extra': 'whiskers.00235',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00235.tdms',
#      'hash': None},
#     {'id': '3497230c-2de3-4b84-867b-ecd94cba3e41',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00236.tdms',
#      'extra': 'whiskers.00236',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00236.tdms',
#      'hash': None},
#     {'id': 'fd8779d5-7b3f-4d54-8e19-411a4928a23c',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00237.tdms',
#      'extra': 'whiskers.00237',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00237.tdms',
#      'hash': None},
#     {'id': '17e24d0e-2d81-4997-82e0-6c3752839ae5',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00238.tdms',
#      'extra': 'whiskers.00238',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00238.tdms',
#      'hash': None},
#     {'id': '62acc232-4513-46f2-8198-fb614deca1d8',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00239.tdms',
#      'extra': 'whiskers.00239',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00239.tdms',
#      'hash': None},
#     {'id': 'd4c148e0-a688-418d-9e58-2b1916bf4849',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00024.tdms',
#      'extra': 'whiskers.00024',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00024.tdms',
#      'hash': None},
#     {'id': 'd0dd942d-11a3-4b9f-ab0f-9b46acbfb0bd',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00240.tdms',
#      'extra': 'whiskers.00240',
#      'exists': True,
#      'file_name': 'behaviour.video.whiskers.00240.tdms',
#      'hash': None},
#     {'id': '909ec33a-f5d5-4c87-b5e3-0fe873459dca',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video.whiskers.00241.tdms',
#      'extra': 'whiskers.00241',
# ...
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00261.json',
#      'extra': 'whiskers.00261',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00261.json',
#      'hash': None},
#     {'id': 'aa196865-6160-41c8-b5d7-2dedfef410f8',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00262.json',
#      'extra': 'whiskers.00262',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00262.json',
#      'hash': None},
#     {'id': '21cd7899-ec05-485a-81d0-62ce87506c87',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00263.json',
#      'extra': 'whiskers.00263',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00263.json',
#      'hash': None},
#     {'id': '5328bf0b-aa9a-48ac-a405-68f9a135a3f5',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00264.json',
#      'extra': 'whiskers.00264',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00264.json',
#      'hash': None},
#     {'id': 'e7c3ec41-7c79-40bf-8056-b2c4e77d36a8',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00265.json',
#      'extra': 'whiskers.00265',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00265.json',
#      'hash': None},
#     {'id': '348cf459-d8a1-43ce-9d5f-57210ea221b6',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00266.json',
#      'extra': 'whiskers.00266',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00266.json',
#      'hash': None},
#     {'id': '5427637f-3a54-4d4f-97a3-72ee69224d3a',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00267.json',
#      'extra': 'whiskers.00267',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00267.json',
#      'hash': None},
#     {'id': '74dd8670-4c1b-4f61-bb1a-36304c2e5673',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00268.json',
#      'extra': 'whiskers.00268',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00268.json',
#      'hash': None},
#     {'id': '2b994ccf-76fb-484d-a77b-015d98cee419',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00269.json',
#      'extra': 'whiskers.00269',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00269.json',
#      'hash': None},
#     {'id': '3d50a797-43c7-4108-86d1-2d034125da38',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00027.json',
#      'extra': 'whiskers.00027',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00027.json',
#      'hash': None},
#     {'id': '0bfaf120-d81c-4c24-b61f-d08bf93dfbef',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00270.json',
#      'extra': 'whiskers.00270',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00270.json',
#      'hash': None},
#     {'id': '5cbf6033-755d-4213-9bf2-4b8c1acdb4fa',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00271.json',
#      'extra': 'whiskers.00271',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00271.json',
#      'hash': None},
#     {'id': '7fb1d9a3-88f6-4363-9cd9-b6e8d1590835',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00272.json',
#      'extra': 'whiskers.00272',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00272.json',
#      'hash': None},
#     {'id': '6a48a12c-c008-4c6f-b864-2d13e7d97013',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00273.json',
#      'extra': 'whiskers.00273',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00273.json',
#      'hash': None},
#     {'id': '9b7e1f5f-f232-4621-b7af-e2388330cca0',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00274.json',
#      'extra': 'whiskers.00274',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00274.json',
#      'hash': None},
#     {'id': 'f56fc62b-7544-46fe-910f-106be1e91e16',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00275.json',
#      'extra': 'whiskers.00275',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00275.json',
#      'hash': None},
#     {'id': '907053ff-7951-45ec-a4c9-86305387b700',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00276.json',
#      'extra': 'whiskers.00276',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00276.json',
#      'hash': None},
#     {'id': '06aa9c02-4a5a-4e7f-a372-52c5d2f5f0d0',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00277.json',
#      'extra': 'whiskers.00277',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00277.json',
#      'hash': None},
#     {'id': 'eb43e83f-d72c-450d-987f-4a51a6a7f63c',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00278.json',
#      'extra': 'whiskers.00278',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00278.json',
#      'hash': None},
#     {'id': 'bf6a6350-1b77-460b-9c8f-4cf741eea5a1',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00279.json',
#      'extra': 'whiskers.00279',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00279.json',
#      'hash': None},
#     {'id': 'a1cc9b48-af0b-417d-b973-f06bc931510f',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00028.json',
#      'extra': 'whiskers.00028',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00028.json',
#      'hash': None},
#     {'id': '15aecbdf-a43e-479c-aa4f-6c991e685aca',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00280.json',
#      'extra': 'whiskers.00280',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00280.json',
#      'hash': None},
#     {'id': '25a3bc87-21f8-47a8-9ff2-0c7cabff3766',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00281.json',
#      'extra': 'whiskers.00281',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00281.json',
#      'hash': None},
#     {'id': '6737e11f-40d9-4fbe-879e-816ff8df4126',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00282.json',
#      'extra': 'whiskers.00282',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00282.json',
#      'hash': None},
#     {'id': 'ab862bf2-b77a-4f8b-a967-e65547de9b1d',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00283.json',
#      'extra': 'whiskers.00283',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00283.json',
#      'hash': None},
#     {'id': '896ed2c1-6973-4433-8b01-fbfbe3b56d03',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00284.json',
#      'extra': 'whiskers.00284',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00284.json',
#      'hash': None},
#     {'id': '85dc6e65-9690-4ad2-ac40-60e70b82d6c0',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00285.json',
#      'extra': 'whiskers.00285',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00285.json',
#      'hash': None},
#     {'id': '4ce7ca35-f42d-4594-aba3-0705c089c97f',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00286.json',
#      'extra': 'whiskers.00286',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00286.json',
#      'hash': None},
#     {'id': 'ed76c6cd-8f16-4679-a5e0-23ca909b0dc6',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00287.json',
#      'extra': 'whiskers.00287',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00287.json',
#      'hash': None},
#     {'id': '7223223d-3ead-4b73-8777-da3d3bb9b19a',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00288.json',
#      'extra': 'whiskers.00288',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00288.json',
#      'hash': None},
#     {'id': '19bc71b1-49de-4a16-8c70-8c337630bfd9',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00289.json',
#      'extra': 'whiskers.00289',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00289.json',
#      'hash': None},
#     {'id': '5c9a6db4-0d71-4d1c-a459-0dcac1058886',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00029.json',
#      'extra': 'whiskers.00029',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00029.json',
#      'hash': None},
#     {'id': '4cbf1d06-c4b0-42b8-821c-fb261e76afc7',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00290.json',
#      'extra': 'whiskers.00290',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00290.json',
#      'hash': None},
#     {'id': '649ad56d-b90a-4c92-aed5-7e675dab4537',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00291.json',
#      'extra': 'whiskers.00291',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00291.json',
#      'hash': None},
#     {'id': '7c990190-44a9-48ed-846c-696037e3b900',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00292.json',
#      'extra': 'whiskers.00292',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00292.json',
#      'hash': None},
#     {'id': 'b7a00539-33dc-46c2-9503-70df293b7834',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00293.json',
#      'extra': 'whiskers.00293',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00293.json',
#      'hash': None},
#     {'id': '3bfba8f9-ce04-424e-97ed-5a1d24df51dc',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00294.json',
#      'extra': 'whiskers.00294',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00294.json',
#      'hash': None},
#     {'id': 'dacaca4b-2477-4926-bc34-a25310128da1',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00295.json',
#      'extra': 'whiskers.00295',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00295.json',
#      'hash': None},
#     {'id': 'd9cf3ffe-8bde-43b6-af59-7111864e42eb',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00296.json',
#      'extra': 'whiskers.00296',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00296.json',
#      'hash': None},
#     {'id': '236e4670-5154-4091-9ef7-e5f6d15b1251',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00297.json',
#      'extra': 'whiskers.00297',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00297.json',
#      'hash': None},
#     {'id': '5d6e8da7-9577-4f9e-bf00-3faa07425ee7',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00298.json',
#      'extra': 'whiskers.00298',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00298.json',
#      'hash': None},
#     {'id': '3f43b24e-4756-4179-805a-dd5b88f7e100',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00299.json',
#      'extra': 'whiskers.00299',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00299.json',
#      'hash': None},
#     {'id': '45a2993e-8e40-485e-9752-f74e79d34968',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00003.json',
#      'extra': 'whiskers.00003',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00003.json',
#      'hash': None},
#     {'id': '756c0f45-bf65-49ab-bd02-36a8dc02199d',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00030.json',
#      'extra': 'whiskers.00030',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00030.json',
#      'hash': None},
#     {'id': '9176db68-693d-4c50-9488-ec2a192a7784',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00031.json',
#      'extra': 'whiskers.00031',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00031.json',
#      'hash': None},
#     {'id': 'fa712074-bb59-4eb8-b831-7f35e24f134e',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00032.json',
#      'extra': 'whiskers.00032',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00032.json',
#      'hash': None},
#     {'id': 'd46fabbd-9630-4896-90fe-6819ab237510',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00033.json',
#      'extra': 'whiskers.00033',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00033.json',
#      'hash': None},
#     {'id': '8927de1e-a8f6-4676-b4d1-ba483d982eec',
#      'relative_path': 'ea04/2024-04-04/001/behaviour_imaging/whiskers/behaviour.video_compressed_meta.whiskers.00034.json',
#      'extra': 'whiskers.00034',
#      'exists': True,
#      'file_name': 'behaviour.video_compressed_meta.whiskers.00034.json',
#      'hash': None}]}],
#  'auto_datetime': '2024-04-04T20:21:49.432435+02:00',
#  'alias': 'ea04/2024-04-04/001',
#  'u_alias': 'ea04_2024-04-04_001',
#  'path': '//cajal/cajal_data2/ONE/MotorSense/ea04/2024-04-04/001',
#  'json': {'whisker_stims': {'Stimulus right': {'0': 'Nothing', '1': 'A3'}}},
#  'probe_insertion': [],
#  'notes': [],
#  'default_data_repository_path': '//cajal/cajal_data2/ONE/MotorSense',
#  'default_data_repository_name': 'Cajal2MotorSense',
#  'default_data_repository_pk': '70a43e0f-09b3-4c0f-996c-12edbdaff06d',
#  'rel_path': 'ea04/2024-04-04/001',
#  'admin_url': '/admin/actions/session/1cae805a-5fd8-4798-ac83-64ac1850f29d/change/'}

# %%
result["count"]
# Out:
# 28

# %%
client.netloc
# Out:
# '127.0.0.1:80'

# %%
from alyx_connector.web.clients import ClientWithAuthentification
client = ClientWithAuthentification.setup_user(url = "http://127.0.0.1:80", username = "tjostmou", make_default=True)
client

# %%
client.path("sessions").endpoint.actions["list"].request(subject="ea04")

# %%
client.rest("sessions","list", subject = "ea04")

# %%
r = client.path("sessions").endpoint.actions["list"].request(subject="ea04")
r

# %%
r = client.rest("sessions","list")
r.ok

# %%
client.path("sessions").endpoint.actions["update"].describe()

# %%
[ (param.name, param.description, param.required) for param in client.path("subjects").endpoint.actions["list"].operation.parameters ]

# %%
client.list_endpoints()

# %%
client.describe("auth-token").actions

# %%
r = client.rest("sessions","list")

# %%
client.netloc

# %%
r.text

# %%
client.url

# %%
r.text

# %%
client.list_endpoints()

# %% [markdown]
# ## First access

# %%
one.ONE(base_url = "http://157.99.138.172:80")

# %% [markdown]
# ## In case of first setup problems :
# Can occur at setup or at first requet to the database (.rest folder was not created correctly)
# Check the file that keeps your logins :
# ### on linux :
# "/home/<user>/.one/.cache"
# and
# "/home/<user>/.one/.\<IP>_\<PORT>"
#
# ### On windows :
# "C:\Users\\<user\>\AppData\Roaming\.one\.cache"
# etc..
#
# The content should be similar to :

# %% [markdown]
# ## Accessing sessions

# %%
connector = one.ONE(mode = 'remote')
sessions = connector.search(subject = "dummy", details = True) # when setting details = True we get a dataframe with rows : sessions, columns : metadata fields
session = sessions.iloc[0] # we take the first session of the dataframe

# %% [markdown]
# ## Accessing data

# %%
files = connector.list_datasets(session.name, object = "trials", attribute = "event*" , extension = ".tdms")
files

# %%
file_records = connector.list_datasets(session.name, object = "trials", attribute = "event*" , extension = ".tdms" , details = True)
import pandas as pd
with pd.option_context('display.max_columns', 10000):
    display(file_records)

# %% [markdown]
# ## Dataset creation process
# When wanting to create new file entries, we need to suppli all the informations here :
# path :  remote_root/subject/date/number/(collection)/(revision)/object.attribute.(extra).extension
# The parts of the path in parentehesis are optionnal and can be blank. All the rest MUST be filled.
#
# The different parts of a file come from different locations of the database models : (this is named the **alf standard**)
#
#  - remote_root : Comes from a data_repository.
#      We will supply the information with the name of a data_repository (use data_repository key in data) or a primary key (use data_repository_pk key in data)
#
#  - subject : All three below come from a session. Simply supply a session primary key with session_pk key in data.
#              To obtain a session pk from a human readable session alias string, use one.to_eid(alias) (ex : alias can be 'dummy/2023-06-19/001')
#  - date :    '' Same as above
#  - number :  '' Same as above
#
#
#  - collection : Can be either "" (cannot be None anymore after changes in the model, for path construction simplicity sake) or "whateverfolder". Can chain folders like so : "whatevertoplevel/whateversub"
#  - revision : Need to supply a primary key with revision_pk. This requires you to first create a revision for the dataset.
#              For now this is not in use so we can keep wonderings about that for later.
#              (but still try as possible to not write code conflicting with this functionnality as it will probably be very usefull at some point anytime soon)
#
#  - object :    The two object and attribute parameters are set by specifying a dataset_type. This can be either a dataset_type name (using dataset_type key) or a dataset_type pk (using dataset_type_pk)
#  - attribute : Same as above. Note that if specifying a dataset_type name, it should be constructed as such : '\<object>.\<attribute>' in a string
#  - extra :     This will be supplied at the level of the file (a dataset can contain 0 to infinite files and is a "group" of files of the same content type). It will be defined later (in the firerecord creating process)
#  - extension : This is defined by the "data_format" model. It is basically a collection of file extensions and the general expectation of the content that we have with that extensions. Can be set either using the extension name (the extension string without the leading dot, using data_format) or a data_format primary key (using data_format_pk)

# %%
session.name

# %%
## Example :

data = {"session_pk": session.name,
        "data_format" : ".tdms",
        "dataset_type" : "trials.feedbackType",
        "data_repository_pk" : "05baa8e4-5eb5-4214-a008-c9e5331004b0",
        "collection" : "mycollection"
       }

dataset = connector.alyx.rest("datasets","create", data=data )
dataset

# %% [markdown]
# ## Accessing an already existing dataset to add files to it :

# %%
## Example :
# Dataset already existing is :
dataset_params = {"dataset_type" : "trials.feedbackType" , "collection" : "mycollection"}

#search for infos of the session where the dataset exists :
session_dict = connector.alyx.rest("sessions","read", id = session.name , no_cache = True)

#get the matching dataset infos :
for dataset in session_dict["data_dataset_session_related"] :
    dataset_check = {key: dataset[key] for key in dataset_params.keys() if key in dataset}
    comparisons = [ dataset_check[key] == dataset_params[key] for key in dataset_check.keys() ]
    if all(comparisons):
        break
dataset

# %% [markdown]
# # File records creation process
# We now only have the extra left to fill to have a complete file path recreateable (and easily searchable using individual components):
#
#  - extra :     This will be supplied at the level of the file (a dataset can contain 0 to infinite files and is a "group" of files of the same content type). It will be defined later (in the firerecord creating process)

# %%
data = {"dataset" : dataset["id"],
        "exist" : False, #this is a dummy file so i profit from this to set exist = False as normaly no file should be there. Set it to true if a real file is at the location there.
        "extra" : "00002"} # let's say this is file 000001 because there is one file per trial. Extra serves in that case. If you wan to have several extra parameters to differentiate : 
        # "extra" : "red.000001" also works. Simply split individual elemnts with dots. No trailing or leading dot (but the database should anyway clean those at save time if i did my job right)


file_record = connector.alyx.rest("files","create", data = data)

# %% [markdown]
# # 'Testing' file recomposition from dataset and file_record :
# The database will do it's job at patching elements together so that each file record have a calculated (and saved) field relative_path that will be the path of the file except the root.
# (all elements above up to subject)
# The root can be either the remote_root supplied by the database or a local root obtained within the one instance (that have been chosen at setup time).
#
# But if you anyway want to recompose a file with the elements themselves, you can do so with the function one.alf.spec.to_full_path  that takes as keyword arguments all parts
# described above in the **alf standard**.

# %%
import Inflow, one
# inflow is just the general purpose package i developped for the lab : install here is necessary : 
# pip install git+https://gitlab.pasteur.fr/haisslab/analysis-packages/Inflow.git@pre-releases

# %%
merge = file_record
merge.update(dataset)

Inflow.decorators.filter_kwargs( one.alf.spec.to_full_path )(**merge, root = merge["remote_root"])

# %% [markdown]
# You can indeed also supply the mapping from the panda series obtained with the connector.list_datasets method (only when specifying details=True otherwise it direclty returns a list of file paths using current data_acces_mode to determine if it should use local or remote root)

# %%
file_records = connector.list_datasets(session.name, object = "trials", attribute = "event*" , extension = ".tdms" , details = True)
import pandas as pd
with pd.option_context('display.max_columns', 10000):
    display(file_records)

# %%
# The relative path or full_path can be reconstructed easily only by supplying a mapping of all the components of a path to the one.alf.spec.to_full_path function.
#Note that for the example here i created a data repository named Calaj2Dummy with a Dummmy folder, and the mouse is also named dummy so there is a repetition of dummies. This is expected.
Inflow.decorators.filter_kwargs( one.alf.spec.to_full_path )(**file_records.iloc[0], root = file_records.iloc[0]["remote_root"])

# %% [markdown]
# # Local vs Remote data access
#
# If you want to access downloaded data from the local repository you set at the begining of the One setup, just paste the files there (with folders architecture kept starting at `subject`)
# Just set the `data_access_mode` to "remote" or "local" with `.set_data_access_mode("remote")`
# At start, the mode is local by default. It can be changed by writing : `one.ONE(data_access_mode = "remote")`
#
# You can also use a specific mode momentarily with the keyword argument : `as_mode` in `list_datasets` and `search` to specify `session.path` or `filerecords.full_path` to be build from either the local or remote versions of the paths.
# Whatever the choice, you will always have `session.local_path` and `session.remote_path` fields available, and `filerecords.local_full_path` and `filerecords.remote_full_path` available.
#
# ⚠️
# The `mode` parameter of one existed before I introduced local and remote paths. It also can be either of value "local" and "remote" but this time it doesn't refer to how file paths are constructed. It refers to how the rest queries are executed. The One class is a child of a One class that is local and use cache tables to query data. Sadly, it doesn't work great, but something that works great is no_cache argument. If you want to refresh values from the "remote", simply set this no_cache argument to True.
